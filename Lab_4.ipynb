# %%
# Persistent contrastive divergence algorithm

import numpy as np
import matplotlib.pyplot as plt
import mkl

mkl.set_num_threads(4)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

# %% [markdown]
# # MNIST dataset

# %%
import mnist
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # Restricted Boltzmann Machine & Contrastive Divergence algorithm

# %%
def sigmoid(matrix):
    return 1.0 / (1.0 + np.exp(-matrix))

class Rbm:
    def __init__(self, visible_size, hidden_size, learning_rate, pc_count = None):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        self.learning_rate = learning_rate
        self.pc_count = pc_count
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.PC = None if self.pc_count is None else append_ones(zeros(self.pc_count, self.hidden_size))

# %%
from numpy import linalg as LA

def reconstuction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    hidden[:, :-1] = sigmoid(minibatch @ rbm.W[:, :-1]) > np.random.rand(observations_count, rbm.W.shape[1] - 1)
    visible = sigmoid(hidden @ np.transpose(rbm.W[:-1, :]))
    
    error = ((LA.norm(minibatch[:, :-1] - visible)) ** 2) / observations_count

    # raise Exception("Not implemented!")

    return error

# %% [markdown]
# ## Algorytm Contrastive Divergence
#
# $\newcommand{\vect}[1]{\mathbf{#1}}$
# W sieci RBM gradient funkcji kosztu względem wag wyznaczamy zgodnie ze wzorem:
#
# $\frac{\delta}{\delta w_{ij}} -\log P(\vect{v}) = -\mathbf{E}[v_i h_j \vert \vect{v}] + \mathbf{E}[v_i h_j]$
#
# #### Faza pozytywna - odpowiada za część $\mathbf{E}[v_i h_j \vert \vect{v}]$
#
# Tą część gradientu wyznaczamy przez wyliczenie iloczynów $v_i h_j$ pomiędzy elementami wektora obserwacji ($v_i$) a prawdopodobieństwami aktywacji w warstwie ukrytej ($h_j$). Operację tą możemy zapisać w postaci zwektoryzowanej jako:
#
# $\nabla_P = \vect{v}^T\sigma(\vect{vW})$
#
# #### Faza negatywna - odpowiada za część $\mathbf{E}[v_i h_j]$
#
# Rozpoczynamy od prawdopodobieństw aktywacji neuronów w warstwie ukrytej, które zostały wyznaczone w fazie pozytywnej. Na ich podstawie losujemy próbkę aktywacji w warstwie ukrytej:
#
# $\vect{h} = \sigma (\vect{vW}) > [rand_1, rand_2, \dots, rand_m]$
#
# Następnie losujemy próbkę aktywacji w warstwie widocznej:
#
# $\vect{v}_1 = \sigma (\vect{hW}^T) > [rand_1, rand_2, \dots, rand_n]$
#
# Aby wyznaczyć *fantazję* sieci RBM, powyższe próbki losujemy (naprzemiennie) $k$ razy (gdzie $k$ to parametr algorytmu CD-*k*):
#
# $\vect{h}_{k-1} = \sigma (\vect{v}_{k-1}\vect{W}) > [rand_1, rand_2, \dots, rand_m]$,
# $\vect{v}_k = \sigma (\vect{h}_{k-1}\vect{W}^T) > [rand_1, rand_2, \dots, rand_n]$
#
# Część negatywną gradientu wyznaczamy poprzez wyliczenie iloczynów $v_{k_i} h_j$ pomiędzy elementami wektora *fantazji* RBM ($v_{k_i}$) a prawdopodobieństwami aktywacji w warstwie ukrytej wyliczonymi dla tejże *fantazji* ($h_j$). Operację tą możemy zapisać w postaci zwektoryzowanej jako:
#
# $\nabla_N = \vect{v}_k^T\sigma(\vect{v}_k\vect{W})$
#
#
# #### Aktualizacja macierzy wag RBM
#
# Uczymy stochastycznym spadkiem wzdłuż gradientu:
#
# $\phi_{t+1} \leftarrow \phi_t - \epsilon \nabla$
#
# co dla gradientu RBM daje:
#
# $W_{t+1} \leftarrow W_t + \epsilon \nabla_P - \epsilon \nabla_N$

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]

    positive_visible = minibatch
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
        
    # Positive
    positive_hidden[:, :-1] = sigmoid(positive_visible @ rbm.W[:, :-1])
    positive_gradient = (np.transpose(positive_visible) @ positive_hidden) / observations_count
        
    # Negative
    negative_hidden[:, :-1] = positive_hidden[:, :-1] > np.random.rand(observations_count, positive_hidden.shape[1] - 1)
    
    negative_visible[:, :-1] = sigmoid(negative_hidden @ np.transpose(rbm.W[:-1, :]))
    negative_visible[:, :-1] = negative_visible[:, :-1] > np.random.rand(observations_count, negative_visible.shape[1] - 1)
    
    for i in range(k-1):
        negative_hidden[:, :-1] = sigmoid(negative_visible @ rbm.W[:, :-1])
        negative_hidden[:, :-1] = negative_hidden[:, :-1] > np.random.rand(observations_count, negative_hidden.shape[1] - 1)
        
        negative_visible[:, :-1] = sigmoid(negative_hidden @ np.transpose(rbm.W[:-1, :]))
        negative_visible[:, :-1] = negative_visible[:, :-1] > np.random.rand(observations_count, negative_visible.shape[1] - 1)
        
    negative_hidden[:, :-1] = sigmoid(negative_visible @ rbm.W[:, :-1])
    negative_gradient = (np.transpose(negative_visible) @ negative_hidden) / observations_count
    
    rbm.W += (rbm.learning_rate * positive_gradient) - (rbm.learning_rate * negative_gradient)

    # raise Exception("Not implemented!")

# %% [markdown]
# ## Algorytm Persistent Contrastive Divergence
#
# $\newcommand{\vect}[1]{\mathbf{#1}}$
# Algorytm Persistent Contrastive Divergence (PCD) różni się od algorytmu CD przebiegiem fazy negatywnej. Faza pozytywna przebiega w PCD tak samo jak w algorytmie CD.
#
# W PCD faza negatywna rozpoczyna się od nie od przykładu uczącego, lecz od stanu *wirtualnych cząstek*, który został został zapamiętany w poprzedniej fazie negatywnej:
#
# $\vect{h} = \vect{p}$,
#
# gdzie $\vect{p}$ to macierz przechowująca stan *wirtualnych cząstek*. Po inicjalizacji negatywnego stanu ukrytego ($\vect{h}$) rozpoczynamy próbkowanie Gibbsa i wyznaczamy fantazję sieci ($\vect{v}_k$). Następnie zapamiętujemy nowy stan wirtualnych cząstek:
#
# $\vect{p} = \sigma (\vect{v}_k\vect{W}) > [rand_1, rand_2, \dots, rand_m]$.
#
# Na koniec aktualizujemy wagi RBM. Aktualizacja wag przebiega tak samo jak w algorytmie CD.

# %%
def pcd(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]
    
    positive_visible = minibatch
    negative_visible = append_ones(zeros(rbm.pc_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(rbm.pc_count, rbm.hidden_size))
    
    # Positive
    positive_hidden[:, :-1] = sigmoid(positive_visible @ rbm.W[:, :-1])
    positive_gradient = (np.transpose(positive_visible) @ positive_hidden) / observations_count
    
    # Negative
    negative_hidden[:, :-1] = rbm.PC[:, :-1]
    negative_visible[:, :-1] = sigmoid(negative_hidden @ np.transpose(rbm.W[:-1, :])) > np.random.rand(negative_visible.shape[0], negative_visible.shape[1] - 1)
    
    for i in range(k-1):
        negative_hidden[:, :-1] = sigmoid(negative_visible @ rbm.W[:, :-1]) > np.random.rand(negative_hidden.shape[0], negative_hidden.shape[1] - 1)
        negative_visible[:, :-1] = sigmoid(negative_hidden @ np.transpose(rbm.W[:-1, :])) > np.random.rand(negative_visible.shape[0], negative_visible.shape[1] - 1)
    
    negative_hidden[:, :-1] = sigmoid(negative_visible @ rbm.W[:, :-1])
    negative_gradient = np.transpose(negative_visible) @ negative_hidden / rbm.pc_count
    
    
    rbm.PC[:, :-1] = negative_hidden[:, :-1] > np.random.rand(rbm.PC.shape[0], rbm.PC.shape[1] - 1)
    rbm.W += (rbm.learning_rate * positive_gradient) - (rbm.learning_rate * negative_gradient)

    # raise Exception("Not implemented!")

# %% [markdown]
# # RBM Training

# %%
def sample_rbm(rbm, minibatch, steps):
    observations_count = minibatch.shape[0]

    visible = minibatch
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    for cd_i in range(steps):
        hidden[:, :-1] = sigmoid(visible @ rbm.W[:, :-1])
        hidden[:, :-1] = (hidden[:, :-1] > rand(observations_count, rbm.hidden_size)).astype(np.float32)
    
        visible[:, :-1] = sigmoid(hidden @ np.transpose(rbm.W[:-1, :]))
        if cd_i < (steps - 1):
            visible[:, :-1] = (visible[:, :-1] > rand(observations_count, rbm.visible_size)).astype(np.float32)

    return visible

# %%
def draw_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)
    
def draw_samples(rbm, initial_batch, steps=200):
    tiles(np.reshape(sample_rbm(rbm, initial_batch, steps)[:, :-1], (-1, 24, 28, 28)))

# %%
def train_epoch(rbm, dataset, batch_size, training_algorithm=cdk):
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        training_algorithm(rbm, batch)
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

def run_training(rbm, dataset, monitoring_set, batch_size, epochs_count, training_algorithm=cdk):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch),  end="\t")

        start_time = time.time()
        train_epoch(rbm, dataset, batch_size, training_algorithm)

        elapsed = time.time() - start_time
        error = reconstuction_error(rbm, monitoring_set)
        print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

    print("Training finished!")

# %%
import time

DATASET_SIZE = 20000 # 60000 for whole dataset
DIGIT_SIZE = 28

VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 128

mnist_train = mnist.train_images().astype(np.float32) / 255.0
np.random.shuffle(mnist_train)
dataset = np.reshape(mnist_train[:DATASET_SIZE], newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
dataset = append_ones(dataset)

monitoring_indeces = np.random.choice(DATASET_SIZE, 256, replace=False)
monitoring_set = dataset[monitoring_indeces]

# %% [markdown]
# ## CDK Training

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

CDK_LEARNING_RATE = 0.1

rbm = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, CDK_LEARNING_RATE)
draw_filters(rbm)

run_training(rbm, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT, cdk)

draw_filters(rbm)
draw_samples(rbm, monitoring_set[:10*24])
# Out:
# Epoch 0:	#####################################################	elapsed: 1.10s, reconstruction error: 32.25
# Epoch 1:	#####################################################	elapsed: 1.09s, reconstruction error: 26.09
# Epoch 2:	#####################################################	elapsed: 1.14s, reconstruction error: 22.65
# Epoch 3:	#####################################################	elapsed: 1.16s, reconstruction error: 20.63
# Epoch 4:	#####################################################	elapsed: 1.09s, reconstruction error: 19.24
# Epoch 5:	#####################################################	elapsed: 1.15s, reconstruction error: 18.35
# Epoch 6:	#####################################################	elapsed: 1.11s, reconstruction error: 17.37
# Epoch 7:	#####################################################	elapsed: 1.09s, reconstruction error: 16.92
# Epoch 8:	#####################################################	elapsed: 1.09s, reconstruction error: 16.40
# Epoch 9:	#####################################################	elapsed: 1.09s, reconstruction error: 15.90
# Epoch 10:	#####################################################	elapsed: 1.08s, reconstruction error: 15.52
# Epoch 11:	#####################################################	elapsed: 1.06s, reconstruction error: 15.07
# Epoch 12:	#####################################################	elapsed: 1.12s, reconstruction error: 14.90
# Epoch 13:	#####################################################	elapsed: 1.13s, reconstruction error: 14.42
# Epoch 14:	#####################################################	elapsed: 1.08s, reconstruction error: 14.23
# Epoch 15:	#####################################################	elapsed: 1.11s, reconstruction error: 13.99
# Epoch 16:	#####################################################	elapsed: 1.12s, reconstruction error: 14.00
# Epoch 17:	#####################################################	elapsed: 1.13s, reconstruction error: 13.58
# Epoch 18:	#####################################################	elapsed: 1.09s, reconstruction error: 13.52
# Epoch 19:	#####################################################	elapsed: 1.06s, reconstruction error: 13.29
# Epoch 20:	#####################################################	elapsed: 1.09s, reconstruction error: 13.14
# Epoch 21:	#####################################################	elapsed: 1.18s, reconstruction error: 12.96
# Epoch 22:	#####################################################	elapsed: 1.08s, reconstruction error: 12.71
# Epoch 23:	#####################################################	elapsed: 1.06s, reconstruction error: 12.74
# Epoch 24:	#####################################################	elapsed: 1.07s, reconstruction error: 12.44
# Epoch 25:	#####################################################	elapsed: 1.09s, reconstruction error: 12.67
# Epoch 26:	#####################################################	elapsed: 1.07s, reconstruction error: 12.31
# Epoch 27:	#####################################################	elapsed: 1.05s, reconstruction error: 12.20
# Epoch 28:	#####################################################	elapsed: 1.05s, reconstruction error: 12.09
# Epoch 29:	#####################################################	elapsed: 1.06s, reconstruction error: 12.17
# Epoch 30:	#####################################################	elapsed: 1.07s, reconstruction error: 12.06
# Epoch 31:	#####################################################	elapsed: 1.07s, reconstruction error: 11.86
# Epoch 32:	#####################################################	elapsed: 1.06s, reconstruction error: 11.89
# Epoch 33:	#####################################################	elapsed: 1.10s, reconstruction error: 11.66
# Epoch 34:	#####################################################	elapsed: 1.15s, reconstruction error: 11.80
# Epoch 35:	#####################################################	elapsed: 1.12s, reconstruction error: 11.64
# Epoch 36:	#####################################################	elapsed: 1.08s, reconstruction error: 11.64
# Epoch 37:	#####################################################	elapsed: 1.14s, reconstruction error: 11.49
# Epoch 38:	#####################################################	elapsed: 1.24s, reconstruction error: 11.62
# Epoch 39:	#####################################################	elapsed: 1.08s, reconstruction error: 11.33
# Epoch 40:	#####################################################	elapsed: 1.13s, reconstruction error: 11.30
# Epoch 41:	#####################################################	elapsed: 1.10s, reconstruction error: 11.38
# Epoch 42:	#####################################################	elapsed: 1.09s, reconstruction error: 11.28
# Epoch 43:	#####################################################	elapsed: 1.10s, reconstruction error: 11.16
# Epoch 44:	#####################################################	elapsed: 1.11s, reconstruction error: 11.16
# Epoch 45:	#####################################################	elapsed: 1.10s, reconstruction error: 11.20
# Epoch 46:	#####################################################	elapsed: 1.09s, reconstruction error: 11.18
# Epoch 47:	#####################################################	elapsed: 1.10s, reconstruction error: 10.97
# Epoch 48:	#####################################################	elapsed: 1.10s, reconstruction error: 11.03
# Epoch 49:	#####################################################	elapsed: 1.12s, reconstruction error: 11.12
# Training finished!

# %% [markdown]
# ## PCD Training

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

PCD_PARTICLES_COUNT = 128
PCD_LEARNING_RATE = 0.01

rbm_pcd = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, PCD_LEARNING_RATE, PCD_PARTICLES_COUNT)
draw_filters(rbm_pcd)

run_training(rbm_pcd, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT, pcd)

draw_filters(rbm_pcd)
draw_samples(rbm_pcd, monitoring_set[:10*24])
# Out:
# Epoch 0:	#####################################################	elapsed: 1.07s, reconstruction error: 78.25
# Epoch 1:	#####################################################	elapsed: 1.06s, reconstruction error: 59.69
# Epoch 2:	#####################################################	elapsed: 1.05s, reconstruction error: 46.53
# Epoch 3:	#####################################################	elapsed: 1.06s, reconstruction error: 40.97
# Epoch 4:	#####################################################	elapsed: 1.06s, reconstruction error: 36.55
# Epoch 5:	#####################################################	elapsed: 1.53s, reconstruction error: 34.45
# Epoch 6:	#####################################################	elapsed: 1.10s, reconstruction error: 32.68
# Epoch 7:	#####################################################	elapsed: 1.11s, reconstruction error: 31.14
# Epoch 8:	#####################################################	elapsed: 1.08s, reconstruction error: 31.01
# Epoch 9:	#####################################################	elapsed: 1.10s, reconstruction error: 30.32
# Epoch 10:	#####################################################	elapsed: 1.15s, reconstruction error: 29.51
# Epoch 11:	#####################################################	elapsed: 1.07s, reconstruction error: 29.04
# Epoch 12:	#####################################################	elapsed: 1.11s, reconstruction error: 27.68
# Epoch 13:	#####################################################	elapsed: 1.06s, reconstruction error: 27.24
# Epoch 14:	#####################################################	elapsed: 1.00s, reconstruction error: 26.95
# Epoch 15:	#####################################################	elapsed: 0.92s, reconstruction error: 26.33
# Epoch 16:	#####################################################	elapsed: 0.94s, reconstruction error: 26.17
# Epoch 17:	#####################################################	elapsed: 0.92s, reconstruction error: 25.46
# Epoch 18:	#####################################################	elapsed: 0.94s, reconstruction error: 25.07
# Epoch 19:	#####################################################	elapsed: 0.92s, reconstruction error: 24.35
# Epoch 20:	#####################################################	elapsed: 0.97s, reconstruction error: 24.36
# Epoch 21:	#####################################################	elapsed: 1.24s, reconstruction error: 24.03
# Epoch 22:	#####################################################	elapsed: 1.00s, reconstruction error: 23.19
# Epoch 23:	#####################################################	elapsed: 1.29s, reconstruction error: 22.73
# Epoch 24:	#####################################################	elapsed: 1.29s, reconstruction error: 22.47
# Epoch 25:	#####################################################	elapsed: 1.08s, reconstruction error: 22.49
# Epoch 26:	#####################################################	elapsed: 1.10s, reconstruction error: 22.22
# Epoch 27:	#####################################################	elapsed: 1.07s, reconstruction error: 21.71
# Epoch 28:	#####################################################	elapsed: 1.10s, reconstruction error: 21.14
# Epoch 29:	#####################################################	elapsed: 1.12s, reconstruction error: 20.87
# Epoch 30:	#####################################################	elapsed: 1.09s, reconstruction error: 20.59
# Epoch 31:	#####################################################	elapsed: 1.09s, reconstruction error: 20.25
# Epoch 32:	#####################################################	elapsed: 1.09s, reconstruction error: 19.91
# Epoch 33:	#####################################################	elapsed: 1.10s, reconstruction error: 19.45
# Epoch 34:	#####################################################	elapsed: 1.09s, reconstruction error: 19.02
# Epoch 35:	#####################################################	elapsed: 1.10s, reconstruction error: 19.02
# Epoch 36:	#####################################################	elapsed: 1.08s, reconstruction error: 18.49
# Epoch 37:	#####################################################	elapsed: 1.09s, reconstruction error: 18.32
# Epoch 38:	#####################################################	elapsed: 1.13s, reconstruction error: 17.97
# Epoch 39:	#####################################################	elapsed: 1.07s, reconstruction error: 17.84
# Epoch 40:	#####################################################	elapsed: 1.10s, reconstruction error: 17.48
# Epoch 41:	#####################################################	elapsed: 1.09s, reconstruction error: 17.12
# Epoch 42:	#####################################################	elapsed: 1.09s, reconstruction error: 16.75
# Epoch 43:	#####################################################	elapsed: 1.09s, reconstruction error: 16.65
# Epoch 44:	#####################################################	elapsed: 1.08s, reconstruction error: 16.46
# Epoch 45:	#####################################################	elapsed: 1.08s, reconstruction error: 16.34
# Epoch 46:	#####################################################	elapsed: 1.09s, reconstruction error: 16.22
# Epoch 47:	#####################################################	elapsed: 1.09s, reconstruction error: 16.15
# Epoch 48:	#####################################################	elapsed: 1.07s, reconstruction error: 16.08
# Epoch 49:	#####################################################	elapsed: 1.08s, reconstruction error: 15.53
# Training finished!

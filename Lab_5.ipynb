# %%
# Momentum method. DBN networks
# 1. Implementation of a momentum method in CD-k
# 2. Implementation learning and sampling of DBN network

import numpy as np
import matplotlib.pyplot as plt
import mkl

mkl.set_num_threads(4)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

# %% [markdown]
# # MNIST dataset

# %%
import mnist
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # Restricted Boltzmann Machine & Contrastive Divergence algorithm

# %%
def sigmoid(matrix):
    return 1.0 / (1.0 + np.exp(-matrix))

class Rbm:
    def __init__(self, visible_size, hidden_size, learning_rate, momentum):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.M = zeros(self.visible_size+1, self.hidden_size+1)

# %%
from numpy import linalg as LA

def reconstuction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    hidden[:, :-1] = sigmoid(minibatch @ rbm.W[:, :-1]) > np.random.rand(observations_count, rbm.W.shape[1] - 1)
    visible = sigmoid(hidden @ np.transpose(rbm.W[:-1, :]))
    
    error = ((LA.norm(minibatch[:, :-1] - visible)) ** 2) / observations_count

    # raise Exception("Not implemented!")

    return error

# %%
def train_epoch(rbm, dataset, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(rbm, batch)
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

def run_training(rbm, dataset, monitoring_set, batch_size, epochs_count):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch),  end="\t")
        
        if epoch == 5:
            rbm.momentum = 0.8

        start_time = time.time()
        train_epoch(rbm, dataset, batch_size)
        elapsed = time.time() - start_time
        
        error = reconstuction_error(rbm, monitoring_set)
        print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

    print("Training finished!")

# %%
def draw_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# # 1. RBM Training with momentum

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]

    positive_visible = minibatch
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
        
    # Positive
    positive_hidden[:, :-1] = sigmoid(positive_visible @ rbm.W[:, :-1])
    positive_gradient = (np.transpose(positive_visible) @ positive_hidden) / observations_count
        
    # Negative
    negative_hidden[:, :-1] = positive_hidden[:, :-1] > np.random.rand(observations_count, positive_hidden.shape[1] - 1)
    
    negative_visible[:, :-1] = sigmoid(negative_hidden @ np.transpose(rbm.W[:-1, :]))
    negative_visible[:, :-1] = negative_visible[:, :-1] > np.random.rand(observations_count, negative_visible.shape[1] - 1)
    
    for i in range(k-1):
        negative_hidden[:, :-1] = sigmoid(negative_visible @ rbm.W[:, :-1])
        negative_hidden[:, :-1] = negative_hidden[:, :-1] > np.random.rand(observations_count, negative_hidden.shape[1] - 1)
        
        negative_visible[:, :-1] = sigmoid(negative_hidden @ np.transpose(rbm.W[:-1, :]))
        negative_visible[:, :-1] = negative_visible[:, :-1] > np.random.rand(observations_count, negative_visible.shape[1] - 1)
        
    negative_hidden[:, :-1] = sigmoid(negative_visible @ rbm.W[:, :-1])
    negative_gradient = (np.transpose(negative_visible) @ negative_hidden) / observations_count
    
    rbm.M = rbm.momentum * rbm.M + rbm.learning_rate * (positive_gradient - negative_gradient)
    rbm.W += rbm.M

    # raise Exception("Not implemented!")

# %%
import time

DATASET_SIZE = 20000 # 60000 for whole dataset
DIGIT_SIZE = 28

VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 128

mnist_train = mnist.train_images().astype(np.float32) / 255.0
np.random.shuffle(mnist_train)
dataset = np.reshape(mnist_train[:DATASET_SIZE], newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
dataset = append_ones(dataset)

monitoring_indeces = np.random.choice(DATASET_SIZE, 256, replace=False)
monitoring_set = dataset[monitoring_indeces]

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
MOMENTUM = 0.5

rbm = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM)
draw_filters(rbm)

run_training(rbm, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT)

draw_filters(rbm)
# Out:
# Epoch 0:	#####################################################	elapsed: 1.21s, reconstruction error: 26.45
# Epoch 1:	#####################################################	elapsed: 1.09s, reconstruction error: 21.37
# Epoch 2:	#####################################################	elapsed: 1.09s, reconstruction error: 18.79
# Epoch 3:	#####################################################	elapsed: 1.11s, reconstruction error: 17.26
# Epoch 4:	#####################################################	elapsed: 1.18s, reconstruction error: 16.28
# Epoch 5:	#####################################################	elapsed: 1.09s, reconstruction error: 15.09
# Epoch 6:	#####################################################	elapsed: 1.07s, reconstruction error: 14.01
# Epoch 7:	#####################################################	elapsed: 1.07s, reconstruction error: 13.28
# Epoch 8:	#####################################################	elapsed: 1.08s, reconstruction error: 12.82
# Epoch 9:	#####################################################	elapsed: 1.10s, reconstruction error: 12.61
# Epoch 10:	#####################################################	elapsed: 1.15s, reconstruction error: 12.15
# Epoch 11:	#####################################################	elapsed: 1.10s, reconstruction error: 12.06
# Epoch 12:	#####################################################	elapsed: 1.08s, reconstruction error: 11.74
# Epoch 13:	#####################################################	elapsed: 1.03s, reconstruction error: 11.63
# Epoch 14:	#####################################################	elapsed: 0.98s, reconstruction error: 11.56
# Epoch 15:	#####################################################	elapsed: 1.10s, reconstruction error: 11.25
# Epoch 16:	#####################################################	elapsed: 1.13s, reconstruction error: 11.21
# Epoch 17:	#####################################################	elapsed: 1.12s, reconstruction error: 11.23
# Epoch 18:	#####################################################	elapsed: 1.14s, reconstruction error: 11.26
# Epoch 19:	#####################################################	elapsed: 1.12s, reconstruction error: 11.03
# Epoch 20:	#####################################################	elapsed: 1.10s, reconstruction error: 10.97
# Epoch 21:	#####################################################	elapsed: 1.11s, reconstruction error: 11.09
# Epoch 22:	#####################################################	elapsed: 1.11s, reconstruction error: 10.78
# Epoch 23:	#####################################################	elapsed: 1.10s, reconstruction error: 10.95
# Epoch 24:	#####################################################	elapsed: 1.16s, reconstruction error: 10.79
# Epoch 25:	#####################################################	elapsed: 1.09s, reconstruction error: 10.90
# Epoch 26:	#####################################################	elapsed: 1.14s, reconstruction error: 10.64
# Epoch 27:	#####################################################	elapsed: 1.22s, reconstruction error: 10.76
# Epoch 28:	#####################################################	elapsed: 1.30s, reconstruction error: 10.62
# Epoch 29:	#####################################################	elapsed: 1.12s, reconstruction error: 10.55
# Epoch 30:	#####################################################	elapsed: 1.11s, reconstruction error: 10.60
# Epoch 31:	#####################################################	elapsed: 1.11s, reconstruction error: 10.55
# Epoch 32:	#####################################################	elapsed: 1.07s, reconstruction error: 10.32
# Epoch 33:	#####################################################	elapsed: 1.15s, reconstruction error: 10.42
# Epoch 34:	#####################################################	elapsed: 1.19s, reconstruction error: 10.54
# Epoch 35:	#####################################################	elapsed: 1.21s, reconstruction error: 10.46
# Epoch 36:	#####################################################	elapsed: 1.18s, reconstruction error: 10.40
# Epoch 37:	#####################################################	elapsed: 1.17s, reconstruction error: 10.46
# Epoch 38:	#####################################################	elapsed: 1.18s, reconstruction error: 10.50
# Epoch 39:	#####################################################	elapsed: 1.33s, reconstruction error: 10.21
# Epoch 40:	#####################################################	elapsed: 1.57s, reconstruction error: 10.39
# Epoch 41:	#####################################################	elapsed: 1.25s, reconstruction error: 10.22
# Epoch 42:	#####################################################	elapsed: 1.19s, reconstruction error: 10.18
# Epoch 43:	#####################################################	elapsed: 1.15s, reconstruction error: 10.17
# Epoch 44:	#####################################################	elapsed: 1.17s, reconstruction error: 10.26
# Epoch 45:	#####################################################	elapsed: 1.24s, reconstruction error: 10.21
# Epoch 46:	#####################################################	elapsed: 1.21s, reconstruction error: 10.25
# Epoch 47:	#####################################################	elapsed: 1.55s, reconstruction error: 10.23
# Epoch 48:	#####################################################	elapsed: 1.27s, reconstruction error: 10.14
# Epoch 49:	#####################################################	elapsed: 1.20s, reconstruction error: 10.09
# Training finished!

# %% [markdown]
# # 2. DBN Training

# %%
def propagate_up(dbn, layers_count, visible):
    for i in range(layers_count):
        visible = append_ones(sigmoid(visible @ dbn[i].W[:, :-1]))
    return visible

def propagate_down(dbn, layers_count, hidden):
    for i in reversed(range(layers_count)):
        hidden = append_ones(sigmoid(hidden @ np.transpose(dbn[i].W[:-1, :])))
    return hidden

# %% [markdown]
# ### DBN reconstruction error

# %%
def dbn_reconstuction_error(dbn, layers_count, minibatch):
    propagated = propagate_up(dbn, layers_count, minibatch)
    return reconstuction_error(dbn[layers_count], propagated)

    # raise Exception("Not implemented!")

# %% [markdown]
# ### Sampling in Deep Belief Networks

# %%
def sample_rbm(rbm, minibatch, steps):
    observations_count = minibatch.shape[0]

    visible = minibatch
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    for cd_i in range(steps):
        hidden[:, :-1] = sigmoid(visible @ rbm.W[:, :-1])
        hidden[:, :-1] = (hidden[:, :-1] > rand(observations_count, rbm.hidden_size)).astype(np.float32)
    
        visible[:, :-1] = sigmoid(hidden @ np.transpose(rbm.W[:-1, :]))
        if cd_i < (steps - 1):
            visible[:, :-1] = (visible[:, :-1] > rand(observations_count, rbm.visible_size)).astype(np.float32)

    return visible

# %%
def sample_dbn(dbn, layer_idx, minibatch, steps):
    minibatch = propagate_up(dbn, layer_idx, minibatch)
    sample = sample_rbm(dbn[layer_idx], minibatch, steps)
    return propagate_down(dbn, layer_idx, sample)

    # raise Exception("Not implemented!")

# %%
def draw_layer_samples(dbn, layer_idx, minibatch, steps=200):
    samples = sample_dbn(dbn, layer_idx, minibatch, steps)
    tiles(np.reshape(samples[:, :-1], newshape=(-1, 16, 28, 28)))

# %% [markdown]
# ### Greedy layer-wise training

# %%
def train_dbn(dbn, layer_idx, dataset, batch_size):
    dataset = propagate_up(dbn, layer_idx, dataset)
    
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(dbn[layer_idx], batch)
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")
    
    # raise Exception("This part is unimplemented.")

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
MOMENTUM = 0.5

DBN_HIDDEN_LAYER_SIZE = 200
dbn = [
    Rbm(VISIBLE_LAYER_SIZE, DBN_HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM),
    Rbm(DBN_HIDDEN_LAYER_SIZE, DBN_HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM),
    Rbm(DBN_HIDDEN_LAYER_SIZE, DBN_HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM)
]

for layer_idx in range(len(dbn)):
    print("\nLearning layer {}".format(layer_idx))

    for epoch in range(EPOCHS_COUNT):
        print("Epoch {}:".format(epoch),  end="\t")

        if epoch == 5:
            dbn[layer_idx].momentum = 0.8
        
        start_time = time.time()
        train_dbn(dbn, layer_idx, dataset, BATCH_SIZE)
        elapsed = time.time() - start_time
        
        error = dbn_reconstuction_error(dbn, layer_idx, monitoring_set)
        print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))
    
print("Training finished!")
# Out:
# Learning layer 0
# Epoch 0:	#####################################################	elapsed: 1.49s, reconstruction error: 24.53
# Epoch 1:	#####################################################	elapsed: 1.48s, reconstruction error: 19.25
# Epoch 2:	#####################################################	elapsed: 1.50s, reconstruction error: 16.70
# Epoch 3:	#####################################################	elapsed: 1.51s, reconstruction error: 15.19
# Epoch 4:	#####################################################	elapsed: 1.61s, reconstruction error: 14.15
# Epoch 5:	#####################################################	elapsed: 1.53s, reconstruction error: 12.85
# Epoch 6:	#####################################################	elapsed: 1.53s, reconstruction error: 11.93
# Epoch 7:	#####################################################	elapsed: 1.51s, reconstruction error: 11.36
# Epoch 8:	#####################################################	elapsed: 1.48s, reconstruction error: 10.78
# Epoch 9:	#####################################################	elapsed: 1.52s, reconstruction error: 10.40
# Epoch 10:	#####################################################	elapsed: 1.50s, reconstruction error: 10.39
# Epoch 11:	#####################################################	elapsed: 1.48s, reconstruction error: 10.21
# Epoch 12:	#####################################################	elapsed: 1.47s, reconstruction error: 9.93
# Epoch 13:	#####################################################	elapsed: 1.50s, reconstruction error: 9.78
# Epoch 14:	#####################################################	elapsed: 1.46s, reconstruction error: 9.58
# Epoch 15:	#####################################################	elapsed: 1.47s, reconstruction error: 9.45
# Epoch 16:	#####################################################	elapsed: 1.51s, reconstruction error: 9.29
# Epoch 17:	#####################################################	elapsed: 1.47s, reconstruction error: 9.49
# Epoch 18:	#####################################################	elapsed: 1.45s, reconstruction error: 9.14
# Epoch 19:	#####################################################	elapsed: 1.44s, reconstruction error: 9.04
# Epoch 20:	#####################################################	elapsed: 1.42s, reconstruction error: 9.18
# Epoch 21:	#####################################################	elapsed: 1.32s, reconstruction error: 9.02
# Epoch 22:	#####################################################	elapsed: 1.31s, reconstruction error: 9.10
# Epoch 23:	#####################################################	elapsed: 1.25s, reconstruction error: 9.05
# Epoch 24:	#####################################################	elapsed: 1.25s, reconstruction error: 8.89
# Epoch 25:	#####################################################	elapsed: 1.24s, reconstruction error: 8.93
# Epoch 26:	#####################################################	elapsed: 1.24s, reconstruction error: 8.85
# Epoch 27:	#####################################################	elapsed: 1.26s, reconstruction error: 8.81
# Epoch 28:	#####################################################	elapsed: 1.26s, reconstruction error: 8.75
# Epoch 29:	#####################################################	elapsed: 1.26s, reconstruction error: 8.85
# Epoch 30:	#####################################################	elapsed: 1.25s, reconstruction error: 8.72
# Epoch 31:	#####################################################	elapsed: 1.24s, reconstruction error: 8.62
# Epoch 32:	#####################################################	elapsed: 1.25s, reconstruction error: 8.62
# Epoch 33:	#####################################################	elapsed: 1.24s, reconstruction error: 8.78
# Epoch 34:	#####################################################	elapsed: 1.34s, reconstruction error: 8.51
# Epoch 35:	#####################################################	elapsed: 1.48s, reconstruction error: 8.59
# Epoch 36:	#####################################################	elapsed: 1.49s, reconstruction error: 8.58
# Epoch 37:	#####################################################	elapsed: 1.49s, reconstruction error: 8.47
# Epoch 38:	#####################################################	elapsed: 1.58s, reconstruction error: 8.45
# Epoch 39:	#####################################################	elapsed: 1.61s, reconstruction error: 8.53
# Epoch 40:	#####################################################	elapsed: 1.47s, reconstruction error: 8.52
# Epoch 41:	#####################################################	elapsed: 1.51s, reconstruction error: 8.24
# Epoch 42:	#####################################################	elapsed: 1.71s, reconstruction error: 8.55
# Epoch 43:	#####################################################	elapsed: 1.63s, reconstruction error: 8.14
# Epoch 44:	#####################################################	elapsed: 1.56s, reconstruction error: 8.45
# Epoch 45:	#####################################################	elapsed: 1.85s, reconstruction error: 8.47
# Epoch 46:	#####################################################	elapsed: 1.59s, reconstruction error: 8.27
# Epoch 47:	#####################################################	elapsed: 1.55s, reconstruction error: 8.43
# Epoch 48:	#####################################################	elapsed: 1.52s, reconstruction error: 8.33
# Epoch 49:	#####################################################	elapsed: 1.53s, reconstruction error: 8.39
#
# Learning layer 1
# Epoch 0:	#####################################################	elapsed: 0.70s, reconstruction error: 14.16
# Epoch 1:	#####################################################	elapsed: 0.70s, reconstruction error: 10.96
# Epoch 2:	#####################################################	elapsed: 0.73s, reconstruction error: 9.14
# Epoch 3:	#####################################################	elapsed: 0.70s, reconstruction error: 8.15
# Epoch 4:	#####################################################	elapsed: 0.73s, reconstruction error: 7.50
# Epoch 5:	#####################################################	elapsed: 0.71s, reconstruction error: 6.81
# Epoch 6:	#####################################################	elapsed: 0.72s, reconstruction error: 6.15
# Epoch 7:	#####################################################	elapsed: 0.69s, reconstruction error: 5.92
# Epoch 8:	#####################################################	elapsed: 0.69s, reconstruction error: 5.48
# Epoch 9:	#####################################################	elapsed: 0.70s, reconstruction error: 5.30
# Epoch 10:	#####################################################	elapsed: 0.70s, reconstruction error: 5.15
# Epoch 11:	#####################################################	elapsed: 0.70s, reconstruction error: 5.00
# Epoch 12:	#####################################################	elapsed: 0.69s, reconstruction error: 4.90
# Epoch 13:	#####################################################	elapsed: 0.70s, reconstruction error: 4.86
# Epoch 14:	#####################################################	elapsed: 0.69s, reconstruction error: 4.82
# Epoch 15:	#####################################################	elapsed: 0.69s, reconstruction error: 4.64
# Epoch 16:	#####################################################	elapsed: 0.70s, reconstruction error: 4.58
# Epoch 17:	#####################################################	elapsed: 0.70s, reconstruction error: 4.51
# Epoch 18:	#####################################################	elapsed: 0.70s, reconstruction error: 4.59
# Epoch 19:	#####################################################	elapsed: 0.70s, reconstruction error: 4.49
# Epoch 20:	#####################################################	elapsed: 0.69s, reconstruction error: 4.46
# Epoch 21:	#####################################################	elapsed: 0.69s, reconstruction error: 4.43
# Epoch 22:	#####################################################	elapsed: 0.67s, reconstruction error: 4.24
# Epoch 23:	#####################################################	elapsed: 0.70s, reconstruction error: 4.37
# Epoch 24:	#####################################################	elapsed: 0.70s, reconstruction error: 4.53
# Epoch 25:	#####################################################	elapsed: 0.72s, reconstruction error: 4.31
# Epoch 26:	#####################################################	elapsed: 0.74s, reconstruction error: 4.30
# Epoch 27:	#####################################################	elapsed: 0.69s, reconstruction error: 4.25
# Epoch 28:	#####################################################	elapsed: 0.69s, reconstruction error: 4.29
# Epoch 29:	#####################################################	elapsed: 0.91s, reconstruction error: 4.28
# Epoch 30:	#####################################################	elapsed: 0.72s, reconstruction error: 4.28
# Epoch 31:	#####################################################	elapsed: 0.73s, reconstruction error: 4.30
# Epoch 32:	#####################################################	elapsed: 0.72s, reconstruction error: 4.22
# Epoch 33:	#####################################################	elapsed: 0.91s, reconstruction error: 4.20
# Epoch 34:	#####################################################	elapsed: 0.79s, reconstruction error: 4.15
# Epoch 35:	#####################################################	elapsed: 0.71s, reconstruction error: 4.11
# Epoch 36:	#####################################################	elapsed: 0.82s, reconstruction error: 4.07
# Epoch 37:	#####################################################	elapsed: 0.71s, reconstruction error: 4.24
# Epoch 38:	#####################################################	elapsed: 0.69s, reconstruction error: 4.18
# Epoch 39:	#####################################################	elapsed: 0.70s, reconstruction error: 4.11
# Epoch 40:	#####################################################	elapsed: 0.68s, reconstruction error: 4.10
# Epoch 41:	#####################################################	elapsed: 0.69s, reconstruction error: 4.05
# Epoch 42:	#####################################################	elapsed: 0.69s, reconstruction error: 4.06
# Epoch 43:	#####################################################	elapsed: 0.70s, reconstruction error: 4.12
# Epoch 44:	#####################################################	elapsed: 0.70s, reconstruction error: 4.20
# Epoch 45:	#####################################################	elapsed: 0.69s, reconstruction error: 4.07
# Epoch 46:	#####################################################	elapsed: 0.90s, reconstruction error: 4.01
# Epoch 47:	#####################################################	elapsed: 0.71s, reconstruction error: 4.11
# Epoch 48:	#####################################################	elapsed: 0.70s, reconstruction error: 4.12
# Epoch 49:	#####################################################	elapsed: 0.72s, reconstruction error: 4.08
#
# Learning layer 2
# Epoch 0:	#####################################################	elapsed: 1.01s, reconstruction error: 10.39
# Epoch 1:	#####################################################	elapsed: 0.77s, reconstruction error: 7.53
# Epoch 2:	#####################################################	elapsed: 0.78s, reconstruction error: 6.32
# Epoch 3:	#####################################################	elapsed: 0.78s, reconstruction error: 5.60
# Epoch 4:	#####################################################	elapsed: 0.77s, reconstruction error: 5.09
# Epoch 5:	#####################################################	elapsed: 0.77s, reconstruction error: 4.60
# Epoch 6:	#####################################################	elapsed: 0.78s, reconstruction error: 4.22
# Epoch 7:	#####################################################	elapsed: 0.79s, reconstruction error: 3.93
# Epoch 8:	#####################################################	elapsed: 0.78s, reconstruction error: 3.82
# Epoch 9:	#####################################################	elapsed: 0.77s, reconstruction error: 3.69
# Epoch 10:	#####################################################	elapsed: 0.79s, reconstruction error: 3.53
# Epoch 11:	#####################################################	elapsed: 0.91s, reconstruction error: 3.46
# Epoch 12:	#####################################################	elapsed: 0.80s, reconstruction error: 3.41
# Epoch 13:	#####################################################	elapsed: 0.87s, reconstruction error: 3.39
# Epoch 14:	#####################################################	elapsed: 0.84s, reconstruction error: 3.29
# Epoch 15:	#####################################################	elapsed: 0.81s, reconstruction error: 3.32
# Epoch 16:	#####################################################	elapsed: 0.79s, reconstruction error: 3.23
# Epoch 17:	#####################################################	elapsed: 0.85s, reconstruction error: 3.29
# Epoch 18:	#####################################################	elapsed: 0.90s, reconstruction error: 3.08
# Epoch 19:	#####################################################	elapsed: 0.81s, reconstruction error: 3.20
# Epoch 20:	#####################################################	elapsed: 0.86s, reconstruction error: 3.10
# Epoch 21:	#####################################################	elapsed: 0.81s, reconstruction error: 3.12
# Epoch 22:	#####################################################	elapsed: 0.83s, reconstruction error: 3.05
# Epoch 23:	#####################################################	elapsed: 0.77s, reconstruction error: 3.05
# Epoch 24:	#####################################################	elapsed: 0.79s, reconstruction error: 3.06
# Epoch 25:	#####################################################	elapsed: 0.78s, reconstruction error: 3.07
# Epoch 26:	#####################################################	elapsed: 0.78s, reconstruction error: 2.92
# Epoch 27:	#####################################################	elapsed: 0.78s, reconstruction error: 2.92
# Epoch 28:	#####################################################	elapsed: 0.76s, reconstruction error: 2.97
# Epoch 29:	#####################################################	elapsed: 0.94s, reconstruction error: 2.96
# Epoch 30:	#####################################################	elapsed: 0.76s, reconstruction error: 2.95
# Epoch 31:	#####################################################	elapsed: 0.80s, reconstruction error: 2.87
# Epoch 32:	#####################################################	elapsed: 0.78s, reconstruction error: 2.92
# Epoch 33:	#####################################################	elapsed: 0.78s, reconstruction error: 3.01
# Epoch 34:	#####################################################	elapsed: 0.79s, reconstruction error: 2.93
# Epoch 35:	#####################################################	elapsed: 0.77s, reconstruction error: 3.00
# Epoch 36:	#####################################################	elapsed: 0.78s, reconstruction error: 2.89
# Epoch 37:	#####################################################	elapsed: 0.78s, reconstruction error: 2.94
# Epoch 38:	#####################################################	elapsed: 0.77s, reconstruction error: 2.95
# Epoch 39:	#####################################################	elapsed: 0.78s, reconstruction error: 2.92
# Epoch 40:	#####################################################	elapsed: 0.78s, reconstruction error: 2.85
# Epoch 41:	#####################################################	elapsed: 0.77s, reconstruction error: 2.82
# Epoch 42:	#####################################################	elapsed: 0.78s, reconstruction error: 2.76
# Epoch 43:	#####################################################	elapsed: 0.83s, reconstruction error: 2.92
# Epoch 44:	#####################################################	elapsed: 0.76s, reconstruction error: 2.83
# Epoch 45:	#####################################################	elapsed: 0.77s, reconstruction error: 2.89
# Epoch 46:	#####################################################	elapsed: 0.78s, reconstruction error: 2.87
# Epoch 47:	#####################################################	elapsed: 0.80s, reconstruction error: 2.77
# Epoch 48:	#####################################################	elapsed: 0.78s, reconstruction error: 2.87
# Epoch 49:	#####################################################	elapsed: 0.86s, reconstruction error: 2.81
# Training finished!

# %%
draw_layer_samples(dbn, 0, monitoring_set[:8*16])

# %%
draw_layer_samples(dbn, 1, monitoring_set[:8*16])

# %%
draw_layer_samples(dbn, 2, monitoring_set[:8*16])

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import mkl

mkl.set_num_threads(4)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def randn(*dims):
    return np.random.randn(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def as_matrix(vector):
    return np.reshape(vector, (-1, 1))

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

def draw_rbm_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)

def draw_layer_filters(layer):
    filters = np.reshape(layer.W[:-1].T, newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# ### Activation functions

# %%
def sigmoid(batch, stochastic=False):
    activations = 1.0 / (1.0 + np.exp(-batch))
    if stochastic:
        return activations > rand(*activations.shape).astype(np.float32)
    else:
        return activations

def sigmoid_derivative(batch):
    s = sigmoid(batch)
    return s * (1.0 - s)

def gaussian(batch, stochastic=False):
    if stochastic:
        return np.random.normal(loc=batch, scale=1)
    else:
        return batch

def gaussian_derivative(batch):
    return np.ones(batch.shape)

# %% [markdown]
# # MNIST dataset

# %%
import mnist
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # RBM & DBN training

# %%
class Rbm:
    def __init__(self, visible_size, hidden_size, visible_act_func, hidden_act_func, 
                 learning_rate, momentum, l2_penalty):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.visible_act_func = visible_act_func
        self.hidden_act_func = hidden_act_func
        
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.l2_penalty = l2_penalty
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.M = zeros(self.visible_size+1, self.hidden_size+1)

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]

    positive_visible = minibatch
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    z = minibatch @ rbm.W[:, :-1]
    positive_hidden[:, :-1] = rbm.hidden_act_func(z)
    negative_hidden[:, :-1] = rbm.hidden_act_func(z, stochastic=True)

    for cd_i in range(k):
        negative_visible[:, :-1] = rbm.visible_act_func(negative_hidden @ rbm.W[:-1, :].T,
                                                        stochastic=True)
        z = negative_visible @ rbm.W[:, :-1]
        if cd_i < (k - 1):
            negative_hidden[:, :-1] = rbm.hidden_act_func(z, stochastic=True)
        else:
            negative_hidden[:, :-1] = rbm.hidden_act_func(z)

    rbm.M *= rbm.momentum
    rbm.M += (rbm.learning_rate / observations_count) * positive_visible.T @ positive_hidden
    rbm.M -= (rbm.learning_rate / observations_count) * negative_visible.T @ negative_hidden

    if rbm.l2_penalty is not None:
        rbm.M[:-1, :-1] = rbm.M[:-1, :-1] - rbm.learning_rate * rbm.l2_penalty * rbm.W[:-1, :-1]

    rbm.W += rbm.M;
    
def reconstuction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    hidden[:, :-1] = rbm.hidden_act_func(minibatch @ rbm.W[:, :-1])
    hidden[:, :-1] = (hidden[:, :-1] > rand(observations_count, rbm.hidden_size))
    
    visible = rbm.visible_act_func(hidden @ np.transpose(rbm.W[:-1, :]))
    
    error = minibatch[:, :-1] - visible
    error = np.sum(np.square(error)) / observations_count
    
    return error

# %%
def propagate_up(dbn, layers_count, visible):
    for i in range(layers_count):
        visible = append_ones(dbn[i].visible_act_func(visible @ dbn[i].W[:, :-1]))
    return visible

def propagate_down(dbn, layers_count, hidden):
    for i in reversed(range(layers_count)):
        hidden = append_ones(dbn[i].hidden_act_func(hidden @ np.transpose(dbn[i].W[:-1, :])))
    return hidden

def dbn_reconstuction_error(dbn, layer_idx, minibatch):
    propagated = propagate_up(dbn, layer_idx, minibatch)
    error = reconstuction_error(dbn[layer_idx], propagated)
    return error

def train_dbn_layer(dbn, layer_idx, dataset, batch_size):
    dataset = propagate_up(dbn, layer_idx, dataset)
    
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(dbn[layer_idx], batch)
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")

def train_dbn(dbn, dataset, monitoring_set, batch_size, epochs_count):
    for layer_idx in range(len(dbn)):
        print("\nLearning layer {}".format(layer_idx))
        
        for epoch in range(epochs_count):
            print("Epoch {}:".format(epoch+1),  end="\t")

            if epoch == 5:
                dbn[layer_idx].momentum = 0.9

            start_time = time.time()
            train_dbn_layer(dbn, layer_idx, dataset, batch_size)
            elapsed = time.time() - start_time

            error = dbn_reconstuction_error(dbn, layer_idx, monitoring_set)
            print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

# %% [markdown]
# # Part 1. Autoencoder training with Nesterov accelerated gradient descend

# %%
class Layer:
    def __init__(self, visible_size, hidden_size, activation_fun, d_activation_fun, 
                 learning_rate, momentum, l2_penalty):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.activation_fun = activation_fun
        self.d_activation_fun = d_activation_fun
                
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.l2_penalty = l2_penalty
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size)).astype(np.float32)
        self.W[-1, :] = 0.0
        
        self.activations = None
        self.d_activations = None
        self.deltas = None

        self.M = zeros(self.visible_size+1, self.hidden_size)

# %% [markdown]
# ## Error backpropagation with Nesterov accelerated gradient descend
#
# __Forward pass.__ When ```compute_derivatives == false```, we are not training the network but use it to make predictions. In this case we cannot use weights in ```layer.W``` directly: in Nesterov method weights in this matrix are shifted along the direction of momentum (that is, they are at the point in the weight space where the gradient is calculated). We need to account for this when calculating the total input to the next layer.

# %%
def forward_pass(ae, batch, compute_derivatives):
    visible = batch
    
    for layer_idx, layer in enumerate(ae):
        if not compute_derivatives:
            # We are using the network to make predictions. Fix evaluation of the total
            # input to the next layer (z) so that it uses the correct weights, and not
            # the weights where the gradient is calculated.
            
            z = visible @ (layer.W - layer.momentum * layer.M)
        else:
            z = visible @ layer.W
            
        layer.activations = append_ones(layer.activation_fun(z))
        
        if compute_derivatives and (layer_idx < len(ae) - 1):
            layer.d_activations = layer.d_activation_fun(z)
            
        visible = layer.activations

    return visible[:, :-1]

# %% [markdown]
# __Backward pass.__ Implement Nesterov updates in the backward pass of error backpropagation.
#
# Remember that the weights in ```layer.W``` are shifted along the direction of momentum. Before we change the momentum matrix (but after we have everything needed to calculate the gradient), we must fix (i.e. _un-shift_) these weights.
#
# At the end of the backward pass, we must update the weight matrix accoring to the momentum interpretation of the Nesterov method.

# %%
def error_backpropagate(ae, batch):
    observations_count = batch.shape[0]

    for layer_idx, layer in reversed(list(enumerate(ae))):
        if layer_idx > 0:
            prev_layer = ae[layer_idx - 1]
            visible = prev_layer.activations
            
            prev_layer.deltas = (layer.deltas @ layer.W[:-1, :].T) * prev_layer.d_activations
        else:
            visible = batch
        
        # Fix weights in layer.W before changing the momentum matrix
        layer.W -= layer.momentum * layer.M
        
        layer.M *= layer.momentum
        layer.M -= (layer.learning_rate / observations_count) * (visible.T @ layer.deltas)
        
        if layer.l2_penalty > 0:
            layer.M[:-1, :] = layer.M[:-1, :] - layer.learning_rate * layer.l2_penalty * layer.W[:-1, :]
        
        # Update the weight matrix accoring to the momentum interpretation of the Nesterov method.
        layer.W += layer.M + layer.momentum * layer.M

# %% [markdown]
# ### Cross entropy cost

# %%
def xentropy(batch, reconstructions):
    observations_count = batch.shape[0]
    return np.sum(-np.sum(batch*np.log(reconstructions) + (1-batch) * np.log(1 - reconstructions), axis=1), axis=0) / observations_count

# %% [markdown]
# ### Training procedure

# %%
def train_ae(ae, dataset, batch_size): # implemented
    batches_limit = dataset.shape[0] / batch_size
    batched_data = chunks(dataset, batch_size)
    
    for batch_idx, batch in enumerate(batched_data):
        reconstructions = forward_pass(ae, batch, True)
        
        ae[-1].deltas = reconstructions - batch[:, :-1]
        
        error_backpropagate(ae, batch)
        
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")

# %%
def run_ae_training(ae, train_set, validation_set, batch_size, epochs_count):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch+1),  end="\t")
        
        if epoch == 10:
            for layer in ae:
                layer.momentum = 0.95
        elif epoch == 15:
            for layer in ae:
                layer.momentum = 0.97
        elif epoch == 20:
            for layer in ae:
                layer.momentum = 0.98
        elif epoch == 25:
            for layer in ae:
                layer.momentum = 0.99
        
        start_time = time.time()
        train_ae(ae, train_set, batch_size)
        elapsed = time.time() - start_time

        xe = xentropy(validation_set[:, :-1], forward_pass(ae, validation_set, False))
        print("\telapsed: {0:>2.2f}s, cross-entropy: {1:>2.2f}".format(elapsed, xe))

    print("Training finished!")

# %% [markdown]
# ###  Initializing AE with DBN weights

# %%
def initialize_ae(ae, dbn):
    assert(len(ae) == 2*len(dbn))
    for layer_idx, layer in enumerate(dbn):
        ae[layer_idx].W = np.copy(dbn[layer_idx].W[:, :-1])
        ae[len(ae) - 1 - layer_idx].W = np.copy(dbn[layer_idx].W[:-1, :].T)

# %% [markdown]
# ## Autoencoder for MNIST digits

# %%
DATASET_SIZE = 10000 # 60000 for whole dataset
DIGIT_SIZE = 28

##### Train set #####

mnist_train_images = mnist.train_images().astype(np.float32) / 255.0
mnist_train_images = np.random.permutation(mnist_train_images)

mnist_train_images = np.reshape(mnist_train_images[:DATASET_SIZE],
                                newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
mnist_train_images = append_ones(mnist_train_images)

monitoring_set_indeces = np.random.choice(mnist_train_images.shape[0], 512, replace=False)
monitoring_set = mnist_train_images[monitoring_set_indeces]

##### Test set #####

mnist_test_images = mnist.test_images().astype(np.float32) / 255.0
mnist_test_images = np.reshape(mnist_test_images, newshape=(-1, DIGIT_SIZE*DIGIT_SIZE))
mnist_test_images = append_ones(mnist_test_images)

# %%
VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE

BATCH_SIZE = 128
EPOCHS_COUNT = 50

RBM_LEARNING_RATE = 0.1
AE_LEARNING_RATE = 0.01
AE_MOMENTUM = 0.9
L2_PENALTY = 0.0002

# %%
from IPython.core.display import HTML

def compare_results(ae, dbn,
                    train_set, validation_set, monitoring_set,
                    batch_size, epochs_count):
    for layer in ae:
        layer.reset()
    
    display(HTML('<h3>DBN training</h3>'))
    train_dbn(dbn, train_set, monitoring_set, batch_size, epochs_count)
    
    initialize_ae(ae, dbn)
    dbn_reconstructions = np.reshape(forward_pass(ae, validation_set[:8*24, :], False),
                                     newshape=(8, 24, 28, 28))
    dbn_rec_cost = xentropy(validation_set[:, :-1],
                            forward_pass(ae, validation_set, False))
    
    display(HTML('<h3>Finetuning pretrained AE</h3>'))
    
    print("Reconstruction cost before finetuning: {0:>2.2f}\n".format(dbn_rec_cost))
    run_ae_training(ae, train_set, validation_set,
                    batch_size, epochs_count)
    
    display(HTML('<h3>Input minibatch</h3>'))
    tiles(np.reshape(validation_set[:8*24, :-1],
                     newshape=(8, 24, 28, 28)))
    
    display(HTML('<h3>Pretrained AE reconstructions</h3>'))
    tiles(dbn_reconstructions)
    
    display(HTML('<h3>Finetuned AE reconstructions</h3>'))
    ae_reconstructions = np.reshape(forward_pass(ae, validation_set[:8*24], False),
                                    newshape=(8, 24, 28, 28))
    tiles(ae_reconstructions)

# %% [markdown]
# ###  Autoencoder network
#
# Define the autoencoder network for MNIST digits. The network structure should be suitable for pretraining with the provided DBN.

# %%
dbn = [
    Rbm(VISIBLE_LAYER_SIZE, 256, sigmoid, sigmoid, RBM_LEARNING_RATE, 0.5, L2_PENALTY),
    Rbm(256, 128, sigmoid, sigmoid, RBM_LEARNING_RATE, 0.5, L2_PENALTY),
    Rbm(128, 64, sigmoid, sigmoid, RBM_LEARNING_RATE, 0.5, L2_PENALTY),
    Rbm(64, 10, sigmoid, gaussian, RBM_LEARNING_RATE / 10.0, 0.5, L2_PENALTY)
]

ae =  [
    Layer(VISIBLE_LAYER_SIZE, 256, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY),
    Layer(256, 128, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY),
    Layer(128, 64, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY),
    Layer(64, 10, gaussian, gaussian_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY),
    Layer(10, 64, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY),
    Layer(64, 128, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY),
    Layer(128, 256, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY),
    Layer(256, VISIBLE_LAYER_SIZE, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY),
]

compare_results(ae, dbn,
                mnist_train_images, mnist_test_images,
                monitoring_set,
                BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>DBN training</h3>
# Learning layer 0
# Epoch 1:	########################################	elapsed: 0.84s, reconstruction error: 31.70
# Epoch 2:	########################################	elapsed: 0.79s, reconstruction error: 24.74
# Epoch 3:	########################################	elapsed: 0.78s, reconstruction error: 21.28
# Epoch 4:	########################################	elapsed: 0.81s, reconstruction error: 18.98
# Epoch 5:	########################################	elapsed: 0.78s, reconstruction error: 17.62
# Epoch 6:	########################################	elapsed: 0.80s, reconstruction error: 15.32
# Epoch 7:	########################################	elapsed: 0.78s, reconstruction error: 13.76
# Epoch 8:	########################################	elapsed: 0.78s, reconstruction error: 12.70
# Epoch 9:	########################################	elapsed: 0.78s, reconstruction error: 12.05
# Epoch 10:	########################################	elapsed: 0.82s, reconstruction error: 11.67
# Epoch 11:	########################################	elapsed: 0.83s, reconstruction error: 11.05
# Epoch 12:	########################################	elapsed: 0.82s, reconstruction error: 10.74
# Epoch 13:	########################################	elapsed: 0.82s, reconstruction error: 10.69
# Epoch 14:	########################################	elapsed: 0.82s, reconstruction error: 10.61
# Epoch 15:	########################################	elapsed: 0.83s, reconstruction error: 10.41
# Epoch 16:	########################################	elapsed: 0.85s, reconstruction error: 10.12
# Epoch 17:	########################################	elapsed: 0.85s, reconstruction error: 9.98
# Epoch 18:	########################################	elapsed: 0.83s, reconstruction error: 9.81
# Epoch 19:	########################################	elapsed: 0.84s, reconstruction error: 9.78
# Epoch 20:	########################################	elapsed: 0.88s, reconstruction error: 9.91
# Epoch 21:	########################################	elapsed: 0.91s, reconstruction error: 9.73
# Epoch 22:	########################################	elapsed: 0.84s, reconstruction error: 9.61
# Epoch 23:	########################################	elapsed: 0.82s, reconstruction error: 9.54
# Epoch 24:	########################################	elapsed: 0.81s, reconstruction error: 9.48
# Epoch 25:	########################################	elapsed: 0.82s, reconstruction error: 9.34
# Epoch 26:	########################################	elapsed: 0.82s, reconstruction error: 9.24
# Epoch 27:	########################################	elapsed: 0.87s, reconstruction error: 9.27
# Epoch 28:	########################################	elapsed: 0.85s, reconstruction error: 9.31
# Epoch 29:	########################################	elapsed: 0.80s, reconstruction error: 9.22
# Epoch 30:	########################################	elapsed: 0.78s, reconstruction error: 9.38
# Epoch 31:	########################################	elapsed: 0.79s, reconstruction error: 9.23
# Epoch 32:	########################################	elapsed: 0.80s, reconstruction error: 8.92
# Epoch 33:	########################################	elapsed: 0.80s, reconstruction error: 9.02
# Epoch 34:	########################################	elapsed: 0.92s, reconstruction error: 9.04
# Epoch 35:	########################################	elapsed: 0.80s, reconstruction error: 8.93
# Epoch 36:	########################################	elapsed: 0.79s, reconstruction error: 8.92
# Epoch 37:	########################################	elapsed: 0.99s, reconstruction error: 8.89
# Epoch 38:	########################################	elapsed: 0.85s, reconstruction error: 8.82
# Epoch 39:	########################################	elapsed: 0.84s, reconstruction error: 8.95
# Epoch 40:	########################################	elapsed: 0.85s, reconstruction error: 8.82
# Epoch 41:	########################################	elapsed: 0.84s, reconstruction error: 8.74
# Epoch 42:	########################################	elapsed: 0.85s, reconstruction error: 8.83
# Epoch 43:	########################################	elapsed: 0.83s, reconstruction error: 8.83
# Epoch 44:	########################################	elapsed: 0.82s, reconstruction error: 8.91
# Epoch 45:	########################################	elapsed: 0.83s, reconstruction error: 8.85
# Epoch 46:	########################################	elapsed: 0.83s, reconstruction error: 8.70
# Epoch 47:	########################################	elapsed: 0.83s, reconstruction error: 8.68
# Epoch 48:	########################################	elapsed: 0.79s, reconstruction error: 8.85
# Epoch 49:	########################################	elapsed: 0.78s, reconstruction error: 8.68
# Epoch 50:	########################################	elapsed: 0.77s, reconstruction error: 8.84
#
# Learning layer 1
# Epoch 1:	########################################	elapsed: 0.39s, reconstruction error: 20.58
# Epoch 2:	########################################	elapsed: 0.37s, reconstruction error: 15.80
# Epoch 3:	########################################	elapsed: 0.37s, reconstruction error: 13.76
# Epoch 4:	########################################	elapsed: 0.37s, reconstruction error: 12.34
# Epoch 5:	########################################	elapsed: 0.37s, reconstruction error: 11.32
# Epoch 6:	########################################	elapsed: 0.37s, reconstruction error: 9.48
# Epoch 7:	########################################	elapsed: 0.37s, reconstruction error: 8.23
# Epoch 8:	########################################	elapsed: 0.44s, reconstruction error: 7.65
# Epoch 9:	########################################	elapsed: 0.36s, reconstruction error: 7.17
# Epoch 10:	########################################	elapsed: 0.37s, reconstruction error: 6.98
# Epoch 11:	########################################	elapsed: 0.36s, reconstruction error: 6.74
# Epoch 12:	########################################	elapsed: 0.39s, reconstruction error: 6.42
# Epoch 13:	########################################	elapsed: 0.38s, reconstruction error: 6.33
# Epoch 14:	########################################	elapsed: 0.37s, reconstruction error: 6.17
# Epoch 15:	########################################	elapsed: 0.39s, reconstruction error: 5.95
# Epoch 16:	########################################	elapsed: 0.40s, reconstruction error: 5.90
# Epoch 17:	########################################	elapsed: 0.38s, reconstruction error: 5.91
# Epoch 18:	########################################	elapsed: 0.39s, reconstruction error: 5.82
# Epoch 19:	########################################	elapsed: 0.37s, reconstruction error: 5.75
# Epoch 20:	########################################	elapsed: 0.35s, reconstruction error: 5.67
# Epoch 21:	########################################	elapsed: 0.37s, reconstruction error: 5.53
# Epoch 22:	########################################	elapsed: 0.35s, reconstruction error: 5.59
# Epoch 23:	########################################	elapsed: 0.36s, reconstruction error: 5.50
# Epoch 24:	########################################	elapsed: 0.36s, reconstruction error: 5.45
# Epoch 25:	########################################	elapsed: 0.37s, reconstruction error: 5.41
# Epoch 26:	########################################	elapsed: 0.39s, reconstruction error: 5.42
# Epoch 27:	########################################	elapsed: 0.36s, reconstruction error: 5.44
# Epoch 28:	########################################	elapsed: 0.37s, reconstruction error: 5.41
# Epoch 29:	########################################	elapsed: 0.39s, reconstruction error: 5.29
# Epoch 30:	########################################	elapsed: 0.37s, reconstruction error: 5.28
# Epoch 31:	########################################	elapsed: 0.37s, reconstruction error: 5.28
# Epoch 32:	########################################	elapsed: 0.41s, reconstruction error: 5.25
# Epoch 33:	########################################	elapsed: 0.36s, reconstruction error: 5.21
# Epoch 34:	########################################	elapsed: 0.36s, reconstruction error: 5.15
# Epoch 35:	########################################	elapsed: 0.38s, reconstruction error: 5.13
# Epoch 36:	########################################	elapsed: 0.36s, reconstruction error: 5.14
# Epoch 37:	########################################	elapsed: 0.36s, reconstruction error: 5.10
# Epoch 38:	########################################	elapsed: 0.36s, reconstruction error: 5.10
# Epoch 39:	########################################	elapsed: 0.36s, reconstruction error: 5.14
# Epoch 40:	########################################	elapsed: 0.36s, reconstruction error: 5.15
# Epoch 41:	########################################	elapsed: 0.35s, reconstruction error: 5.13
# Epoch 42:	########################################	elapsed: 0.36s, reconstruction error: 5.10
# Epoch 43:	########################################	elapsed: 0.36s, reconstruction error: 5.04
# Epoch 44:	########################################	elapsed: 0.35s, reconstruction error: 5.00
# Epoch 45:	########################################	elapsed: 0.35s, reconstruction error: 5.12
# Epoch 46:	########################################	elapsed: 0.35s, reconstruction error: 5.10
# Epoch 47:	########################################	elapsed: 0.35s, reconstruction error: 5.08
# Epoch 48:	########################################	elapsed: 0.36s, reconstruction error: 5.03
# Epoch 49:	########################################	elapsed: 0.35s, reconstruction error: 5.07
# Epoch 50:	########################################	elapsed: 0.35s, reconstruction error: 5.15
#
# Learning layer 2
# Epoch 1:	########################################	elapsed: 0.27s, reconstruction error: 14.03
# Epoch 2:	########################################	elapsed: 0.31s, reconstruction error: 10.61
# Epoch 3:	########################################	elapsed: 0.29s, reconstruction error: 9.17
# Epoch 4:	########################################	elapsed: 0.27s, reconstruction error: 8.21
# Epoch 5:	########################################	elapsed: 0.28s, reconstruction error: 7.51
# Epoch 6:	########################################	elapsed: 0.27s, reconstruction error: 6.24
# Epoch 7:	########################################	elapsed: 0.27s, reconstruction error: 5.49
# Epoch 8:	########################################	elapsed: 0.30s, reconstruction error: 5.17
# Epoch 9:	########################################	elapsed: 0.26s, reconstruction error: 4.81
# Epoch 10:	########################################	elapsed: 0.26s, reconstruction error: 4.71
# Epoch 11:	########################################	elapsed: 0.28s, reconstruction error: 4.56
# Epoch 12:	########################################	elapsed: 0.27s, reconstruction error: 4.47
# Epoch 13:	########################################	elapsed: 0.27s, reconstruction error: 4.46
# Epoch 14:	########################################	elapsed: 0.28s, reconstruction error: 4.31
# Epoch 15:	########################################	elapsed: 0.27s, reconstruction error: 4.28
# Epoch 16:	########################################	elapsed: 0.27s, reconstruction error: 4.19
# Epoch 17:	########################################	elapsed: 0.27s, reconstruction error: 4.11
# Epoch 18:	########################################	elapsed: 0.27s, reconstruction error: 4.10
# Epoch 19:	########################################	elapsed: 0.27s, reconstruction error: 4.08
# Epoch 20:	########################################	elapsed: 0.28s, reconstruction error: 4.06
# Epoch 21:	########################################	elapsed: 0.27s, reconstruction error: 4.04
# Epoch 22:	########################################	elapsed: 0.27s, reconstruction error: 3.95
# Epoch 23:	########################################	elapsed: 0.27s, reconstruction error: 4.01
# Epoch 24:	########################################	elapsed: 0.28s, reconstruction error: 4.02
# Epoch 25:	########################################	elapsed: 0.27s, reconstruction error: 3.92
# Epoch 26:	########################################	elapsed: 0.27s, reconstruction error: 3.97
# Epoch 27:	########################################	elapsed: 0.27s, reconstruction error: 3.89
# Epoch 28:	########################################	elapsed: 0.28s, reconstruction error: 3.94
# Epoch 29:	########################################	elapsed: 0.28s, reconstruction error: 3.92
# Epoch 30:	########################################	elapsed: 0.27s, reconstruction error: 3.89
# Epoch 31:	########################################	elapsed: 0.27s, reconstruction error: 3.93
# Epoch 32:	########################################	elapsed: 0.27s, reconstruction error: 3.88
# Epoch 33:	########################################	elapsed: 0.27s, reconstruction error: 3.88
# Epoch 34:	########################################	elapsed: 0.27s, reconstruction error: 3.87
# Epoch 35:	########################################	elapsed: 0.27s, reconstruction error: 3.87
# Epoch 36:	########################################	elapsed: 0.28s, reconstruction error: 3.85
# Epoch 37:	########################################	elapsed: 0.28s, reconstruction error: 3.87
# Epoch 38:	########################################	elapsed: 0.28s, reconstruction error: 3.83
# Epoch 39:	########################################	elapsed: 0.27s, reconstruction error: 3.83
# Epoch 40:	########################################	elapsed: 0.28s, reconstruction error: 3.76
# Epoch 41:	########################################	elapsed: 0.28s, reconstruction error: 3.79
# Epoch 42:	########################################	elapsed: 0.28s, reconstruction error: 3.85
# Epoch 43:	########################################	elapsed: 0.32s, reconstruction error: 3.75
# Epoch 44:	########################################	elapsed: 0.31s, reconstruction error: 3.71
# Epoch 45:	########################################	elapsed: 0.28s, reconstruction error: 3.76
# Epoch 46:	########################################	elapsed: 0.27s, reconstruction error: 3.84
# Epoch 47:	########################################	elapsed: 0.28s, reconstruction error: 3.83
# Epoch 48:	########################################	elapsed: 0.27s, reconstruction error: 3.77
# Epoch 49:	########################################	elapsed: 0.27s, reconstruction error: 3.75
# Epoch 50:	########################################	elapsed: 0.28s, reconstruction error: 3.79
#
# Learning layer 3
# Epoch 1:	########################################	elapsed: 0.20s, reconstruction error: 11.47
# Epoch 2:	########################################	elapsed: 0.20s, reconstruction error: 10.00
# Epoch 3:	########################################	elapsed: 0.20s, reconstruction error: 9.11
# Epoch 4:	########################################	elapsed: 0.20s, reconstruction error: 8.77
# Epoch 5:	########################################	elapsed: 0.20s, reconstruction error: 8.59
# Epoch 6:	########################################	elapsed: 0.21s, reconstruction error: 8.49
# Epoch 7:	########################################	elapsed: 0.20s, reconstruction error: 8.67
# Epoch 8:	########################################	elapsed: 0.20s, reconstruction error: 8.84
# Epoch 9:	########################################	elapsed: 0.20s, reconstruction error: 9.03
# Epoch 10:	########################################	elapsed: 0.20s, reconstruction error: 9.14
# Epoch 11:	########################################	elapsed: 0.20s, reconstruction error: 9.28
# Epoch 12:	########################################	elapsed: 0.20s, reconstruction error: 9.37
# Epoch 13:	########################################	elapsed: 0.20s, reconstruction error: 9.44
# Epoch 14:	########################################	elapsed: 0.20s, reconstruction error: 9.52
# Epoch 15:	########################################	elapsed: 0.20s, reconstruction error: 9.54
# Epoch 16:	########################################	elapsed: 0.20s, reconstruction error: 9.60
# Epoch 17:	########################################	elapsed: 0.20s, reconstruction error: 9.64
# Epoch 18:	########################################	elapsed: 0.20s, reconstruction error: 9.68
# Epoch 19:	########################################	elapsed: 0.20s, reconstruction error: 9.67
# Epoch 20:	########################################	elapsed: 0.20s, reconstruction error: 9.72
# Epoch 21:	########################################	elapsed: 0.20s, reconstruction error: 9.74
# Epoch 22:	########################################	elapsed: 0.20s, reconstruction error: 9.77
# Epoch 23:	########################################	elapsed: 0.20s, reconstruction error: 9.76
# Epoch 24:	########################################	elapsed: 0.20s, reconstruction error: 9.80
# Epoch 25:	########################################	elapsed: 0.20s, reconstruction error: 9.82
# Epoch 26:	########################################	elapsed: 0.20s, reconstruction error: 9.82
# Epoch 27:	########################################	elapsed: 0.20s, reconstruction error: 9.84
# Epoch 28:	########################################	elapsed: 0.20s, reconstruction error: 9.84
# Epoch 29:	########################################	elapsed: 0.20s, reconstruction error: 9.89
# Epoch 30:	########################################	elapsed: 0.20s, reconstruction error: 9.86
# Epoch 31:	########################################	elapsed: 0.20s, reconstruction error: 9.89
# Epoch 32:	########################################	elapsed: 0.21s, reconstruction error: 9.91
# Epoch 33:	########################################	elapsed: 0.20s, reconstruction error: 9.90
# Epoch 34:	########################################	elapsed: 0.20s, reconstruction error: 9.93
# Epoch 35:	########################################	elapsed: 0.20s, reconstruction error: 9.96
# Epoch 36:	########################################	elapsed: 0.20s, reconstruction error: 9.95
# Epoch 37:	########################################	elapsed: 0.21s, reconstruction error: 9.94
# Epoch 38:	########################################	elapsed: 0.20s, reconstruction error: 10.00
# Epoch 39:	########################################	elapsed: 0.20s, reconstruction error: 9.98
# Epoch 40:	########################################	elapsed: 0.21s, reconstruction error: 10.02
# Epoch 41:	########################################	elapsed: 0.60s, reconstruction error: 10.01
# Epoch 42:	########################################	elapsed: 0.20s, reconstruction error: 10.04
# Epoch 43:	########################################	elapsed: 0.23s, reconstruction error: 10.04
# Epoch 44:	########################################	elapsed: 0.21s, reconstruction error: 10.06
# Epoch 45:	########################################	elapsed: 0.32s, reconstruction error: 10.02
# Epoch 46:	########################################	elapsed: 0.20s, reconstruction error: 10.04
# Epoch 47:	########################################	elapsed: 0.20s, reconstruction error: 10.02
# Epoch 48:	########################################	elapsed: 0.20s, reconstruction error: 10.05
# Epoch 49:	########################################	elapsed: 0.23s, reconstruction error: 10.07
# Epoch 50:	########################################	elapsed: 0.59s, reconstruction error: 10.06
# <h3>Finetuning pretrained AE</h3>
# Reconstruction cost before finetuning: 139.18
#
# Epoch 1:	########################################	elapsed: 1.93s, cross-entropy: 106.19
# Epoch 2:	########################################	elapsed: 1.78s, cross-entropy: 102.84
# Epoch 3:	########################################	elapsed: 1.81s, cross-entropy: 100.92
# Epoch 4:	########################################	elapsed: 1.82s, cross-entropy: 99.51
# Epoch 5:	########################################	elapsed: 1.79s, cross-entropy: 98.33
# Epoch 6:	########################################	elapsed: 1.76s, cross-entropy: 97.35
# Epoch 7:	########################################	elapsed: 1.78s, cross-entropy: 96.53
# Epoch 8:	########################################	elapsed: 1.81s, cross-entropy: 95.84
# Epoch 9:	########################################	elapsed: 1.78s, cross-entropy: 95.24
# Epoch 10:	########################################	elapsed: 1.73s, cross-entropy: 94.72
# Epoch 11:	########################################	elapsed: 1.74s, cross-entropy: 94.50
# Epoch 12:	########################################	elapsed: 1.75s, cross-entropy: 93.80
# Epoch 13:	########################################	elapsed: 1.85s, cross-entropy: 93.14
# Epoch 14:	########################################	elapsed: 1.92s, cross-entropy: 92.76
# Epoch 15:	########################################	elapsed: 1.90s, cross-entropy: 92.27
# Epoch 16:	########################################	elapsed: 1.74s, cross-entropy: 92.36
# Epoch 17:	########################################	elapsed: 1.57s, cross-entropy: 91.93
# Epoch 18:	########################################	elapsed: 1.96s, cross-entropy: 91.70
# Epoch 19:	########################################	elapsed: 1.73s, cross-entropy: 91.28
# Epoch 20:	########################################	elapsed: 1.79s, cross-entropy: 91.00
# Epoch 21:	########################################	elapsed: 1.79s, cross-entropy: 91.52
# Epoch 22:	########################################	elapsed: 1.78s, cross-entropy: 91.83
# Epoch 23:	########################################	elapsed: 1.76s, cross-entropy: 91.42
# Epoch 24:	########################################	elapsed: 1.79s, cross-entropy: 91.73
# Epoch 25:	########################################	elapsed: 2.12s, cross-entropy: 91.74
# Epoch 26:	########################################	elapsed: 1.78s, cross-entropy: 93.13
# Epoch 27:	########################################	elapsed: 1.78s, cross-entropy: 94.44
# Epoch 28:	########################################	elapsed: 1.78s, cross-entropy: 95.09
# Epoch 29:	########################################	elapsed: 1.84s, cross-entropy: 94.00
# Epoch 30:	########################################	elapsed: 2.20s, cross-entropy: 93.13
# Epoch 31:	########################################	elapsed: 1.81s, cross-entropy: 93.17
# Epoch 32:	########################################	elapsed: 1.80s, cross-entropy: 92.22
# Epoch 33:	########################################	elapsed: 1.78s, cross-entropy: 91.46
# Epoch 34:	########################################	elapsed: 1.79s, cross-entropy: 92.01
# Epoch 35:	########################################	elapsed: 1.75s, cross-entropy: 90.50
# Epoch 36:	########################################	elapsed: 1.68s, cross-entropy: 90.55
# Epoch 37:	########################################	elapsed: 1.82s, cross-entropy: 89.96
# Epoch 38:	########################################	elapsed: 1.82s, cross-entropy: 89.75
# Epoch 39:	########################################	elapsed: 1.74s, cross-entropy: 89.21
# Epoch 40:	########################################	elapsed: 1.76s, cross-entropy: 88.33
# Epoch 41:	########################################	elapsed: 1.72s, cross-entropy: 88.72
# Epoch 42:	########################################	elapsed: 1.81s, cross-entropy: 88.05
# Epoch 43:	########################################	elapsed: 1.82s, cross-entropy: 88.03
# Epoch 44:	########################################	elapsed: 1.82s, cross-entropy: 88.21
# Epoch 45:	########################################	elapsed: 2.00s, cross-entropy: 88.05
# Epoch 46:	########################################	elapsed: 1.83s, cross-entropy: 87.72
# Epoch 47:	########################################	elapsed: 1.85s, cross-entropy: 87.54
# Epoch 48:	########################################	elapsed: 1.85s, cross-entropy: 87.66
# Epoch 49:	########################################	elapsed: 1.82s, cross-entropy: 87.37
# Epoch 50:	########################################	elapsed: 2.15s, cross-entropy: 87.55
# Training finished!
# <h3>Input minibatch</h3>
# <h3>Pretrained AE reconstructions</h3>
# <h3>Finetuned AE reconstructions</h3>

# %% [markdown]
# # Part 2. Visualization of MNIST digits with an autoencoder

# %%
def run_2d_ae_training(ae, train_set, validation_set, batch_size, epochs_count):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch+1),  end="\t")
        
        if epoch == 10:
            for layer in ae:
                layer.momentum = 0.8
        elif epoch == 30:
            for layer in ae:
                layer.momentum = 0.9
        
        start_time = time.time()
        train_ae(ae, train_set, batch_size)
        elapsed = time.time() - start_time

        xe = xentropy(validation_set[:, :-1], forward_pass(ae, validation_set, False))
        print("\telapsed: {0:>2.2f}s, cross-entropy: {1:>2.2f}".format(elapsed, xe))

    print("Training finished!")

# %%
def plot_2d_mnist_scatter(X, y):
    fig, plot = plt.subplots()
    fig.set_size_inches(16, 16)
    plt.prism()

    for i in range(10):
        digit_indeces = y == i
        dim1 = X[digit_indeces, 0]
        dim2 = X[digit_indeces, 1]
        plot.scatter(dim1, dim2, label=str(i))

    plot.set_xticks(())
    plot.set_yticks(())

    plt.tight_layout()
    plt.legend()
    plt.show()

# %%
from IPython.core.display import HTML

def compare_2d_visualizations(ae, dbn,
                              train_set, validation_set, validation_labels, monitoring_set,
                              batch_size, epochs_count):
    for layer in ae:
        layer.reset()
    
    display(HTML('<h3>DBN training</h3>'))
    train_dbn(dbn, train_set, monitoring_set, batch_size, epochs_count)
    
    initialize_ae(ae, dbn)
    dbn_rec_cost = xentropy(validation_set[:, :-1],
                            forward_pass(ae, validation_set, False))
    
    _ = forward_pass(ae, validation_set, False)
    dbn_codes = ae[3].activations[:, :-1]
    
    display(HTML('<h3>Finetuning pretrained AE</h3>'))
    
    print("Reconstruction cost before finetuning: {0:>2.2f}\n".format(dbn_rec_cost))
    run_2d_ae_training(ae, train_set, validation_set,
                       batch_size, epochs_count)
    
    _ = forward_pass(ae, validation_set, False)
    ae_codes = ae[3].activations[:, :-1]
    
    display(HTML('<h3>2D codes from the pretrained AE</h3>'))
    plot_2d_mnist_scatter(dbn_codes, validation_labels)
    
    display(HTML('<h3>2D codes from the finetuned AE</h3>'))
    plot_2d_mnist_scatter(ae_codes, validation_labels)

# %%
DATASET_SIZE = 20000 # 60000 for whole dataset
DIGIT_SIZE = 28

##### Train set #####

mnist_train_images = mnist.train_images().astype(np.float32) / 255.0
mnist_train_images = np.random.permutation(mnist_train_images)

mnist_train_images = np.reshape(mnist_train_images[:DATASET_SIZE],
                                newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
mnist_train_images = append_ones(mnist_train_images)

monitoring_set_indeces = np.random.choice(mnist_train_images.shape[0], 512, replace=False)
monitoring_set = mnist_train_images[monitoring_set_indeces]

##### Test set #####

mnist_test_images = mnist.test_images().astype(np.float32) / 255.0
mnist_test_images = np.reshape(mnist_test_images, newshape=(-1, DIGIT_SIZE*DIGIT_SIZE))
mnist_test_images = append_ones(mnist_test_images)
mnist_test_labels = mnist.test_labels()

# %%
VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE

BATCH_SIZE = 128
EPOCHS_COUNT = 50

RBM_LEARNING_RATE = 0.1
AE_LEARNING_RATE = 0.01
AE_MOMENTUM = 0.5
L2_PENALTY = 0.0002

# %% [markdown]
# ###  Autoencoder network for 2D visualization
#
# Define the autoencoder network for MNIST digits. Use the network structure from the previous part, but change the size of the coding layer to 2 neurons.

# %%
dbn = [
    Rbm(VISIBLE_LAYER_SIZE, 256, sigmoid, sigmoid, RBM_LEARNING_RATE, 0.5, L2_PENALTY),
    Rbm(256, 128, sigmoid, sigmoid, RBM_LEARNING_RATE, 0.5, L2_PENALTY),
    Rbm(128, 64, sigmoid, sigmoid, RBM_LEARNING_RATE, 0.5, L2_PENALTY),
    Rbm(64, 2, sigmoid, gaussian, RBM_LEARNING_RATE / 10.0, 0.5, L2_PENALTY)
]

ae =  [
    Layer(VISIBLE_LAYER_SIZE, 256, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY),
    Layer(256, 128, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY),
    Layer(128, 64, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY),
    Layer(64, 2, gaussian, gaussian_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY),
    Layer(2, 64, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY),
    Layer(64, 128, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY),
    Layer(128, 256, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY),
    Layer(256, VISIBLE_LAYER_SIZE, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY),
]

compare_2d_visualizations(ae, dbn,
                mnist_train_images, mnist_test_images, mnist_test_labels,
                monitoring_set,
                BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>DBN training</h3>
# Learning layer 0
# Epoch 1:	########################################	elapsed: 1.65s, reconstruction error: 23.18
# Epoch 2:	########################################	elapsed: 1.69s, reconstruction error: 17.73
# Epoch 3:	########################################	elapsed: 1.56s, reconstruction error: 15.46
# Epoch 4:	########################################	elapsed: 1.56s, reconstruction error: 13.86
# Epoch 5:	########################################	elapsed: 1.54s, reconstruction error: 13.00
# Epoch 6:	########################################	elapsed: 1.52s, reconstruction error: 11.90
# Epoch 7:	########################################	elapsed: 1.53s, reconstruction error: 10.81
# Epoch 8:	########################################	elapsed: 1.55s, reconstruction error: 10.50
# Epoch 9:	########################################	elapsed: 1.61s, reconstruction error: 10.04
# Epoch 10:	########################################	elapsed: 1.65s, reconstruction error: 10.01
# Epoch 11:	########################################	elapsed: 1.68s, reconstruction error: 9.46
# Epoch 12:	########################################	elapsed: 1.56s, reconstruction error: 9.44
# Epoch 13:	########################################	elapsed: 1.56s, reconstruction error: 9.19
# Epoch 14:	########################################	elapsed: 1.54s, reconstruction error: 9.26
# Epoch 15:	########################################	elapsed: 1.59s, reconstruction error: 9.16
# Epoch 16:	########################################	elapsed: 1.56s, reconstruction error: 9.12
# Epoch 17:	########################################	elapsed: 1.48s, reconstruction error: 8.96
# Epoch 18:	########################################	elapsed: 1.65s, reconstruction error: 8.77
# Epoch 19:	########################################	elapsed: 1.64s, reconstruction error: 8.96
# Epoch 20:	########################################	elapsed: 1.49s, reconstruction error: 8.80
# Epoch 21:	########################################	elapsed: 1.58s, reconstruction error: 8.85
# Epoch 22:	########################################	elapsed: 1.65s, reconstruction error: 8.79
# Epoch 23:	########################################	elapsed: 1.62s, reconstruction error: 8.61
# Epoch 24:	########################################	elapsed: 1.74s, reconstruction error: 8.77
# Epoch 25:	########################################	elapsed: 1.55s, reconstruction error: 8.67
# Epoch 26:	########################################	elapsed: 1.57s, reconstruction error: 8.64
# Epoch 27:	########################################	elapsed: 1.63s, reconstruction error: 8.60
# Epoch 28:	########################################	elapsed: 1.57s, reconstruction error: 8.64
# Epoch 29:	########################################	elapsed: 1.98s, reconstruction error: 8.59
# Epoch 30:	########################################	elapsed: 1.55s, reconstruction error: 8.49
# Epoch 31:	########################################	elapsed: 1.48s, reconstruction error: 8.59
# Epoch 32:	########################################	elapsed: 1.65s, reconstruction error: 8.40
# Epoch 33:	########################################	elapsed: 1.60s, reconstruction error: 8.51
# Epoch 34:	########################################	elapsed: 1.59s, reconstruction error: 8.52
# Epoch 35:	########################################	elapsed: 1.54s, reconstruction error: 8.37
# Epoch 36:	########################################	elapsed: 1.53s, reconstruction error: 8.36
# Epoch 37:	########################################	elapsed: 1.52s, reconstruction error: 8.32
# Epoch 38:	########################################	elapsed: 1.54s, reconstruction error: 8.34
# Epoch 39:	########################################	elapsed: 1.54s, reconstruction error: 8.49
# Epoch 40:	########################################	elapsed: 1.56s, reconstruction error: 8.43
# Epoch 41:	########################################	elapsed: 1.55s, reconstruction error: 8.50
# Epoch 42:	########################################	elapsed: 1.57s, reconstruction error: 8.36
# Epoch 43:	########################################	elapsed: 1.65s, reconstruction error: 8.46
# Epoch 44:	########################################	elapsed: 1.73s, reconstruction error: 8.41
# Epoch 45:	########################################	elapsed: 1.81s, reconstruction error: 8.36
# Epoch 46:	########################################	elapsed: 1.86s, reconstruction error: 8.35
# Epoch 47:	########################################	elapsed: 1.80s, reconstruction error: 8.30
# Epoch 48:	########################################	elapsed: 1.64s, reconstruction error: 8.29
# Epoch 49:	########################################	elapsed: 1.59s, reconstruction error: 8.26
# Epoch 50:	########################################	elapsed: 1.58s, reconstruction error: 8.24
#
# Learning layer 1
# Epoch 1:	########################################	elapsed: 0.74s, reconstruction error: 15.31
# Epoch 2:	########################################	elapsed: 0.74s, reconstruction error: 11.71
# Epoch 3:	########################################	elapsed: 0.75s, reconstruction error: 10.04
# Epoch 4:	########################################	elapsed: 0.70s, reconstruction error: 8.93
# Epoch 5:	########################################	elapsed: 0.72s, reconstruction error: 8.19
# Epoch 6:	########################################	elapsed: 0.77s, reconstruction error: 7.27
# Epoch 7:	########################################	elapsed: 0.70s, reconstruction error: 6.43
# Epoch 8:	########################################	elapsed: 0.71s, reconstruction error: 6.13
# Epoch 9:	########################################	elapsed: 0.72s, reconstruction error: 5.89
# Epoch 10:	########################################	elapsed: 0.73s, reconstruction error: 5.64
# Epoch 11:	########################################	elapsed: 0.72s, reconstruction error: 5.60
# Epoch 12:	########################################	elapsed: 0.83s, reconstruction error: 5.45
# Epoch 13:	########################################	elapsed: 0.74s, reconstruction error: 5.37
# Epoch 14:	########################################	elapsed: 1.04s, reconstruction error: 5.26
# Epoch 15:	########################################	elapsed: 0.74s, reconstruction error: 5.20
# Epoch 16:	########################################	elapsed: 0.76s, reconstruction error: 5.10
# Epoch 17:	########################################	elapsed: 0.72s, reconstruction error: 4.91
# Epoch 18:	########################################	elapsed: 0.73s, reconstruction error: 4.98
# Epoch 19:	########################################	elapsed: 0.75s, reconstruction error: 5.00
# Epoch 20:	########################################	elapsed: 0.73s, reconstruction error: 4.96
# Epoch 21:	########################################	elapsed: 0.71s, reconstruction error: 4.87
# Epoch 22:	########################################	elapsed: 0.72s, reconstruction error: 4.84
# Epoch 23:	########################################	elapsed: 0.73s, reconstruction error: 4.79
# Epoch 24:	########################################	elapsed: 0.73s, reconstruction error: 4.76
# Epoch 25:	########################################	elapsed: 0.72s, reconstruction error: 4.75
# Epoch 26:	########################################	elapsed: 0.71s, reconstruction error: 4.69
# Epoch 27:	########################################	elapsed: 0.71s, reconstruction error: 4.69
# Epoch 28:	########################################	elapsed: 0.71s, reconstruction error: 4.73
# Epoch 29:	########################################	elapsed: 0.71s, reconstruction error: 4.57
# Epoch 30:	########################################	elapsed: 0.71s, reconstruction error: 4.64
# Epoch 31:	########################################	elapsed: 0.71s, reconstruction error: 4.65
# Epoch 32:	########################################	elapsed: 0.71s, reconstruction error: 4.63
# Epoch 33:	########################################	elapsed: 0.71s, reconstruction error: 4.69
# Epoch 34:	########################################	elapsed: 0.74s, reconstruction error: 4.60
# Epoch 35:	########################################	elapsed: 0.76s, reconstruction error: 4.58
# Epoch 36:	########################################	elapsed: 0.91s, reconstruction error: 4.64
# Epoch 37:	########################################	elapsed: 0.77s, reconstruction error: 4.55
# Epoch 38:	########################################	elapsed: 0.72s, reconstruction error: 4.58
# Epoch 39:	########################################	elapsed: 0.72s, reconstruction error: 4.52
# Epoch 40:	########################################	elapsed: 0.72s, reconstruction error: 4.53
# Epoch 41:	########################################	elapsed: 0.72s, reconstruction error: 4.68
# Epoch 42:	########################################	elapsed: 0.72s, reconstruction error: 4.65
# Epoch 43:	########################################	elapsed: 0.73s, reconstruction error: 4.51
# Epoch 44:	########################################	elapsed: 0.70s, reconstruction error: 4.60
# Epoch 45:	########################################	elapsed: 0.71s, reconstruction error: 4.47
# Epoch 46:	########################################	elapsed: 0.70s, reconstruction error: 4.51
# Epoch 47:	########################################	elapsed: 0.70s, reconstruction error: 4.47
# Epoch 48:	########################################	elapsed: 0.71s, reconstruction error: 4.52
# Epoch 49:	########################################	elapsed: 0.71s, reconstruction error: 4.51
# Epoch 50:	########################################	elapsed: 0.71s, reconstruction error: 4.46
#
# Learning layer 2
# Epoch 1:	########################################	elapsed: 0.55s, reconstruction error: 10.58
# Epoch 2:	########################################	elapsed: 0.55s, reconstruction error: 8.14
# Epoch 3:	########################################	elapsed: 0.55s, reconstruction error: 7.00
# Epoch 4:	########################################	elapsed: 0.56s, reconstruction error: 6.36
# Epoch 5:	########################################	elapsed: 0.55s, reconstruction error: 5.92
# Epoch 6:	########################################	elapsed: 0.55s, reconstruction error: 5.16
# Epoch 7:	########################################	elapsed: 0.55s, reconstruction error: 4.75
# Epoch 8:	########################################	elapsed: 0.55s, reconstruction error: 4.49
# Epoch 9:	########################################	elapsed: 0.77s, reconstruction error: 4.36
# Epoch 10:	########################################	elapsed: 0.56s, reconstruction error: 4.25
# Epoch 11:	########################################	elapsed: 1.07s, reconstruction error: 4.26
# Epoch 12:	########################################	elapsed: 0.55s, reconstruction error: 4.21
# Epoch 13:	########################################	elapsed: 0.55s, reconstruction error: 4.13
# Epoch 14:	########################################	elapsed: 0.55s, reconstruction error: 4.09
# Epoch 15:	########################################	elapsed: 0.55s, reconstruction error: 4.02
# Epoch 16:	########################################	elapsed: 0.55s, reconstruction error: 3.96
# Epoch 17:	########################################	elapsed: 0.54s, reconstruction error: 3.98
# Epoch 18:	########################################	elapsed: 0.54s, reconstruction error: 4.02
# Epoch 19:	########################################	elapsed: 0.54s, reconstruction error: 3.91
# Epoch 20:	########################################	elapsed: 0.54s, reconstruction error: 4.01
# Epoch 21:	########################################	elapsed: 0.54s, reconstruction error: 3.89
# Epoch 22:	########################################	elapsed: 0.54s, reconstruction error: 3.91
# Epoch 23:	########################################	elapsed: 0.54s, reconstruction error: 3.85
# Epoch 24:	########################################	elapsed: 0.54s, reconstruction error: 3.89
# Epoch 25:	########################################	elapsed: 0.54s, reconstruction error: 3.86
# Epoch 26:	########################################	elapsed: 0.54s, reconstruction error: 3.93
# Epoch 27:	########################################	elapsed: 0.54s, reconstruction error: 3.86
# Epoch 28:	########################################	elapsed: 0.54s, reconstruction error: 3.91
# Epoch 29:	########################################	elapsed: 0.54s, reconstruction error: 3.76
# Epoch 30:	########################################	elapsed: 0.54s, reconstruction error: 3.83
# Epoch 31:	########################################	elapsed: 0.54s, reconstruction error: 3.83
# Epoch 32:	########################################	elapsed: 0.54s, reconstruction error: 3.79
# Epoch 33:	########################################	elapsed: 0.54s, reconstruction error: 3.85
# Epoch 34:	########################################	elapsed: 0.54s, reconstruction error: 3.82
# Epoch 35:	########################################	elapsed: 0.54s, reconstruction error: 3.79
# Epoch 36:	########################################	elapsed: 0.54s, reconstruction error: 3.83
# Epoch 37:	########################################	elapsed: 0.56s, reconstruction error: 3.77
# Epoch 38:	########################################	elapsed: 0.89s, reconstruction error: 3.78
# Epoch 39:	########################################	elapsed: 0.54s, reconstruction error: 3.77
# Epoch 40:	########################################	elapsed: 0.55s, reconstruction error: 3.74
# Epoch 41:	########################################	elapsed: 0.53s, reconstruction error: 3.77
# Epoch 42:	########################################	elapsed: 0.53s, reconstruction error: 3.78
# Epoch 43:	########################################	elapsed: 0.56s, reconstruction error: 3.79
# Epoch 44:	########################################	elapsed: 0.72s, reconstruction error: 3.77
# Epoch 45:	########################################	elapsed: 0.66s, reconstruction error: 3.77
# Epoch 46:	########################################	elapsed: 0.57s, reconstruction error: 3.74
# Epoch 47:	########################################	elapsed: 0.57s, reconstruction error: 3.77
# Epoch 48:	########################################	elapsed: 0.57s, reconstruction error: 3.74
# Epoch 49:	########################################	elapsed: 0.56s, reconstruction error: 3.72
# Epoch 50:	########################################	elapsed: 0.55s, reconstruction error: 3.76
#
# Learning layer 3
# Epoch 1:	########################################	elapsed: 0.36s, reconstruction error: 10.56
# Epoch 2:	########################################	elapsed: 0.36s, reconstruction error: 10.09
# Epoch 3:	########################################	elapsed: 0.36s, reconstruction error: 9.93
# Epoch 4:	########################################	elapsed: 0.36s, reconstruction error: 9.90
# Epoch 5:	########################################	elapsed: 0.36s, reconstruction error: 9.88
# Epoch 6:	########################################	elapsed: 0.36s, reconstruction error: 9.97
# Epoch 7:	########################################	elapsed: 0.72s, reconstruction error: 9.98
# Epoch 8:	########################################	elapsed: 0.35s, reconstruction error: 9.97
# Epoch 9:	########################################	elapsed: 0.36s, reconstruction error: 9.95
# Epoch 10:	########################################	elapsed: 0.38s, reconstruction error: 9.94
# Epoch 11:	########################################	elapsed: 0.37s, reconstruction error: 9.90
# Epoch 12:	########################################	elapsed: 0.36s, reconstruction error: 9.89
# Epoch 13:	########################################	elapsed: 0.35s, reconstruction error: 9.88
# Epoch 14:	########################################	elapsed: 0.36s, reconstruction error: 9.87
# Epoch 15:	########################################	elapsed: 0.35s, reconstruction error: 9.86
# Epoch 16:	########################################	elapsed: 0.35s, reconstruction error: 9.85
# Epoch 17:	########################################	elapsed: 0.35s, reconstruction error: 9.83
# Epoch 18:	########################################	elapsed: 0.35s, reconstruction error: 9.83
# Epoch 19:	########################################	elapsed: 0.36s, reconstruction error: 9.83
# Epoch 20:	########################################	elapsed: 0.35s, reconstruction error: 9.81
# Epoch 21:	########################################	elapsed: 0.36s, reconstruction error: 9.80
# Epoch 22:	########################################	elapsed: 0.37s, reconstruction error: 9.80
# Epoch 23:	########################################	elapsed: 0.37s, reconstruction error: 9.79
# Epoch 24:	########################################	elapsed: 0.38s, reconstruction error: 9.80
# Epoch 25:	########################################	elapsed: 0.37s, reconstruction error: 9.79
# Epoch 26:	########################################	elapsed: 0.37s, reconstruction error: 9.78
# Epoch 27:	########################################	elapsed: 0.37s, reconstruction error: 9.78
# Epoch 28:	########################################	elapsed: 0.37s, reconstruction error: 9.77
# Epoch 29:	########################################	elapsed: 0.37s, reconstruction error: 9.77
# Epoch 30:	########################################	elapsed: 0.38s, reconstruction error: 9.77
# Epoch 31:	########################################	elapsed: 0.37s, reconstruction error: 9.75
# Epoch 32:	########################################	elapsed: 0.37s, reconstruction error: 9.75
# Epoch 33:	########################################	elapsed: 0.39s, reconstruction error: 9.75
# Epoch 34:	########################################	elapsed: 0.37s, reconstruction error: 9.76
# Epoch 35:	########################################	elapsed: 0.37s, reconstruction error: 9.74
# Epoch 36:	########################################	elapsed: 0.37s, reconstruction error: 9.75
# Epoch 37:	########################################	elapsed: 0.36s, reconstruction error: 9.74
# Epoch 38:	########################################	elapsed: 0.35s, reconstruction error: 9.74
# Epoch 39:	########################################	elapsed: 0.35s, reconstruction error: 9.74
# Epoch 40:	########################################	elapsed: 0.35s, reconstruction error: 9.75
# Epoch 41:	########################################	elapsed: 0.36s, reconstruction error: 9.73
# Epoch 42:	########################################	elapsed: 0.35s, reconstruction error: 9.73
# Epoch 43:	########################################	elapsed: 0.35s, reconstruction error: 9.73
# Epoch 44:	########################################	elapsed: 0.36s, reconstruction error: 9.73
# Epoch 45:	########################################	elapsed: 0.36s, reconstruction error: 9.73
# Epoch 46:	########################################	elapsed: 0.35s, reconstruction error: 9.72
# Epoch 47:	########################################	elapsed: 0.35s, reconstruction error: 9.72
# Epoch 48:	########################################	elapsed: 0.35s, reconstruction error: 9.73
# Epoch 49:	########################################	elapsed: 0.35s, reconstruction error: 9.72
# Epoch 50:	########################################	elapsed: 0.35s, reconstruction error: 9.72
# <h3>Finetuning pretrained AE</h3>
# Reconstruction cost before finetuning: 249.50
#
# Epoch 1:	########################################	elapsed: 3.61s, cross-entropy: 167.87
# Epoch 2:	########################################	elapsed: 3.59s, cross-entropy: 163.75
# Epoch 3:	########################################	elapsed: 3.61s, cross-entropy: 161.23
# Epoch 4:	########################################	elapsed: 3.70s, cross-entropy: 158.96
# Epoch 5:	########################################	elapsed: 3.70s, cross-entropy: 157.11
# Epoch 6:	########################################	elapsed: 3.81s, cross-entropy: 155.65
# Epoch 7:	########################################	elapsed: 3.67s, cross-entropy: 154.46
# Epoch 8:	########################################	elapsed: 3.52s, cross-entropy: 153.47
# Epoch 9:	########################################	elapsed: 3.74s, cross-entropy: 152.70
# Epoch 10:	########################################	elapsed: 3.53s, cross-entropy: 152.00
# Epoch 11:	########################################	elapsed: 4.49s, cross-entropy: 151.55
# Epoch 12:	########################################	elapsed: 3.69s, cross-entropy: 149.87
# Epoch 13:	########################################	elapsed: 3.79s, cross-entropy: 148.69
# Epoch 14:	########################################	elapsed: 3.74s, cross-entropy: 147.63
# Epoch 15:	########################################	elapsed: 3.91s, cross-entropy: 147.94
# Epoch 16:	########################################	elapsed: 3.68s, cross-entropy: 146.31
# Epoch 17:	########################################	elapsed: 3.57s, cross-entropy: 145.72
# Epoch 18:	########################################	elapsed: 3.57s, cross-entropy: 144.89
# Epoch 19:	########################################	elapsed: 3.61s, cross-entropy: 144.37
# Epoch 20:	########################################	elapsed: 3.78s, cross-entropy: 144.07
# Epoch 21:	########################################	elapsed: 3.63s, cross-entropy: 144.12
# Epoch 22:	########################################	elapsed: 3.47s, cross-entropy: 143.61
# Epoch 23:	########################################	elapsed: 3.45s, cross-entropy: 143.00
# Epoch 24:	########################################	elapsed: 3.50s, cross-entropy: 142.65
# Epoch 25:	########################################	elapsed: 3.45s, cross-entropy: 142.70
# Epoch 26:	########################################	elapsed: 3.43s, cross-entropy: 142.12
# Epoch 27:	########################################	elapsed: 3.38s, cross-entropy: 141.96
# Epoch 28:	########################################	elapsed: 3.41s, cross-entropy: 142.02
# Epoch 29:	########################################	elapsed: 3.38s, cross-entropy: 141.30
# Epoch 30:	########################################	elapsed: 3.99s, cross-entropy: 141.35
# Epoch 31:	########################################	elapsed: 3.66s, cross-entropy: 141.12
# Epoch 32:	########################################	elapsed: 3.90s, cross-entropy: 141.43
# Epoch 33:	########################################	elapsed: 3.66s, cross-entropy: 140.81
# Epoch 34:	########################################	elapsed: 3.60s, cross-entropy: 141.16
# Epoch 35:	########################################	elapsed: 3.63s, cross-entropy: 139.86
# Epoch 36:	########################################	elapsed: 3.64s, cross-entropy: 140.20
# Epoch 37:	########################################	elapsed: 3.73s, cross-entropy: 140.06
# Epoch 38:	########################################	elapsed: 3.53s, cross-entropy: 139.24
# Epoch 39:	########################################	elapsed: 3.77s, cross-entropy: 139.16
# Epoch 40:	########################################	elapsed: 3.70s, cross-entropy: 138.79
# Epoch 41:	########################################	elapsed: 3.67s, cross-entropy: 138.72
# Epoch 42:	########################################	elapsed: 3.58s, cross-entropy: 138.47
# Epoch 43:	########################################	elapsed: 3.57s, cross-entropy: 138.19
# Epoch 44:	########################################	elapsed: 3.69s, cross-entropy: 138.37
# Epoch 45:	########################################	elapsed: 3.57s, cross-entropy: 138.54
# Epoch 46:	########################################	elapsed: 3.53s, cross-entropy: 138.38
# Epoch 47:	########################################	elapsed: 3.59s, cross-entropy: 137.85
# Epoch 48:	########################################	elapsed: 4.04s, cross-entropy: 137.67
# Epoch 49:	########################################	elapsed: 3.57s, cross-entropy: 137.77
# Epoch 50:	########################################	elapsed: 3.55s, cross-entropy: 137.47
# Training finished!
# <h3>2D codes from the pretrained AE</h3>
# <h3>2D codes from the finetuned AE</h3>

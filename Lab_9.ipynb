# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import mkl

mkl.set_num_threads(4)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def randn(*dims):
    return np.random.randn(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def as_matrix(vector):
    return np.reshape(vector, (-1, 1))

def one_hot_encode(labels):
    one_hot = zeros(labels.shape[0], np.max(labels) + 1) 
    one_hot[np.arange(labels.shape[0]), labels] = 1
    return one_hot.astype(np.float32)

def classify(mlp, batch):
    probabilities, _ = forward_pass(mlp, batch, False)
    return np.argmax(probabilities, axis=1)

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

def draw_layer_filters(layer):
    filters = np.reshape(layer.W[:-1].T, newshape=(16, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# ### Activation functions

# %%
def sigmoid(batch, stochastic=False):
    activations = 1.0 / (1.0 + np.exp(-batch))
    if stochastic:
        return activations > rand(*activations.shape).astype(np.float32)
    else:
        return activations

def sigmoid_derivative(batch):
    s = sigmoid(batch)
    return s * (1.0 - s)

def softmax(batch):
    batch = batch - np.expand_dims(np.max(batch, axis = 1), 1)
    return np.exp(batch) / np.expand_dims(np.exp(batch).sum(axis=1), 1)

# %%
def relu(batch, stochastic=False):
    activations = np.maximum(batch, 0)
    if stochastic:
        return np.maximum(0, batch + np.random.normal(scale=np.sqrt(sigmoid(batch)), size=batch.shape))
    
    return np.maximum(0, batch)

def relu_derivative(batch):
    return np.where(batch > 0, 1, 0)

# %% [markdown]
# # MNIST dataset

# %%
import mnist
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # MLP training

# %%
class Layer:
    def __init__(self, visible_size, hidden_size, activation_fun, d_activation_fun, 
                 dropout_rate, learning_rate, momentum, weight_limit):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.activation_fun = activation_fun
        self.d_activation_fun = d_activation_fun
        
        self.dropout_rate = dropout_rate
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.weight_limit = weight_limit
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size)).astype(np.float32)
        self.W[-1, :] = 0.0
        
        self.activations = None
        self.d_activations = None
        self.deltas = None
        
        self.M = zeros(self.visible_size+1, self.hidden_size)
        
    def deep_copy(self):
        copy = Layer(self.visible_size, self.hidden_size, self.activation_fun, self.d_activation_fun,
                     self.dropout_rate, self.learning_rate, self.momentum, self.weight_limit)
        copy.W = np.copy(self.W)
        copy.M = np.copy(self.M)
        return copy

# %%
def limit_weights(weights, limit):
    norms = np.linalg.norm(weights, axis=0)
    scale = np.where(norms > limit, limit/norms, 1)
    return weights * scale

# %% [markdown]
# ### Forward pass
#
# Calculate total input to the neurons. Then calculate activations (remember to add *ones* as the last column). Store result in `layer.activations`.
#
# ##### Computing derivatives of activation function
#
# If `compute_derivatives` is set to `True`, we also need to compute the derivatives of the activation function and store them in `layer.d_activations`. We **do not** need to add *ones column* to the derivatives matrix! *Ones* are only needed in the activations matrix, where they are used to add biases to the total input of neurons in the next hidden layer.
#
# ##### Dropout
#
# If `compute_derivatives` is set to `True` and the dropout rate in the input layer is greater than 0, we need to calculate the dropout mask for the MLP input and apply it to `batch`.
#
# When calculating hidden activations in an MLP layer, check whether dropout rate in the next layer is greater then 0. If yes, then we need to apply dropout to the calculated activations (and derivatives of activations). In this case:
# * construct dropout mask for the hidden layer,
# * apply this mask to where it is needed in the hidden layer.
#
# Do **not** apply dropout to the last column in activations or input batch, as they contains fixed *ones*.

# %%
def forward_pass(mlp, batch, compute_derivatives):    
    if compute_derivatives and mlp[0].dropout_rate > 0:
        batch = np.copy(batch)
        # apply dropout to the MLP input
        mask = rand(batch.shape[0], batch.shape[1]-1) < mlp[0].dropout_rate
        batch[:, :-1][mask] = 0
        
    visible = batch
    
    for layer_idx, layer in enumerate(mlp):
        z = visible @ layer.W
        layer.activations = append_ones(layer.activation_fun(z))
        
        if compute_derivatives and (layer_idx < len(mlp) - 1):
            layer.d_activations = layer.d_activation_fun(z)
            
            if mlp[layer_idx+1].dropout_rate > 0:
                # apply dropout where is it needed in the hidden layer
                mask = rand(*layer.d_activations.shape) < mlp[layer_idx+1].dropout_rate
                layer.activations[:, :-1][mask] = 0
                layer.d_activations[mask] = 0
        
        visible = layer.activations
    
    return visible[:, :-1], batch

# %% [markdown]
# ### Error backpropagation

# %%
def error_backpropagate(mlp, batch):
    observations_count = batch.shape[0]
    
    for layer_idx, layer in reversed(list(enumerate(mlp))):
        if layer_idx > 0:
            prev_layer = mlp[layer_idx - 1]
            visible = prev_layer.activations

            prev_layer.deltas = (layer.deltas @ layer.W[:-1, :].T) * prev_layer.d_activations
        else:
            visible = batch
        
        gradient = (visible.T @ layer.deltas) / observations_count
        layer.M *= layer.momentum
        layer.M -= layer.learning_rate * gradient
        
        layer.W += layer.M
        
        if layer.weight_limit > 0.0:
            layer.W[:-1, :] = limit_weights(layer.W[:-1, :], layer.weight_limit)

# %% [markdown]
# ### Mean dropout network
#
# Implement the weight scalling for the network that approximates MLP outputs under dropout.

# %%
def mean_network(mlp):
    mlp = [layer.deep_copy() for layer in mlp]
    
    for layer in mlp:
        layer.W *= (1 - layer.dropout_rate)
    
    return mlp

# %% [markdown]
# ### Training procedure

# %%
def train_mlp(mlp, dataset, labels, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    
    batched_data = chunks(dataset, batch_size)
    batched_labels = chunks(labels, batch_size)
    
    for batch_idx, (batch, batch_labels) in enumerate(zip(batched_data, batched_labels)):
        # Forward pass: compute activatations and derivatives of activations
        y, batch_with_dropout = forward_pass(mlp, batch, True)
        
        mlp[-1].deltas = y-batch_labels
        
        # Once softmax deltas are set, we may backpropagate errors
        error_backpropagate(mlp, batch_with_dropout)
        
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")

# %%
def run_mlp_training(mlp, train_set, train_labels, validation_set, validation_labels,
                     batch_size, epochs_count):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch+1),  end="\t")
        
        if epoch == 5:
            for layer in mlp:
                layer.momentum = 0.95
                layer.lr = 0.15
        elif epoch == 170:
            for layer in mlp:
                layer.momentum = 0.5
                layer.lr = 0.01
        
        start_time = time.time()
        train_mlp(mlp, train_set, train_labels, batch_size)
        elapsed = time.time() - start_time
        
        test_mlp = mean_network(mlp)
        
        predictions = classify(test_mlp, validation_set)
        accuracy = 100.0 * np.sum(predictions == validation_labels) / predictions.shape[0]
        print("\telapsed: {0:>2.2f}s, accuracy: {1:>2.2f}".format(elapsed, accuracy))

    print("Training finished!")

# %% [markdown]
# # MNIST digits classification

# %%
DATASET_SIZE = 5000 # 60000 for whole dataset
DIGIT_SIZE = 28

##### Train set #####

mnist_train_images = mnist.train_images().astype(np.float32) / 255.0
mnist_train_labels = mnist.train_labels()

order = np.random.permutation(len(mnist_train_images))
mnist_train_images = mnist_train_images[order]
mnist_train_labels = mnist_train_labels[order]

mnist_train_images = np.reshape(mnist_train_images[:DATASET_SIZE],
                                newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
mnist_train_images = append_ones(mnist_train_images)

mnist_train_labels = mnist_train_labels[:DATASET_SIZE]
mnist_train_labels = one_hot_encode(mnist_train_labels)

monitoring_set_indeces = np.random.choice(mnist_train_images.shape[0], 512, replace=False)
monitoring_set = mnist_train_images[monitoring_set_indeces]

##### Test set #####

mnist_test_images = mnist.test_images().astype(np.float32) / 255.0
mnist_test_images = np.reshape(mnist_test_images, newshape=(-1, DIGIT_SIZE*DIGIT_SIZE))
mnist_test_images = append_ones(mnist_test_images)

mnist_test_labels = mnist.test_labels()

# %%
VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 512

BATCH_SIZE = 128
EPOCHS_COUNT = 200

LEARNING_RATE = 0.03
SOFTMAX_LEARNING_RATE = 0.15
MOMENTUM = 0.5

# %%
from IPython.core.display import HTML

def evaluate(mlp, train_set, train_labels,
             validation_set, validation_labels,
             batch_size, epochs_count):
    for layer in mlp:
        layer.reset()

    display(HTML('<h3>MLP training</h3>'))
    run_mlp_training(mlp,
                     train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count)
    
    display(HTML('<h3>Input layer filters in MLP</h3>'))
    draw_layer_filters(mlp[0])
    
    display(HTML('<h3>Largest norms of weight-vectors in MLP layers</h3>'))
    for i, layer in enumerate(mlp):
        max_norm = np.max(np.linalg.norm(layer.W[:-1, :], axis=0))
        print('\tlayer {0}: {1:.2f}'.format(i+1, max_norm))

# %% [markdown]
# ### Plain MLP (no dropout)

# %%
mlp = [
    Layer(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, 0.0, LEARNING_RATE, MOMENTUM,
          weight_limit=1.0),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, 0.0, LEARNING_RATE, MOMENTUM,
          weight_limit=1.0),
    Layer(HIDDEN_LAYER_SIZE, 10, softmax, None, 0.0, SOFTMAX_LEARNING_RATE, MOMENTUM,
          weight_limit=4.0)
]

evaluate(mlp, 
         mnist_train_images, mnist_train_labels, 
         mnist_test_images, mnist_test_labels,
         BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>MLP training</h3>
# Epoch 1:	########################################	elapsed: 1.18s, accuracy: 20.35
# Epoch 2:	########################################	elapsed: 1.22s, accuracy: 28.97
# Epoch 3:	########################################	elapsed: 1.19s, accuracy: 42.52
# Epoch 4:	########################################	elapsed: 1.15s, accuracy: 65.18
# Epoch 5:	########################################	elapsed: 1.14s, accuracy: 69.88
# Epoch 6:	########################################	elapsed: 1.16s, accuracy: 82.81
# Epoch 7:	########################################	elapsed: 1.16s, accuracy: 88.51
# Epoch 8:	########################################	elapsed: 1.18s, accuracy: 89.58
# Epoch 9:	########################################	elapsed: 1.15s, accuracy: 91.39
# Epoch 10:	########################################	elapsed: 1.14s, accuracy: 91.76
# Epoch 11:	########################################	elapsed: 1.14s, accuracy: 93.16
# Epoch 12:	########################################	elapsed: 1.13s, accuracy: 92.99
# Epoch 13:	########################################	elapsed: 1.16s, accuracy: 94.14
# Epoch 14:	########################################	elapsed: 1.14s, accuracy: 91.38
# Epoch 15:	########################################	elapsed: 1.16s, accuracy: 93.14
# Epoch 16:	########################################	elapsed: 1.15s, accuracy: 94.15
# Epoch 17:	########################################	elapsed: 1.14s, accuracy: 93.56
# Epoch 18:	########################################	elapsed: 1.14s, accuracy: 93.42
# Epoch 19:	########################################	elapsed: 1.12s, accuracy: 94.78
# Epoch 20:	########################################	elapsed: 1.13s, accuracy: 94.34
# Epoch 21:	########################################	elapsed: 1.11s, accuracy: 94.77
# Epoch 22:	########################################	elapsed: 1.11s, accuracy: 95.12
# Epoch 23:	########################################	elapsed: 1.13s, accuracy: 93.90
# Epoch 24:	########################################	elapsed: 1.12s, accuracy: 94.51
# Epoch 25:	########################################	elapsed: 1.14s, accuracy: 94.14
# Epoch 26:	########################################	elapsed: 1.13s, accuracy: 94.07
# Epoch 27:	########################################	elapsed: 1.12s, accuracy: 93.72
# Epoch 28:	########################################	elapsed: 1.09s, accuracy: 94.50
# Epoch 29:	########################################	elapsed: 1.27s, accuracy: 94.63
# Epoch 30:	########################################	elapsed: 1.22s, accuracy: 95.08
# Epoch 31:	########################################	elapsed: 1.28s, accuracy: 95.11
# Epoch 32:	########################################	elapsed: 1.17s, accuracy: 95.14
# Epoch 33:	########################################	elapsed: 1.14s, accuracy: 95.28
# Epoch 34:	########################################	elapsed: 1.21s, accuracy: 95.22
# Epoch 35:	########################################	elapsed: 1.17s, accuracy: 95.22
# Epoch 36:	########################################	elapsed: 1.18s, accuracy: 95.25
# Epoch 37:	########################################	elapsed: 1.15s, accuracy: 95.24
# Epoch 38:	########################################	elapsed: 1.21s, accuracy: 95.28
# Epoch 39:	########################################	elapsed: 1.15s, accuracy: 95.31
# Epoch 40:	########################################	elapsed: 1.16s, accuracy: 95.28
# Epoch 41:	########################################	elapsed: 1.19s, accuracy: 95.28
# Epoch 42:	########################################	elapsed: 1.19s, accuracy: 95.27
# Epoch 43:	########################################	elapsed: 1.20s, accuracy: 95.28
# Epoch 44:	########################################	elapsed: 1.22s, accuracy: 95.29
# Epoch 45:	########################################	elapsed: 1.22s, accuracy: 95.29
# Epoch 46:	########################################	elapsed: 1.27s, accuracy: 95.30
# Epoch 47:	########################################	elapsed: 1.36s, accuracy: 95.30
# Epoch 48:	########################################	elapsed: 1.32s, accuracy: 95.31
# Epoch 49:	########################################	elapsed: 1.26s, accuracy: 95.31
# Epoch 50:	########################################	elapsed: 1.23s, accuracy: 95.33
# Epoch 51:	########################################	elapsed: 1.49s, accuracy: 95.33
# Epoch 52:	########################################	elapsed: 1.57s, accuracy: 95.33
# Epoch 53:	########################################	elapsed: 1.50s, accuracy: 95.32
# Epoch 54:	########################################	elapsed: 1.38s, accuracy: 95.32
# Epoch 55:	########################################	elapsed: 1.64s, accuracy: 95.32
# Epoch 56:	########################################	elapsed: 1.85s, accuracy: 95.33
# Epoch 57:	########################################	elapsed: 1.26s, accuracy: 95.32
# Epoch 58:	########################################	elapsed: 1.28s, accuracy: 95.31
# Epoch 59:	########################################	elapsed: 1.25s, accuracy: 95.31
# Epoch 60:	########################################	elapsed: 1.27s, accuracy: 95.31
# Epoch 61:	########################################	elapsed: 1.29s, accuracy: 95.31
# Epoch 62:	########################################	elapsed: 1.32s, accuracy: 95.31
# Epoch 63:	########################################	elapsed: 1.28s, accuracy: 95.31
# Epoch 64:	########################################	elapsed: 1.31s, accuracy: 95.31
# Epoch 65:	########################################	elapsed: 1.34s, accuracy: 95.31
# Epoch 66:	########################################	elapsed: 1.32s, accuracy: 95.31
# Epoch 67:	########################################	elapsed: 1.48s, accuracy: 95.33
# Epoch 68:	########################################	elapsed: 1.57s, accuracy: 95.33
# Epoch 69:	########################################	elapsed: 1.34s, accuracy: 95.32
# Epoch 70:	########################################	elapsed: 1.27s, accuracy: 95.32
# Epoch 71:	########################################	elapsed: 1.29s, accuracy: 95.31
# Epoch 72:	########################################	elapsed: 1.31s, accuracy: 95.31
# Epoch 73:	########################################	elapsed: 1.29s, accuracy: 95.31
# Epoch 74:	########################################	elapsed: 1.33s, accuracy: 95.32
# Epoch 75:	########################################	elapsed: 1.29s, accuracy: 95.32
# Epoch 76:	########################################	elapsed: 1.29s, accuracy: 95.32
# Epoch 77:	########################################	elapsed: 1.30s, accuracy: 95.32
# Epoch 78:	########################################	elapsed: 1.30s, accuracy: 95.32
# Epoch 79:	########################################	elapsed: 1.30s, accuracy: 95.32
# Epoch 80:	########################################	elapsed: 1.29s, accuracy: 95.32
# Epoch 81:	########################################	elapsed: 1.34s, accuracy: 95.32
# Epoch 82:	########################################	elapsed: 1.32s, accuracy: 95.32
# Epoch 83:	########################################	elapsed: 1.37s, accuracy: 95.33
# Epoch 84:	########################################	elapsed: 1.39s, accuracy: 95.32
# Epoch 85:	########################################	elapsed: 1.31s, accuracy: 95.32
# Epoch 86:	########################################	elapsed: 1.29s, accuracy: 95.31
# Epoch 87:	########################################	elapsed: 1.29s, accuracy: 95.31
# Epoch 88:	########################################	elapsed: 1.29s, accuracy: 95.31
# Epoch 89:	########################################	elapsed: 1.29s, accuracy: 95.32
# Epoch 90:	########################################	elapsed: 1.29s, accuracy: 95.31
# Epoch 91:	########################################	elapsed: 1.28s, accuracy: 95.30
# Epoch 92:	########################################	elapsed: 1.33s, accuracy: 95.31
# Epoch 93:	########################################	elapsed: 1.46s, accuracy: 95.31
# Epoch 94:	########################################	elapsed: 1.31s, accuracy: 95.31
# Epoch 95:	########################################	elapsed: 1.32s, accuracy: 95.33
# Epoch 96:	########################################	elapsed: 1.37s, accuracy: 95.33
# Epoch 97:	########################################	elapsed: 1.32s, accuracy: 95.33
# Epoch 98:	########################################	elapsed: 1.32s, accuracy: 95.33
# Epoch 99:	########################################	elapsed: 1.28s, accuracy: 95.33
# Epoch 100:	########################################	elapsed: 1.33s, accuracy: 95.33
# Epoch 101:	########################################	elapsed: 1.87s, accuracy: 95.33
# Epoch 102:	########################################	elapsed: 1.41s, accuracy: 95.33
# Epoch 103:	########################################	elapsed: 1.35s, accuracy: 95.33
# Epoch 104:	########################################	elapsed: 1.37s, accuracy: 95.33
# Epoch 105:	########################################	elapsed: 1.31s, accuracy: 95.33
# Epoch 106:	########################################	elapsed: 1.30s, accuracy: 95.33
# Epoch 107:	########################################	elapsed: 1.29s, accuracy: 95.33
# Epoch 108:	########################################	elapsed: 1.29s, accuracy: 95.33
# Epoch 109:	########################################	elapsed: 1.32s, accuracy: 95.33
# Epoch 110:	########################################	elapsed: 1.28s, accuracy: 95.32
# Epoch 111:	########################################	elapsed: 1.32s, accuracy: 95.32
# Epoch 112:	########################################	elapsed: 1.47s, accuracy: 95.33
# Epoch 113:	########################################	elapsed: 1.29s, accuracy: 95.33
# Epoch 114:	########################################	elapsed: 1.28s, accuracy: 95.33
# Epoch 115:	########################################	elapsed: 1.30s, accuracy: 95.33
# Epoch 116:	########################################	elapsed: 1.27s, accuracy: 95.33
# Epoch 117:	########################################	elapsed: 1.28s, accuracy: 95.33
# Epoch 118:	########################################	elapsed: 1.27s, accuracy: 95.33
# Epoch 119:	########################################	elapsed: 1.29s, accuracy: 95.33
# Epoch 120:	########################################	elapsed: 1.31s, accuracy: 95.33
# Epoch 121:	########################################	elapsed: 1.29s, accuracy: 95.33
# Epoch 122:	########################################	elapsed: 1.32s, accuracy: 95.33
# Epoch 123:	########################################	elapsed: 1.29s, accuracy: 95.34
# Epoch 124:	########################################	elapsed: 1.29s, accuracy: 95.34
# Epoch 125:	########################################	elapsed: 1.29s, accuracy: 95.34
# Epoch 126:	########################################	elapsed: 1.30s, accuracy: 95.34
# Epoch 127:	########################################	elapsed: 1.28s, accuracy: 95.34
# Epoch 128:	########################################	elapsed: 1.30s, accuracy: 95.34
# Epoch 129:	########################################	elapsed: 1.38s, accuracy: 95.34
# Epoch 130:	########################################	elapsed: 1.35s, accuracy: 95.33
# Epoch 131:	########################################	elapsed: 1.35s, accuracy: 95.33
# Epoch 132:	########################################	elapsed: 1.31s, accuracy: 95.33
# Epoch 133:	########################################	elapsed: 1.27s, accuracy: 95.33
# Epoch 134:	########################################	elapsed: 1.27s, accuracy: 95.33
# Epoch 135:	########################################	elapsed: 1.29s, accuracy: 95.32
# Epoch 136:	########################################	elapsed: 1.34s, accuracy: 95.33
# Epoch 137:	########################################	elapsed: 1.26s, accuracy: 95.33
# Epoch 138:	########################################	elapsed: 1.28s, accuracy: 95.33
# Epoch 139:	########################################	elapsed: 1.29s, accuracy: 95.33
# Epoch 140:	########################################	elapsed: 1.31s, accuracy: 95.33
# Epoch 141:	########################################	elapsed: 1.31s, accuracy: 95.32
# Epoch 142:	########################################	elapsed: 1.35s, accuracy: 95.32
# Epoch 143:	########################################	elapsed: 1.55s, accuracy: 95.32
# Epoch 144:	########################################	elapsed: 1.31s, accuracy: 95.32
# Epoch 145:	########################################	elapsed: 1.29s, accuracy: 95.32
# Epoch 146:	########################################	elapsed: 1.32s, accuracy: 95.31
# Epoch 147:	########################################	elapsed: 1.31s, accuracy: 95.31
# Epoch 148:	########################################	elapsed: 1.30s, accuracy: 95.31
# Epoch 149:	########################################	elapsed: 1.29s, accuracy: 95.30
# Epoch 150:	########################################	elapsed: 1.27s, accuracy: 95.30
# Epoch 151:	########################################	elapsed: 1.28s, accuracy: 95.30
# Epoch 152:	########################################	elapsed: 1.29s, accuracy: 95.30
# Epoch 153:	########################################	elapsed: 1.28s, accuracy: 95.30
# Epoch 154:	########################################	elapsed: 1.29s, accuracy: 95.30
# Epoch 155:	########################################	elapsed: 1.30s, accuracy: 95.30
# Epoch 156:	########################################	elapsed: 1.30s, accuracy: 95.30
# Epoch 157:	########################################	elapsed: 1.29s, accuracy: 95.30
# Epoch 158:	########################################	elapsed: 1.37s, accuracy: 95.30
# Epoch 159:	########################################	elapsed: 1.40s, accuracy: 95.30
# Epoch 160:	########################################	elapsed: 1.31s, accuracy: 95.31
# Epoch 161:	########################################	elapsed: 1.29s, accuracy: 95.31
# Epoch 162:	########################################	elapsed: 1.32s, accuracy: 95.31
# Epoch 163:	########################################	elapsed: 1.31s, accuracy: 95.31
# Epoch 164:	########################################	elapsed: 1.32s, accuracy: 95.32
# Epoch 165:	########################################	elapsed: 1.32s, accuracy: 95.32
# Epoch 166:	########################################	elapsed: 1.30s, accuracy: 95.31
# Epoch 167:	########################################	elapsed: 1.32s, accuracy: 95.31
# Epoch 168:	########################################	elapsed: 1.31s, accuracy: 95.31
# Epoch 169:	########################################	elapsed: 1.35s, accuracy: 95.31
# Epoch 170:	########################################	elapsed: 1.31s, accuracy: 95.31
# Epoch 171:	########################################	elapsed: 1.25s, accuracy: 95.31
# Epoch 172:	########################################	elapsed: 1.22s, accuracy: 95.31
# Epoch 173:	########################################	elapsed: 1.18s, accuracy: 95.31
# Epoch 174:	########################################	elapsed: 1.17s, accuracy: 95.31
# Epoch 175:	########################################	elapsed: 1.17s, accuracy: 95.31
# Epoch 176:	########################################	elapsed: 1.25s, accuracy: 95.31
# Epoch 177:	########################################	elapsed: 1.17s, accuracy: 95.31
# Epoch 178:	########################################	elapsed: 1.22s, accuracy: 95.31
# Epoch 179:	########################################	elapsed: 1.18s, accuracy: 95.31
# Epoch 180:	########################################	elapsed: 1.18s, accuracy: 95.31
# Epoch 181:	########################################	elapsed: 1.18s, accuracy: 95.31
# Epoch 182:	########################################	elapsed: 1.15s, accuracy: 95.31
# Epoch 183:	########################################	elapsed: 1.17s, accuracy: 95.31
# Epoch 184:	########################################	elapsed: 1.19s, accuracy: 95.31
# Epoch 185:	########################################	elapsed: 1.18s, accuracy: 95.31
# Epoch 186:	########################################	elapsed: 1.16s, accuracy: 95.31
# Epoch 187:	########################################	elapsed: 1.16s, accuracy: 95.31
# Epoch 188:	########################################	elapsed: 1.16s, accuracy: 95.31
# Epoch 189:	########################################	elapsed: 1.16s, accuracy: 95.31
# Epoch 190:	########################################	elapsed: 1.15s, accuracy: 95.31
# Epoch 191:	########################################	elapsed: 1.16s, accuracy: 95.31
# Epoch 192:	########################################	elapsed: 1.15s, accuracy: 95.31
# Epoch 193:	########################################	elapsed: 1.19s, accuracy: 95.31
# Epoch 194:	########################################	elapsed: 1.17s, accuracy: 95.31
# Epoch 195:	########################################	elapsed: 1.16s, accuracy: 95.31
# Epoch 196:	########################################	elapsed: 1.16s, accuracy: 95.31
# Epoch 197:	########################################	elapsed: 1.17s, accuracy: 95.31
# Epoch 198:	########################################	elapsed: 1.15s, accuracy: 95.31
# Epoch 199:	########################################	elapsed: 1.27s, accuracy: 95.31
# Epoch 200:	########################################	elapsed: 1.18s, accuracy: 95.31
# Training finished!
# <h3>Input layer filters in MLP</h3>
# <h3>Largest norms of weight-vectors in MLP layers</h3>
# 	layer 1: 1.00
# 	layer 2: 0.86
# 	layer 3: 4.00

# %% [markdown]
# ### MLP with dropout

# %%
mlp_with_dropout = [
    Layer(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, 0.2, LEARNING_RATE, MOMENTUM,
          weight_limit=1.0),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, 0.5, LEARNING_RATE, MOMENTUM,
          weight_limit=1.0),
    Layer(HIDDEN_LAYER_SIZE, 10, softmax, None, 0.5, SOFTMAX_LEARNING_RATE, MOMENTUM,
          weight_limit=4.0)
]

evaluate(mlp_with_dropout, 
         mnist_train_images, mnist_train_labels, 
         mnist_test_images, mnist_test_labels,
         BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>MLP training</h3>
# Epoch 1:	########################################	elapsed: 1.49s, accuracy: 11.35
# Epoch 2:	########################################	elapsed: 1.44s, accuracy: 11.35
# Epoch 3:	########################################	elapsed: 1.64s, accuracy: 11.35
# Epoch 4:	########################################	elapsed: 1.48s, accuracy: 11.47
# Epoch 5:	########################################	elapsed: 1.55s, accuracy: 13.39
# Epoch 6:	########################################	elapsed: 1.59s, accuracy: 20.65
# Epoch 7:	########################################	elapsed: 1.50s, accuracy: 22.21
# Epoch 8:	########################################	elapsed: 1.45s, accuracy: 56.17
# Epoch 9:	########################################	elapsed: 1.42s, accuracy: 75.42
# Epoch 10:	########################################	elapsed: 1.46s, accuracy: 83.68
# Epoch 11:	########################################	elapsed: 1.43s, accuracy: 88.03
# Epoch 12:	########################################	elapsed: 1.49s, accuracy: 87.54
# Epoch 13:	########################################	elapsed: 1.42s, accuracy: 89.36
# Epoch 14:	########################################	elapsed: 1.44s, accuracy: 90.37
# Epoch 15:	########################################	elapsed: 1.49s, accuracy: 90.75
# Epoch 16:	########################################	elapsed: 1.52s, accuracy: 91.89
# Epoch 17:	########################################	elapsed: 1.44s, accuracy: 92.39
# Epoch 18:	########################################	elapsed: 1.43s, accuracy: 92.66
# Epoch 19:	########################################	elapsed: 1.47s, accuracy: 93.37
# Epoch 20:	########################################	elapsed: 1.46s, accuracy: 93.17
# Epoch 21:	########################################	elapsed: 1.46s, accuracy: 93.51
# Epoch 22:	########################################	elapsed: 1.52s, accuracy: 93.88
# Epoch 23:	########################################	elapsed: 1.46s, accuracy: 93.53
# Epoch 24:	########################################	elapsed: 1.45s, accuracy: 93.84
# Epoch 25:	########################################	elapsed: 1.44s, accuracy: 94.70
# Epoch 26:	########################################	elapsed: 1.45s, accuracy: 94.52
# Epoch 27:	########################################	elapsed: 1.43s, accuracy: 94.62
# Epoch 28:	########################################	elapsed: 1.44s, accuracy: 94.95
# Epoch 29:	########################################	elapsed: 1.42s, accuracy: 94.77
# Epoch 30:	########################################	elapsed: 1.47s, accuracy: 94.53
# Epoch 31:	########################################	elapsed: 1.45s, accuracy: 94.66
# Epoch 32:	########################################	elapsed: 1.45s, accuracy: 94.93
# Epoch 33:	########################################	elapsed: 1.41s, accuracy: 94.95
# Epoch 34:	########################################	elapsed: 1.43s, accuracy: 94.86
# Epoch 35:	########################################	elapsed: 1.42s, accuracy: 94.75
# Epoch 36:	########################################	elapsed: 1.44s, accuracy: 94.89
# Epoch 37:	########################################	elapsed: 1.44s, accuracy: 95.24
# Epoch 38:	########################################	elapsed: 1.49s, accuracy: 95.15
# Epoch 39:	########################################	elapsed: 1.46s, accuracy: 95.26
# Epoch 40:	########################################	elapsed: 1.48s, accuracy: 95.21
# Epoch 41:	########################################	elapsed: 1.51s, accuracy: 94.89
# Epoch 42:	########################################	elapsed: 1.42s, accuracy: 94.80
# Epoch 43:	########################################	elapsed: 1.52s, accuracy: 95.15
# Epoch 44:	########################################	elapsed: 1.43s, accuracy: 95.20
# Epoch 45:	########################################	elapsed: 1.45s, accuracy: 95.41
# Epoch 46:	########################################	elapsed: 1.52s, accuracy: 95.49
# Epoch 47:	########################################	elapsed: 1.46s, accuracy: 95.48
# Epoch 48:	########################################	elapsed: 1.48s, accuracy: 95.49
# Epoch 49:	########################################	elapsed: 1.52s, accuracy: 95.47
# Epoch 50:	########################################	elapsed: 1.48s, accuracy: 95.39
# Epoch 51:	########################################	elapsed: 1.59s, accuracy: 95.59
# Epoch 52:	########################################	elapsed: 1.56s, accuracy: 95.51
# Epoch 53:	########################################	elapsed: 1.50s, accuracy: 95.48
# Epoch 54:	########################################	elapsed: 1.51s, accuracy: 95.05
# Epoch 55:	########################################	elapsed: 1.49s, accuracy: 95.56
# Epoch 56:	########################################	elapsed: 1.51s, accuracy: 95.64
# Epoch 57:	########################################	elapsed: 1.52s, accuracy: 95.60
# Epoch 58:	########################################	elapsed: 1.49s, accuracy: 95.55
# Epoch 59:	########################################	elapsed: 1.50s, accuracy: 95.60
# Epoch 60:	########################################	elapsed: 1.51s, accuracy: 95.75
# Epoch 61:	########################################	elapsed: 1.50s, accuracy: 95.74
# Epoch 62:	########################################	elapsed: 1.79s, accuracy: 95.59
# Epoch 63:	########################################	elapsed: 1.51s, accuracy: 95.78
# Epoch 64:	########################################	elapsed: 1.47s, accuracy: 95.70
# Epoch 65:	########################################	elapsed: 1.49s, accuracy: 95.77
# Epoch 66:	########################################	elapsed: 1.58s, accuracy: 95.79
# Epoch 67:	########################################	elapsed: 1.60s, accuracy: 95.73
# Epoch 68:	########################################	elapsed: 1.49s, accuracy: 95.86
# Epoch 69:	########################################	elapsed: 1.56s, accuracy: 95.47
# Epoch 70:	########################################	elapsed: 1.51s, accuracy: 95.79
# Epoch 71:	########################################	elapsed: 1.50s, accuracy: 95.80
# Epoch 72:	########################################	elapsed: 1.55s, accuracy: 95.92
# Epoch 73:	########################################	elapsed: 1.51s, accuracy: 95.76
# Epoch 74:	########################################	elapsed: 1.52s, accuracy: 95.65
# Epoch 75:	########################################	elapsed: 1.55s, accuracy: 95.87
# Epoch 76:	########################################	elapsed: 1.52s, accuracy: 95.67
# Epoch 77:	########################################	elapsed: 1.57s, accuracy: 95.89
# Epoch 78:	########################################	elapsed: 1.50s, accuracy: 95.68
# Epoch 79:	########################################	elapsed: 1.50s, accuracy: 95.89
# Epoch 80:	########################################	elapsed: 1.50s, accuracy: 95.89
# Epoch 81:	########################################	elapsed: 1.53s, accuracy: 95.97
# Epoch 82:	########################################	elapsed: 1.50s, accuracy: 95.95
# Epoch 83:	########################################	elapsed: 1.50s, accuracy: 95.95
# Epoch 84:	########################################	elapsed: 1.49s, accuracy: 95.76
# Epoch 85:	########################################	elapsed: 1.62s, accuracy: 95.78
# Epoch 86:	########################################	elapsed: 1.53s, accuracy: 95.72
# Epoch 87:	########################################	elapsed: 1.51s, accuracy: 96.07
# Epoch 88:	########################################	elapsed: 1.52s, accuracy: 95.97
# Epoch 89:	########################################	elapsed: 1.51s, accuracy: 95.90
# Epoch 90:	########################################	elapsed: 1.51s, accuracy: 96.00
# Epoch 91:	########################################	elapsed: 1.52s, accuracy: 96.14
# Epoch 92:	########################################	elapsed: 1.51s, accuracy: 96.14
# Epoch 93:	########################################	elapsed: 1.56s, accuracy: 96.13
# Epoch 94:	########################################	elapsed: 1.50s, accuracy: 95.99
# Epoch 95:	########################################	elapsed: 1.52s, accuracy: 96.12
# Epoch 96:	########################################	elapsed: 1.53s, accuracy: 96.11
# Epoch 97:	########################################	elapsed: 1.53s, accuracy: 96.05
# Epoch 98:	########################################	elapsed: 1.52s, accuracy: 96.05
# Epoch 99:	########################################	elapsed: 1.57s, accuracy: 96.15
# Epoch 100:	########################################	elapsed: 1.62s, accuracy: 95.87
# Epoch 101:	########################################	elapsed: 1.55s, accuracy: 96.02
# Epoch 102:	########################################	elapsed: 1.54s, accuracy: 95.96
# Epoch 103:	########################################	elapsed: 1.55s, accuracy: 96.34
# Epoch 104:	########################################	elapsed: 1.53s, accuracy: 95.96
# Epoch 105:	########################################	elapsed: 1.54s, accuracy: 96.10
# Epoch 106:	########################################	elapsed: 1.53s, accuracy: 96.06
# Epoch 107:	########################################	elapsed: 1.55s, accuracy: 96.20
# Epoch 108:	########################################	elapsed: 1.82s, accuracy: 96.04
# Epoch 109:	########################################	elapsed: 1.56s, accuracy: 95.94
# Epoch 110:	########################################	elapsed: 1.72s, accuracy: 95.98
# Epoch 111:	########################################	elapsed: 1.54s, accuracy: 96.05
# Epoch 112:	########################################	elapsed: 1.53s, accuracy: 96.10
# Epoch 113:	########################################	elapsed: 1.52s, accuracy: 96.00
# Epoch 114:	########################################	elapsed: 1.51s, accuracy: 95.99
# Epoch 115:	########################################	elapsed: 1.55s, accuracy: 96.08
# Epoch 116:	########################################	elapsed: 1.52s, accuracy: 95.97
# Epoch 117:	########################################	elapsed: 1.64s, accuracy: 96.29
# Epoch 118:	########################################	elapsed: 1.71s, accuracy: 95.96
# Epoch 119:	########################################	elapsed: 1.66s, accuracy: 96.11
# Epoch 120:	########################################	elapsed: 1.56s, accuracy: 96.07
# Epoch 121:	########################################	elapsed: 1.54s, accuracy: 96.43
# Epoch 122:	########################################	elapsed: 1.52s, accuracy: 95.97
# Epoch 123:	########################################	elapsed: 1.56s, accuracy: 96.31
# Epoch 124:	########################################	elapsed: 1.50s, accuracy: 95.86
# Epoch 125:	########################################	elapsed: 1.55s, accuracy: 96.18
# Epoch 126:	########################################	elapsed: 1.56s, accuracy: 96.07
# Epoch 127:	########################################	elapsed: 1.53s, accuracy: 96.34
# Epoch 128:	########################################	elapsed: 1.51s, accuracy: 96.10
# Epoch 129:	########################################	elapsed: 1.50s, accuracy: 96.32
# Epoch 130:	########################################	elapsed: 1.55s, accuracy: 96.21
# Epoch 131:	########################################	elapsed: 1.54s, accuracy: 96.15
# Epoch 132:	########################################	elapsed: 1.58s, accuracy: 96.32
# Epoch 133:	########################################	elapsed: 1.56s, accuracy: 96.02
# Epoch 134:	########################################	elapsed: 1.54s, accuracy: 95.92
# Epoch 135:	########################################	elapsed: 1.54s, accuracy: 96.11
# Epoch 136:	########################################	elapsed: 1.62s, accuracy: 96.37
# Epoch 137:	########################################	elapsed: 1.59s, accuracy: 96.28
# Epoch 138:	########################################	elapsed: 1.55s, accuracy: 96.26
# Epoch 139:	########################################	elapsed: 1.52s, accuracy: 96.30
# Epoch 140:	########################################	elapsed: 1.54s, accuracy: 96.12
# Epoch 141:	########################################	elapsed: 1.61s, accuracy: 96.06
# Epoch 142:	########################################	elapsed: 1.60s, accuracy: 96.17
# Epoch 143:	########################################	elapsed: 1.57s, accuracy: 96.13
# Epoch 144:	########################################	elapsed: 1.52s, accuracy: 96.19
# Epoch 145:	########################################	elapsed: 1.54s, accuracy: 96.15
# Epoch 146:	########################################	elapsed: 1.52s, accuracy: 96.21
# Epoch 147:	########################################	elapsed: 1.48s, accuracy: 96.02
# Epoch 148:	########################################	elapsed: 1.50s, accuracy: 96.20
# Epoch 149:	########################################	elapsed: 1.47s, accuracy: 96.08
# Epoch 150:	########################################	elapsed: 1.49s, accuracy: 96.25
# Epoch 151:	########################################	elapsed: 1.55s, accuracy: 96.28
# Epoch 152:	########################################	elapsed: 1.58s, accuracy: 96.14
# Epoch 153:	########################################	elapsed: 1.64s, accuracy: 96.17
# Epoch 154:	########################################	elapsed: 1.50s, accuracy: 96.39
# Epoch 155:	########################################	elapsed: 1.49s, accuracy: 96.16
# Epoch 156:	########################################	elapsed: 1.53s, accuracy: 96.08
# Epoch 157:	########################################	elapsed: 1.50s, accuracy: 96.12
# Epoch 158:	########################################	elapsed: 1.51s, accuracy: 96.21
# Epoch 159:	########################################	elapsed: 1.51s, accuracy: 96.12
# Epoch 160:	########################################	elapsed: 1.50s, accuracy: 96.20
# Epoch 161:	########################################	elapsed: 1.52s, accuracy: 96.24
# Epoch 162:	########################################	elapsed: 1.50s, accuracy: 96.34
# Epoch 163:	########################################	elapsed: 1.53s, accuracy: 96.30
# Epoch 164:	########################################	elapsed: 1.50s, accuracy: 96.18
# Epoch 165:	########################################	elapsed: 1.51s, accuracy: 96.17
# Epoch 166:	########################################	elapsed: 1.51s, accuracy: 96.08
# Epoch 167:	########################################	elapsed: 1.54s, accuracy: 96.14
# Epoch 168:	########################################	elapsed: 1.51s, accuracy: 96.13
# Epoch 169:	########################################	elapsed: 1.50s, accuracy: 96.06
# Epoch 170:	########################################	elapsed: 1.51s, accuracy: 96.11
# Epoch 171:	########################################	elapsed: 1.48s, accuracy: 96.24
# Epoch 172:	########################################	elapsed: 1.44s, accuracy: 96.23
# Epoch 173:	########################################	elapsed: 1.48s, accuracy: 96.28
# Epoch 174:	########################################	elapsed: 1.44s, accuracy: 96.27
# Epoch 175:	########################################	elapsed: 1.41s, accuracy: 96.26
# Epoch 176:	########################################	elapsed: 1.51s, accuracy: 96.26
# Epoch 177:	########################################	elapsed: 1.40s, accuracy: 96.26
# Epoch 178:	########################################	elapsed: 1.42s, accuracy: 96.24
# Epoch 179:	########################################	elapsed: 1.42s, accuracy: 96.28
# Epoch 180:	########################################	elapsed: 1.42s, accuracy: 96.28
# Epoch 181:	########################################	elapsed: 1.41s, accuracy: 96.35
# Epoch 182:	########################################	elapsed: 1.44s, accuracy: 96.36
# Epoch 183:	########################################	elapsed: 1.44s, accuracy: 96.32
# Epoch 184:	########################################	elapsed: 1.42s, accuracy: 96.32
# Epoch 185:	########################################	elapsed: 1.47s, accuracy: 96.26
# Epoch 186:	########################################	elapsed: 1.61s, accuracy: 96.30
# Epoch 187:	########################################	elapsed: 1.55s, accuracy: 96.36
# Epoch 188:	########################################	elapsed: 1.44s, accuracy: 96.39
# Epoch 189:	########################################	elapsed: 1.42s, accuracy: 96.29
# Epoch 190:	########################################	elapsed: 1.42s, accuracy: 96.37
# Epoch 191:	########################################	elapsed: 1.41s, accuracy: 96.35
# Epoch 192:	########################################	elapsed: 1.42s, accuracy: 96.28
# Epoch 193:	########################################	elapsed: 1.41s, accuracy: 96.27
# Epoch 194:	########################################	elapsed: 1.43s, accuracy: 96.23
# Epoch 195:	########################################	elapsed: 1.41s, accuracy: 96.32
# Epoch 196:	########################################	elapsed: 1.42s, accuracy: 96.28
# Epoch 197:	########################################	elapsed: 1.40s, accuracy: 96.25
# Epoch 198:	########################################	elapsed: 1.43s, accuracy: 96.27
# Epoch 199:	########################################	elapsed: 1.40s, accuracy: 96.26
# Epoch 200:	########################################	elapsed: 1.42s, accuracy: 96.29
# Training finished!
# <h3>Input layer filters in MLP</h3>
# <h3>Largest norms of weight-vectors in MLP layers</h3>
# 	layer 1: 1.00
# 	layer 2: 1.00
# 	layer 3: 4.00

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import mkl

mkl.set_num_threads(4)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def as_matrix(vector):
    return np.reshape(vector, (-1, 1))

def one_hot_encode(labels):
    one_hot = zeros(labels.shape[0], np.max(labels) + 1) 
    one_hot[np.arange(labels.shape[0]), labels] = 1
    return one_hot.astype(np.float32)

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

# %% [markdown]
# ### Activation functions

# %%
def sigmoid(batch):
    return 1.0 / (1.0 + np.exp(-batch))

def sigmoid_derivative(batch):
    s = sigmoid(batch)
    return s * (1.0 - s)

# %% [markdown]
# # MNIST dataset

# %%
import mnist
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # Part 1: $L^1$ and $L^2$ penalties

# %%
class Rbm:
    def __init__(self, visible_size, hidden_size, learning_rate, momentum, l1_penalty, l2_penalty):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.l1_penalty = l1_penalty
        self.l2_penalty = l2_penalty
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.M = zeros(self.visible_size+1, self.hidden_size+1)

# %%
def reconstuction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    hidden[:, :-1] = (sigmoid(minibatch @ rbm.W[:, :-1]) > rand(observations_count, rbm.hidden_size)).astype(np.float32)
    visible = sigmoid(hidden @ rbm.W.T[:, :-1])
    
    error = np.sum(np.power(visible - minibatch[:, :-1], 2))/observations_count

    return error

# %%
def train_epoch(rbm, dataset, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(rbm, batch)
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")

def run_training(rbm, dataset, monitoring_set, batch_size, epochs_count):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch+1),  end="\t")
        
        if epoch == 5:
            rbm.momentum = 0.8

        start_time = time.time()
        train_epoch(rbm, dataset, batch_size)
        elapsed = time.time() - start_time
        
        error = reconstuction_error(rbm, monitoring_set)
        print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

    print("Training finished!")

def draw_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# ### CDK with regulatization
#
# Implement the Contrastive Divergence algorithm with $L^1$ and $L^2$ penalties. If
# ```python
# rbm.l1_penalty > 0
# ```
# the algorithm should constrain the weights with $L^1$ penalty. Otherwise, if
# ```python
# rbm.l2_penalty > 0
# ```
# the algorithm should constrain the weights with $L^2$ penalty.
#
# Do **not** apply the penalties to the biases!

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]
    
    positive_visible = minibatch
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    positive_hidden[:, :-1] = sigmoid(positive_visible @ rbm.W[:, :-1])
    positive_gradient = (positive_visible.T @ positive_hidden)
    
    negative_hidden[:, :-1] = (positive_hidden[:, :-1] > rand(observations_count, rbm.hidden_size)).astype(np.float32)
    for i in range(k):
        negative_visible[:, :-1] = (sigmoid(negative_hidden @ rbm.W.T[:, :-1]) > rand(observations_count, rbm.visible_size)).astype(np.float32)
        if i == k-1:
            negative_hidden[:, :-1] = sigmoid(negative_visible @ rbm.W[:, :-1])
        else:
            negative_hidden[:, :-1] = (sigmoid(negative_visible @ rbm.W[:, :-1]) > rand(observations_count, rbm.hidden_size)).astype(np.float32)

    negative_gradient = (negative_visible.T @ negative_hidden)
    gradient = positive_gradient - negative_gradient
    
    if rbm.l1_penalty > 0:
        gradient[:-1, :-1] += rbm.l1_penalty * np.sign(rbm.W[:-1, :-1])
    if rbm.l2_penalty > 0:
        gradient[:-1, :-1] += rbm.l2_penalty * rbm.W[:-1, :-1]
        
    rbm.M = (rbm.momentum * rbm.M) + rbm.learning_rate*(gradient / observations_count)
    rbm.W = rbm.W + rbm.M

# %% [markdown]
# ## Comparison of regularization penalties

# %%
DATASET_SIZE = 20000 # 60000 for whole dataset
DIGIT_SIZE = 28

VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 128

mnist_train = mnist.train_images().astype(np.float32) / 255.0
np.random.shuffle(mnist_train)
dataset = np.reshape(mnist_train[:DATASET_SIZE], newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
dataset = append_ones(dataset)

monitoring_indeces = np.random.choice(DATASET_SIZE, 256, replace=False)
monitoring_set = dataset[monitoring_indeces]

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
MOMENTUM = 0.5

# %% [markdown]
# ### RBM with no regularization

# %%
L1_PENALTY = 0.0
L2_PENALTY = 0.0

np.random.seed(1234)
rbm_plain = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM, L1_PENALTY, L2_PENALTY)

run_training(rbm_plain, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT)
# Out:
# Epoch 1:	########################################	elapsed: 0.81s, reconstruction error: 25.56
# Epoch 2:	########################################	elapsed: 0.73s, reconstruction error: 20.39
# Epoch 3:	########################################	elapsed: 0.68s, reconstruction error: 18.09
# Epoch 4:	########################################	elapsed: 1.03s, reconstruction error: 16.54
# Epoch 5:	########################################	elapsed: 0.91s, reconstruction error: 15.59
# Epoch 6:	########################################	elapsed: 0.69s, reconstruction error: 14.58
# Epoch 7:	########################################	elapsed: 0.72s, reconstruction error: 13.66
# Epoch 8:	########################################	elapsed: 0.73s, reconstruction error: 13.30
# Epoch 9:	########################################	elapsed: 0.79s, reconstruction error: 12.71
# Epoch 10:	########################################	elapsed: 0.84s, reconstruction error: 12.09
# Epoch 11:	########################################	elapsed: 0.86s, reconstruction error: 11.77
# Epoch 12:	########################################	elapsed: 1.06s, reconstruction error: 11.68
# Epoch 13:	########################################	elapsed: 0.82s, reconstruction error: 11.47
# Epoch 14:	########################################	elapsed: 0.74s, reconstruction error: 11.28
# Epoch 15:	########################################	elapsed: 0.72s, reconstruction error: 11.14
# Epoch 16:	########################################	elapsed: 0.73s, reconstruction error: 11.10
# Epoch 17:	########################################	elapsed: 0.72s, reconstruction error: 10.96
# Epoch 18:	########################################	elapsed: 0.70s, reconstruction error: 10.75
# Epoch 19:	########################################	elapsed: 0.72s, reconstruction error: 10.93
# Epoch 20:	########################################	elapsed: 0.75s, reconstruction error: 10.72
# Epoch 21:	########################################	elapsed: 0.80s, reconstruction error: 10.65
# Epoch 22:	########################################	elapsed: 0.71s, reconstruction error: 10.56
# Epoch 23:	########################################	elapsed: 0.72s, reconstruction error: 10.35
# Epoch 24:	########################################	elapsed: 0.72s, reconstruction error: 10.41
# Epoch 25:	########################################	elapsed: 0.74s, reconstruction error: 10.41
# Epoch 26:	########################################	elapsed: 0.75s, reconstruction error: 10.36
# Epoch 27:	########################################	elapsed: 0.72s, reconstruction error: 10.32
# Epoch 28:	########################################	elapsed: 0.73s, reconstruction error: 10.28
# Epoch 29:	########################################	elapsed: 0.81s, reconstruction error: 10.30
# Epoch 30:	########################################	elapsed: 0.73s, reconstruction error: 10.11
# Epoch 31:	########################################	elapsed: 0.73s, reconstruction error: 10.10
# Epoch 32:	########################################	elapsed: 0.76s, reconstruction error: 9.97
# Epoch 33:	########################################	elapsed: 0.85s, reconstruction error: 10.05
# Epoch 34:	########################################	elapsed: 1.15s, reconstruction error: 9.97
# Epoch 35:	########################################	elapsed: 0.74s, reconstruction error: 9.96
# Epoch 36:	########################################	elapsed: 1.12s, reconstruction error: 9.95
# Epoch 37:	########################################	elapsed: 0.77s, reconstruction error: 10.06
# Epoch 38:	########################################	elapsed: 1.37s, reconstruction error: 10.00
# Epoch 39:	########################################	elapsed: 1.36s, reconstruction error: 9.93
# Epoch 40:	########################################	elapsed: 1.43s, reconstruction error: 9.84
# Epoch 41:	########################################	elapsed: 0.76s, reconstruction error: 9.74
# Epoch 42:	########################################	elapsed: 0.75s, reconstruction error: 9.84
# Epoch 43:	########################################	elapsed: 0.85s, reconstruction error: 9.85
# Epoch 44:	########################################	elapsed: 0.75s, reconstruction error: 9.74
# Epoch 45:	########################################	elapsed: 0.76s, reconstruction error: 9.84
# Epoch 46:	########################################	elapsed: 0.80s, reconstruction error: 9.92
# Epoch 47:	########################################	elapsed: 0.74s, reconstruction error: 9.69
# Epoch 48:	########################################	elapsed: 0.75s, reconstruction error: 9.88
# Epoch 49:	########################################	elapsed: 0.84s, reconstruction error: 9.85
# Epoch 50:	########################################	elapsed: 0.74s, reconstruction error: 9.76
# Training finished!

# %% [markdown]
# ### RBM with $L^1$ penalty

# %%
L1_PENALTY = 0.0001
L2_PENALTY = 0.0

np.random.seed(1234)
rbm_l1 = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM, L1_PENALTY, L2_PENALTY)

run_training(rbm_l1, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT)
# Out:
# Epoch 1:	########################################	elapsed: 1.02s, reconstruction error: 25.52
# Epoch 2:	########################################	elapsed: 1.28s, reconstruction error: 20.38
# Epoch 3:	########################################	elapsed: 1.58s, reconstruction error: 18.09
# Epoch 4:	########################################	elapsed: 1.17s, reconstruction error: 16.51
# Epoch 5:	########################################	elapsed: 0.81s, reconstruction error: 15.62
# Epoch 6:	########################################	elapsed: 0.87s, reconstruction error: 14.48
# Epoch 7:	########################################	elapsed: 1.02s, reconstruction error: 13.63
# Epoch 8:	########################################	elapsed: 0.83s, reconstruction error: 13.29
# Epoch 9:	########################################	elapsed: 0.85s, reconstruction error: 12.67
# Epoch 10:	########################################	elapsed: 1.21s, reconstruction error: 12.15
# Epoch 11:	########################################	elapsed: 1.00s, reconstruction error: 11.78
# Epoch 12:	########################################	elapsed: 0.92s, reconstruction error: 11.81
# Epoch 13:	########################################	elapsed: 1.05s, reconstruction error: 11.32
# Epoch 14:	########################################	elapsed: 0.93s, reconstruction error: 11.27
# Epoch 15:	########################################	elapsed: 0.82s, reconstruction error: 11.19
# Epoch 16:	########################################	elapsed: 0.85s, reconstruction error: 11.09
# Epoch 17:	########################################	elapsed: 0.83s, reconstruction error: 11.01
# Epoch 18:	########################################	elapsed: 0.84s, reconstruction error: 10.78
# Epoch 19:	########################################	elapsed: 0.80s, reconstruction error: 10.89
# Epoch 20:	########################################	elapsed: 0.82s, reconstruction error: 10.64
# Epoch 21:	########################################	elapsed: 0.81s, reconstruction error: 10.75
# Epoch 22:	########################################	elapsed: 0.86s, reconstruction error: 10.55
# Epoch 23:	########################################	elapsed: 0.81s, reconstruction error: 10.42
# Epoch 24:	########################################	elapsed: 0.87s, reconstruction error: 10.59
# Epoch 25:	########################################	elapsed: 0.81s, reconstruction error: 10.43
# Epoch 26:	########################################	elapsed: 0.87s, reconstruction error: 10.47
# Epoch 27:	########################################	elapsed: 0.81s, reconstruction error: 10.41
# Epoch 28:	########################################	elapsed: 0.89s, reconstruction error: 10.39
# Epoch 29:	########################################	elapsed: 0.99s, reconstruction error: 10.34
# Epoch 30:	########################################	elapsed: 0.84s, reconstruction error: 10.14
# Epoch 31:	########################################	elapsed: 0.81s, reconstruction error: 10.22
# Epoch 32:	########################################	elapsed: 0.82s, reconstruction error: 10.12
# Epoch 33:	########################################	elapsed: 0.86s, reconstruction error: 9.99
# Epoch 34:	########################################	elapsed: 0.85s, reconstruction error: 10.07
# Epoch 35:	########################################	elapsed: 0.82s, reconstruction error: 9.99
# Epoch 36:	########################################	elapsed: 0.89s, reconstruction error: 9.78
# Epoch 37:	########################################	elapsed: 0.83s, reconstruction error: 10.07
# Epoch 38:	########################################	elapsed: 0.85s, reconstruction error: 10.06
# Epoch 39:	########################################	elapsed: 0.85s, reconstruction error: 9.96
# Epoch 40:	########################################	elapsed: 0.91s, reconstruction error: 9.97
# Epoch 41:	########################################	elapsed: 0.84s, reconstruction error: 9.87
# Epoch 42:	########################################	elapsed: 0.85s, reconstruction error: 9.87
# Epoch 43:	########################################	elapsed: 0.88s, reconstruction error: 9.82
# Epoch 44:	########################################	elapsed: 0.88s, reconstruction error: 9.95
# Epoch 45:	########################################	elapsed: 0.91s, reconstruction error: 9.98
# Epoch 46:	########################################	elapsed: 0.83s, reconstruction error: 9.77
# Epoch 47:	########################################	elapsed: 0.86s, reconstruction error: 9.85
# Epoch 48:	########################################	elapsed: 0.91s, reconstruction error: 9.80
# Epoch 49:	########################################	elapsed: 0.84s, reconstruction error: 9.78
# Epoch 50:	########################################	elapsed: 0.89s, reconstruction error: 9.88
# Training finished!

# %% [markdown]
# ### RBM with $L^2$ penalty

# %%
L1_PENALTY = 0.0
L2_PENALTY = 0.0005

np.random.seed(1234)
rbm_l2 = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM, L1_PENALTY, L2_PENALTY)

run_training(rbm_l2, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT)
# Out:
# Epoch 1:	########################################	elapsed: 0.85s, reconstruction error: 25.57
# Epoch 2:	########################################	elapsed: 0.74s, reconstruction error: 20.36
# Epoch 3:	########################################	elapsed: 0.72s, reconstruction error: 18.10
# Epoch 4:	########################################	elapsed: 0.71s, reconstruction error: 16.49
# Epoch 5:	########################################	elapsed: 0.71s, reconstruction error: 15.65
# Epoch 6:	########################################	elapsed: 0.71s, reconstruction error: 14.60
# Epoch 7:	########################################	elapsed: 0.72s, reconstruction error: 13.71
# Epoch 8:	########################################	elapsed: 0.74s, reconstruction error: 13.25
# Epoch 9:	########################################	elapsed: 0.70s, reconstruction error: 12.63
# Epoch 10:	########################################	elapsed: 0.73s, reconstruction error: 12.20
# Epoch 11:	########################################	elapsed: 0.73s, reconstruction error: 11.83
# Epoch 12:	########################################	elapsed: 0.73s, reconstruction error: 11.79
# Epoch 13:	########################################	elapsed: 0.71s, reconstruction error: 11.44
# Epoch 14:	########################################	elapsed: 0.75s, reconstruction error: 11.28
# Epoch 15:	########################################	elapsed: 0.76s, reconstruction error: 11.10
# Epoch 16:	########################################	elapsed: 0.71s, reconstruction error: 11.15
# Epoch 17:	########################################	elapsed: 0.72s, reconstruction error: 10.94
# Epoch 18:	########################################	elapsed: 0.72s, reconstruction error: 10.81
# Epoch 19:	########################################	elapsed: 0.71s, reconstruction error: 10.99
# Epoch 20:	########################################	elapsed: 0.75s, reconstruction error: 10.68
# Epoch 21:	########################################	elapsed: 0.72s, reconstruction error: 10.80
# Epoch 22:	########################################	elapsed: 0.72s, reconstruction error: 10.57
# Epoch 23:	########################################	elapsed: 0.72s, reconstruction error: 10.42
# Epoch 24:	########################################	elapsed: 0.74s, reconstruction error: 10.51
# Epoch 25:	########################################	elapsed: 0.72s, reconstruction error: 10.34
# Epoch 26:	########################################	elapsed: 0.72s, reconstruction error: 10.40
# Epoch 27:	########################################	elapsed: 0.74s, reconstruction error: 10.34
# Epoch 28:	########################################	elapsed: 0.76s, reconstruction error: 10.30
# Epoch 29:	########################################	elapsed: 0.76s, reconstruction error: 10.36
# Epoch 30:	########################################	elapsed: 0.73s, reconstruction error: 10.17
# Epoch 31:	########################################	elapsed: 0.71s, reconstruction error: 10.14
# Epoch 32:	########################################	elapsed: 0.75s, reconstruction error: 10.08
# Epoch 33:	########################################	elapsed: 0.72s, reconstruction error: 10.06
# Epoch 34:	########################################	elapsed: 0.73s, reconstruction error: 10.11
# Epoch 35:	########################################	elapsed: 0.71s, reconstruction error: 9.96
# Epoch 36:	########################################	elapsed: 0.75s, reconstruction error: 10.06
# Epoch 37:	########################################	elapsed: 0.73s, reconstruction error: 10.05
# Epoch 38:	########################################	elapsed: 0.74s, reconstruction error: 9.95
# Epoch 39:	########################################	elapsed: 0.72s, reconstruction error: 9.94
# Epoch 40:	########################################	elapsed: 0.73s, reconstruction error: 9.88
# Epoch 41:	########################################	elapsed: 0.77s, reconstruction error: 9.83
# Epoch 42:	########################################	elapsed: 0.76s, reconstruction error: 9.80
# Epoch 43:	########################################	elapsed: 0.72s, reconstruction error: 9.78
# Epoch 44:	########################################	elapsed: 0.76s, reconstruction error: 9.81
# Epoch 45:	########################################	elapsed: 1.05s, reconstruction error: 9.91
# Epoch 46:	########################################	elapsed: 1.03s, reconstruction error: 9.86
# Epoch 47:	########################################	elapsed: 0.98s, reconstruction error: 9.72
# Epoch 48:	########################################	elapsed: 1.45s, reconstruction error: 9.74
# Epoch 49:	########################################	elapsed: 1.34s, reconstruction error: 9.73
# Epoch 50:	########################################	elapsed: 0.84s, reconstruction error: 9.91
# Training finished!

# %% [markdown]
# ### Plain filters

# %%
draw_filters(rbm_plain)

# %% [markdown]
# ### $L^1$ filters

# %%
draw_filters(rbm_l1)

# %% [markdown]
# ### $L^2$ filters

# %%
draw_filters(rbm_l2)

# %% [markdown]
# # Part 2: MLP pretraining

# %%
def softmax(z):
    z = z - np.expand_dims(np.max(z, axis = 1), 1)
    return np.exp(z) / np.expand_dims(np.exp(z).sum(axis=1), 1)

# %%
class Layer:
    def __init__(self, visible_size, hidden_size, activation_fun, d_activation_fun, 
                 learning_rate, momentum, l2_penalty):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.activation_fun = activation_fun
        self.d_activation_fun = d_activation_fun
                
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.l2_penalty = l2_penalty
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size)).astype(np.float32)
        self.W[-1, :] = 0.0
        
        self.activations = None
        self.d_activations = None
        self.deltas = None

        self.M = zeros(self.visible_size+1, self.hidden_size)

# %% [markdown]
# ### Forward pass

# %%
def forward_pass(mlp, batch, compute_derivatives):
    visible = batch
    
    for layer_idx, layer in enumerate(mlp):
        z = visible @ layer.W
        layer.activations = append_ones(layer.activation_fun(z))
        
        if compute_derivatives and (layer_idx < len(mlp) - 1):
            layer.d_activations = layer.d_activation_fun(z)
        
        visible = layer.activations
        
    return visible[:, :-1]

# %% [markdown]
# ### Error backpropagation
#
# Extend the implementation of error backpropagation (from Lab 6) with $L^2$ penalty. Apply the penalty when:
# ```python
# rbm.l2_penalty > 0
# ```
#
# Do **not** apply the penalty to the biases.

# %%
def error_backpropagate(mlp, batch):
    observations_count = batch.shape[0]
    
    for layer_idx, layer in reversed(list(enumerate(mlp))):
        if layer_idx > 0:
            prev_layer = mlp[layer_idx - 1]
            visible = prev_layer.activations
            prev_layer.deltas = layer.deltas @ layer.W[:-1, :].T * prev_layer.d_activations
        else:
            visible = batch
        
        gradient = visible.T @ layer.deltas
        if layer.l2_penalty > 0 and layer_idx != len(mlp)-1:
            gradient[:-1, :] += layer.l2_penalty * layer.W[:-1, :]
            
        layer.M = layer.momentum * layer.M - layer.learning_rate * (gradient) / observations_count
        layer.W += layer.M

# %% [markdown]
# ### MLP training

# %%
def train_mlp(mlp, dataset, labels, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    
    batched_data = chunks(dataset, batch_size)
    batched_labels = chunks(labels, batch_size)
    
    for batch_idx, (batch, batch_labels) in enumerate(zip(batched_data, batched_labels)):
        # Forward pass: compute activatations and derivatives of activations
        y = forward_pass(mlp, batch, True)
        
        mlp[-1].deltas = y - batch_labels
        
        # Once softmax deltas are set, we may backpropagate errors
        error_backpropagate(mlp, batch)
        
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

# %%
def classify(mlp, batch):
    probabilities = forward_pass(mlp, batch, False)
    return np.argmax(probabilities, axis=1)

def run_mlp_training(mlp, train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count):
    
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch+1),  end="\t")
        
        if epoch == 5:
            for layer in mlp: layer.momentum = 0.9
        
        start_time = time.time()
        train_mlp(mlp, train_set, train_labels, batch_size)
        elapsed = time.time() - start_time

        predictions = classify(mlp, validation_set)
        accuracy = 100.0 * np.sum(predictions == validation_labels) / predictions.shape[0]
        print("\telapsed: {0:>2.2f}s, accuracy: {1:>2.2f}".format(elapsed, accuracy))

    print("Training finished!")
    
def draw_layer_filters(layer):
    filters = np.reshape(layer.W[:-1].T, newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# ## DBN Pretraining

# %%
def propagate_up(dbn, layers_count, visible):
    for i in range(layers_count):
        visible = append_ones(sigmoid(visible @ dbn[i].W[:, :-1]))
    return visible

def propagate_down(dbn, layers_count, hidden):
    for i in reversed(range(layers_count)):
        hidden = append_ones(sigmoid(hidden @ np.transpose(dbn[i].W[:-1, :])))
    return hidden

# %%
def dbn_reconstuction_error(dbn, layers_count, minibatch):
    visible = propagate_up(dbn, layers_count, minibatch)
    error = reconstuction_error(dbn[layers_count], visible)
    
    return error

# %%
def train_dbn_layer(dbn, layer_idx, dataset, batch_size):
    dataset = propagate_up(dbn, layer_idx, dataset)
    
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(dbn[layer_idx], batch)
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

# %%
def train_dbn(dbn, dataset, monitoring_set, batch_size, epochs_count):
    for layer_idx in range(len(dbn)):
        print("\nLearning layer {}".format(layer_idx))
        
        for epoch in range(epochs_count):
            print("Epoch {}:".format(epoch+1),  end="\t")

            if epoch == 5:
                dbn[layer_idx].momentum = 0.9

            start_time = time.time()
            train_dbn_layer(dbn, layer_idx, dataset, batch_size)
            elapsed = time.time() - start_time

            error = dbn_reconstuction_error(dbn, layer_idx, monitoring_set)
            print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

# %% [markdown]
# ##  Initializing MLP with DBN weights
#
# Implement initialization of MLP weights (and biases) using weights (and biases) from the DBN layers.
#
# Make sure that the MLP weights (and biases) are **copies** of the DBN weights (and biases). You can use ```np.copy(...)``` function to copy the weights (simple assignment will make a view instead of a copy).

# %%
def initialize_mlp(mlp, dbn):
    for i in range(len(mlp)-1):
        mlp[i].W = np.copy(dbn[i].W[:, :-1])

# %% [markdown]
# # MNIST digits classification

# %%
np.random.seed(1234)

DATASET_SIZE = 10000 # 60000 for whole dataset
DIGIT_SIZE = 28

##### Train set #####

mnist_train_images = mnist.train_images().astype(np.float32) / 255.0
mnist_train_labels = mnist.train_labels()

order = np.random.permutation(len(mnist_train_images))
mnist_train_images = mnist_train_images[order]
mnist_train_labels = mnist_train_labels[order]

mnist_train_images = np.reshape(mnist_train_images[:DATASET_SIZE],
                                newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
mnist_train_images = append_ones(mnist_train_images)

mnist_train_labels = mnist_train_labels[:DATASET_SIZE]
mnist_train_labels = one_hot_encode(mnist_train_labels)

monitoring_set_indeces = np.random.choice(mnist_train_images.shape[0], 512, replace=False)
monitoring_set = mnist_train_images[monitoring_set_indeces]

##### Test set #####

mnist_test_images = mnist.test_images().astype(np.float32) / 255.0
mnist_test_images = np.reshape(mnist_test_images, newshape=(-1, DIGIT_SIZE*DIGIT_SIZE))
mnist_test_images = append_ones(mnist_test_images)

mnist_test_labels = mnist.test_labels()

# %% [markdown]
# ### Plain vs pretrained MLP comparison

# %%
from IPython.core.display import HTML

def compare_pretraining_results(mlp, dbn,
                                train_set, train_labels,
                                validation_set, validation_labels,
                                monitoring_set,
                                batch_size, epochs_count):
    for layer in mlp:
        layer.reset()

    display(HTML('<h3>Plain MLP training</h3>'))
    run_mlp_training(mlp,
                     train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count)
    
    display(HTML('<h3>Input layer filters in the plain MLP</h3>'))
    draw_layer_filters(mlp[0])
    
    display(HTML('<h3>DBN training</h3>'))
    train_dbn(dbn, train_set, monitoring_set, batch_size, epochs_count)
    
    for layer in mlp:
        layer.reset()
    
    initialize_mlp(mlp, dbn)
    
    display(HTML('<h3>Finetuning pretrained MLP</h3>'))
    run_mlp_training(mlp,
                     train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count)
    
    display(HTML('<h3>First layer filters in the DBN</h3>'))
    draw_filters(dbn[0])
    
    display(HTML('<h3>Input layer filters in the pretrained & finetuned MLP</h3>'))
    draw_layer_filters(mlp[0])

# %%
VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 256

BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
SOFTMAX_LEARNING_RATE = 0.15
MOMENTUM = 0.5
L2_PENALTY = 0.00002

# %% [markdown]
# ### Shallow neural network

# %%
shallow_mlp = [
    Layer(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, sigmoid_derivative, LEARNING_RATE, MOMENTUM, L2_PENALTY),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, sigmoid_derivative, LEARNING_RATE, MOMENTUM, L2_PENALTY),
    Layer(HIDDEN_LAYER_SIZE, 10, softmax, None, SOFTMAX_LEARNING_RATE, MOMENTUM, L2_PENALTY)
]

shallow_dbn = [
    Rbm(mlp_layer.visible_size,
        mlp_layer.hidden_size,
        LEARNING_RATE, MOMENTUM, 0.0, L2_PENALTY) for mlp_layer in shallow_mlp[:-1]
]

compare_pretraining_results(shallow_mlp, shallow_dbn,
                            mnist_train_images, mnist_train_labels,
                            mnist_test_images, mnist_test_labels,
                            monitoring_set,
                            BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>Plain MLP training</h3>
# Epoch 1:	########################################	elapsed: 0.40s, accuracy: 10.10
# Epoch 2:	########################################	elapsed: 0.32s, accuracy: 10.10
# Epoch 3:	########################################	elapsed: 0.52s, accuracy: 8.92
# Epoch 4:	########################################	elapsed: 0.39s, accuracy: 8.92
# Epoch 5:	########################################	elapsed: 0.37s, accuracy: 11.35
# Epoch 6:	########################################	elapsed: 0.32s, accuracy: 14.85
# Epoch 7:	########################################	elapsed: 0.38s, accuracy: 27.38
# Epoch 8:	########################################	elapsed: 0.35s, accuracy: 31.59
# Epoch 9:	########################################	elapsed: 0.39s, accuracy: 31.59
# Epoch 10:	########################################	elapsed: 0.37s, accuracy: 48.48
# Epoch 11:	########################################	elapsed: 0.50s, accuracy: 57.63
# Epoch 12:	########################################	elapsed: 0.36s, accuracy: 65.68
# Epoch 13:	########################################	elapsed: 0.37s, accuracy: 79.77
# Epoch 14:	########################################	elapsed: 0.36s, accuracy: 83.39
# Epoch 15:	########################################	elapsed: 0.36s, accuracy: 85.21
# Epoch 16:	########################################	elapsed: 0.34s, accuracy: 87.11
# Epoch 17:	########################################	elapsed: 0.39s, accuracy: 88.71
# Epoch 18:	########################################	elapsed: 0.33s, accuracy: 89.67
# Epoch 19:	########################################	elapsed: 0.38s, accuracy: 90.31
# Epoch 20:	########################################	elapsed: 0.37s, accuracy: 91.00
# Epoch 21:	########################################	elapsed: 0.48s, accuracy: 91.38
# Epoch 22:	########################################	elapsed: 0.48s, accuracy: 91.81
# Epoch 23:	########################################	elapsed: 0.32s, accuracy: 92.07
# Epoch 24:	########################################	elapsed: 0.34s, accuracy: 92.28
# Epoch 25:	########################################	elapsed: 0.33s, accuracy: 92.42
# Epoch 26:	########################################	elapsed: 0.32s, accuracy: 92.55
# Epoch 27:	########################################	elapsed: 0.41s, accuracy: 92.69
# Epoch 28:	########################################	elapsed: 0.58s, accuracy: 92.89
# Epoch 29:	########################################	elapsed: 0.36s, accuracy: 93.12
# Epoch 30:	########################################	elapsed: 0.56s, accuracy: 93.28
# Epoch 31:	########################################	elapsed: 0.48s, accuracy: 93.42
# Epoch 32:	########################################	elapsed: 0.36s, accuracy: 93.55
# Epoch 33:	########################################	elapsed: 0.35s, accuracy: 93.66
# Epoch 34:	########################################	elapsed: 0.38s, accuracy: 93.61
# Epoch 35:	########################################	elapsed: 0.39s, accuracy: 93.67
# Epoch 36:	########################################	elapsed: 0.39s, accuracy: 93.63
# Epoch 37:	########################################	elapsed: 0.35s, accuracy: 93.71
# Epoch 38:	########################################	elapsed: 0.40s, accuracy: 93.64
# Epoch 39:	########################################	elapsed: 0.37s, accuracy: 93.55
# Epoch 40:	########################################	elapsed: 0.38s, accuracy: 93.44
# Epoch 41:	########################################	elapsed: 0.36s, accuracy: 93.39
# Epoch 42:	########################################	elapsed: 0.39s, accuracy: 93.25
# Epoch 43:	########################################	elapsed: 0.34s, accuracy: 93.12
# Epoch 44:	########################################	elapsed: 0.35s, accuracy: 93.00
# Epoch 45:	########################################	elapsed: 0.40s, accuracy: 93.00
# Epoch 46:	########################################	elapsed: 0.42s, accuracy: 93.30
# Epoch 47:	########################################	elapsed: 0.42s, accuracy: 93.57
# Epoch 48:	########################################	elapsed: 0.41s, accuracy: 93.59
# Epoch 49:	########################################	elapsed: 0.38s, accuracy: 93.56
# Epoch 50:	########################################	elapsed: 0.38s, accuracy: 93.51
# Training finished!
# <h3>Input layer filters in the plain MLP</h3>
# <h3>DBN training</h3>
# Learning layer 0
# Epoch 1:	########################################	elapsed: 0.81s, reconstruction error: 31.14
# Epoch 2:	########################################	elapsed: 0.64s, reconstruction error: 24.39
# Epoch 3:	########################################	elapsed: 0.61s, reconstruction error: 21.05
# Epoch 4:	########################################	elapsed: 0.62s, reconstruction error: 19.30
# Epoch 5:	########################################	elapsed: 0.76s, reconstruction error: 17.59
# Epoch 6:	########################################	elapsed: 1.19s, reconstruction error: 15.30
# Epoch 7:	########################################	elapsed: 0.61s, reconstruction error: 13.43
# Epoch 8:	########################################	elapsed: 0.83s, reconstruction error: 12.53
# Epoch 9:	########################################	elapsed: 0.67s, reconstruction error: 11.70
# Epoch 10:	########################################	elapsed: 0.66s, reconstruction error: 11.39
# Epoch 11:	########################################	elapsed: 0.63s, reconstruction error: 10.90
# Epoch 12:	########################################	elapsed: 0.73s, reconstruction error: 10.63
# Epoch 13:	########################################	elapsed: 0.63s, reconstruction error: 10.62
# Epoch 14:	########################################	elapsed: 0.82s, reconstruction error: 10.28
# Epoch 15:	########################################	elapsed: 0.63s, reconstruction error: 9.93
# Epoch 16:	########################################	elapsed: 0.64s, reconstruction error: 9.95
# Epoch 17:	########################################	elapsed: 0.70s, reconstruction error: 9.90
# Epoch 18:	########################################	elapsed: 1.13s, reconstruction error: 9.90
# Epoch 19:	########################################	elapsed: 0.75s, reconstruction error: 9.76
# Epoch 20:	########################################	elapsed: 0.67s, reconstruction error: 9.60
# Epoch 21:	########################################	elapsed: 0.65s, reconstruction error: 9.47
# Epoch 22:	########################################	elapsed: 0.62s, reconstruction error: 9.24
# Epoch 23:	########################################	elapsed: 0.75s, reconstruction error: 9.37
# Epoch 24:	########################################	elapsed: 0.70s, reconstruction error: 9.53
# Epoch 25:	########################################	elapsed: 0.66s, reconstruction error: 9.39
# Epoch 26:	########################################	elapsed: 0.62s, reconstruction error: 9.10
# Epoch 27:	########################################	elapsed: 0.65s, reconstruction error: 9.17
# Epoch 28:	########################################	elapsed: 0.78s, reconstruction error: 9.16
# Epoch 29:	########################################	elapsed: 0.65s, reconstruction error: 9.05
# Epoch 30:	########################################	elapsed: 0.67s, reconstruction error: 8.97
# Epoch 31:	########################################	elapsed: 0.68s, reconstruction error: 8.99
# Epoch 32:	########################################	elapsed: 0.66s, reconstruction error: 8.93
# Epoch 33:	########################################	elapsed: 0.63s, reconstruction error: 9.04
# Epoch 34:	########################################	elapsed: 0.65s, reconstruction error: 9.02
# Epoch 35:	########################################	elapsed: 0.66s, reconstruction error: 8.94
# Epoch 36:	########################################	elapsed: 0.66s, reconstruction error: 8.94
# Epoch 37:	########################################	elapsed: 0.80s, reconstruction error: 8.84
# Epoch 38:	########################################	elapsed: 0.79s, reconstruction error: 8.83
# Epoch 39:	########################################	elapsed: 0.71s, reconstruction error: 8.89
# Epoch 40:	########################################	elapsed: 0.62s, reconstruction error: 8.73
# Epoch 41:	########################################	elapsed: 1.08s, reconstruction error: 8.84
# Epoch 42:	########################################	elapsed: 0.77s, reconstruction error: 8.71
# Epoch 43:	########################################	elapsed: 0.66s, reconstruction error: 8.81
# Epoch 44:	########################################	elapsed: 0.65s, reconstruction error: 8.76
# Epoch 45:	########################################	elapsed: 0.72s, reconstruction error: 8.75
# Epoch 46:	########################################	elapsed: 0.86s, reconstruction error: 8.78
# Epoch 47:	########################################	elapsed: 0.81s, reconstruction error: 8.59
# Epoch 48:	########################################	elapsed: 0.67s, reconstruction error: 8.71
# Epoch 49:	########################################	elapsed: 0.65s, reconstruction error: 8.74
# Epoch 50:	########################################	elapsed: 0.65s, reconstruction error: 8.73
#
# Learning layer 1
# Epoch 1:	########################################	elapsed: 0.31s, reconstruction error: 19.10
# Epoch 2:	########################################	elapsed: 0.36s, reconstruction error: 14.70
# Epoch 3:	########################################	elapsed: 0.31s, reconstruction error: 12.60
# Epoch 4:	########################################	elapsed: 0.31s, reconstruction error: 11.21
# Epoch 5:	########################################	elapsed: 0.30s, reconstruction error: 10.19
# Epoch 6:	########################################	elapsed: 0.32s, reconstruction error: 8.49
# Epoch 7:	########################################	elapsed: 0.31s, reconstruction error: 7.24
# Epoch 8:	########################################	elapsed: 0.34s, reconstruction error: 6.71
# Epoch 9:	########################################	elapsed: 0.31s, reconstruction error: 6.14
# Epoch 10:	########################################	elapsed: 0.39s, reconstruction error: 5.82
# Epoch 11:	########################################	elapsed: 0.32s, reconstruction error: 5.57
# Epoch 12:	########################################	elapsed: 0.45s, reconstruction error: 5.49
# Epoch 13:	########################################	elapsed: 0.29s, reconstruction error: 5.25
# Epoch 14:	########################################	elapsed: 0.31s, reconstruction error: 5.17
# Epoch 15:	########################################	elapsed: 0.29s, reconstruction error: 5.03
# Epoch 16:	########################################	elapsed: 0.33s, reconstruction error: 4.82
# Epoch 17:	########################################	elapsed: 0.29s, reconstruction error: 4.82
# Epoch 18:	########################################	elapsed: 0.30s, reconstruction error: 4.73
# Epoch 19:	########################################	elapsed: 0.28s, reconstruction error: 4.72
# Epoch 20:	########################################	elapsed: 0.33s, reconstruction error: 4.60
# Epoch 21:	########################################	elapsed: 0.34s, reconstruction error: 4.55
# Epoch 22:	########################################	elapsed: 0.31s, reconstruction error: 4.58
# Epoch 23:	########################################	elapsed: 0.30s, reconstruction error: 4.49
# Epoch 24:	########################################	elapsed: 0.30s, reconstruction error: 4.52
# Epoch 25:	########################################	elapsed: 0.29s, reconstruction error: 4.46
# Epoch 26:	########################################	elapsed: 0.30s, reconstruction error: 4.46
# Epoch 27:	########################################	elapsed: 0.34s, reconstruction error: 4.36
# Epoch 28:	########################################	elapsed: 0.30s, reconstruction error: 4.29
# Epoch 29:	########################################	elapsed: 0.28s, reconstruction error: 4.35
# Epoch 30:	########################################	elapsed: 0.36s, reconstruction error: 4.20
# Epoch 31:	########################################	elapsed: 0.29s, reconstruction error: 4.27
# Epoch 32:	########################################	elapsed: 0.31s, reconstruction error: 4.18
# Epoch 33:	########################################	elapsed: 0.31s, reconstruction error: 4.27
# Epoch 34:	########################################	elapsed: 0.28s, reconstruction error: 4.27
# Epoch 35:	########################################	elapsed: 0.33s, reconstruction error: 4.22
# Epoch 36:	########################################	elapsed: 0.30s, reconstruction error: 4.20
# Epoch 37:	########################################	elapsed: 0.34s, reconstruction error: 4.18
# Epoch 38:	########################################	elapsed: 0.30s, reconstruction error: 4.20
# Epoch 39:	########################################	elapsed: 0.35s, reconstruction error: 4.13
# Epoch 40:	########################################	elapsed: 0.29s, reconstruction error: 4.15
# Epoch 41:	########################################	elapsed: 0.30s, reconstruction error: 4.15
# Epoch 42:	########################################	elapsed: 0.35s, reconstruction error: 4.13
# Epoch 43:	########################################	elapsed: 0.29s, reconstruction error: 4.08
# Epoch 44:	########################################	elapsed: 0.30s, reconstruction error: 4.13
# Epoch 45:	########################################	elapsed: 0.30s, reconstruction error: 3.99
# Epoch 46:	########################################	elapsed: 0.34s, reconstruction error: 4.03
# Epoch 47:	########################################	elapsed: 0.31s, reconstruction error: 4.09
# Epoch 48:	########################################	elapsed: 0.39s, reconstruction error: 4.08
# Epoch 49:	########################################	elapsed: 0.31s, reconstruction error: 4.00
# Epoch 50:	########################################	elapsed: 0.35s, reconstruction error: 4.04
# <h3>Finetuning pretrained MLP</h3>
# Epoch 1:	########################################	elapsed: 0.47s, accuracy: 93.55
# Epoch 2:	########################################	elapsed: 0.35s, accuracy: 94.81
# Epoch 3:	########################################	elapsed: 0.38s, accuracy: 95.32
# Epoch 4:	########################################	elapsed: 0.34s, accuracy: 95.65
# Epoch 5:	########################################	elapsed: 0.33s, accuracy: 95.80
# Epoch 6:	########################################	elapsed: 0.31s, accuracy: 96.01
# Epoch 7:	########################################	elapsed: 0.31s, accuracy: 96.12
# Epoch 8:	########################################	elapsed: 0.33s, accuracy: 96.26
# Epoch 9:	########################################	elapsed: 0.32s, accuracy: 96.39
# Epoch 10:	########################################	elapsed: 0.33s, accuracy: 96.44
# Epoch 11:	########################################	elapsed: 0.31s, accuracy: 96.52
# Epoch 12:	########################################	elapsed: 0.31s, accuracy: 96.59
# Epoch 13:	########################################	elapsed: 0.34s, accuracy: 96.57
# Epoch 14:	########################################	elapsed: 0.32s, accuracy: 96.57
# Epoch 15:	########################################	elapsed: 0.31s, accuracy: 96.63
# Epoch 16:	########################################	elapsed: 0.31s, accuracy: 96.65
# Epoch 17:	########################################	elapsed: 0.37s, accuracy: 96.65
# Epoch 18:	########################################	elapsed: 0.34s, accuracy: 96.64
# Epoch 19:	########################################	elapsed: 0.34s, accuracy: 96.69
# Epoch 20:	########################################	elapsed: 0.35s, accuracy: 96.64
# Epoch 21:	########################################	elapsed: 0.31s, accuracy: 96.67
# Epoch 22:	########################################	elapsed: 0.32s, accuracy: 96.68
# Epoch 23:	########################################	elapsed: 0.35s, accuracy: 96.72
# Epoch 24:	########################################	elapsed: 0.33s, accuracy: 96.73
# Epoch 25:	########################################	elapsed: 0.34s, accuracy: 96.74
# Epoch 26:	########################################	elapsed: 0.32s, accuracy: 96.73
# Epoch 27:	########################################	elapsed: 0.34s, accuracy: 96.74
# Epoch 28:	########################################	elapsed: 0.31s, accuracy: 96.75
# Epoch 29:	########################################	elapsed: 0.32s, accuracy: 96.76
# Epoch 30:	########################################	elapsed: 0.34s, accuracy: 96.76
# Epoch 31:	########################################	elapsed: 0.35s, accuracy: 96.77
# Epoch 32:	########################################	elapsed: 0.36s, accuracy: 96.80
# Epoch 33:	########################################	elapsed: 0.32s, accuracy: 96.82
# Epoch 34:	########################################	elapsed: 0.33s, accuracy: 96.83
# Epoch 35:	########################################	elapsed: 0.34s, accuracy: 96.83
# Epoch 36:	########################################	elapsed: 0.33s, accuracy: 96.83
# Epoch 37:	########################################	elapsed: 0.32s, accuracy: 96.82
# Epoch 38:	########################################	elapsed: 0.32s, accuracy: 96.83
# Epoch 39:	########################################	elapsed: 0.34s, accuracy: 96.85
# Epoch 40:	########################################	elapsed: 0.33s, accuracy: 96.84
# Epoch 41:	########################################	elapsed: 0.37s, accuracy: 96.85
# Epoch 42:	########################################	elapsed: 0.35s, accuracy: 96.85
# Epoch 43:	########################################	elapsed: 0.34s, accuracy: 96.86
# Epoch 44:	########################################	elapsed: 0.33s, accuracy: 96.86
# Epoch 45:	########################################	elapsed: 0.34s, accuracy: 96.87
# Epoch 46:	########################################	elapsed: 0.31s, accuracy: 96.88
# Epoch 47:	########################################	elapsed: 0.33s, accuracy: 96.91
# Epoch 48:	########################################	elapsed: 0.35s, accuracy: 96.92
# Epoch 49:	########################################	elapsed: 0.35s, accuracy: 96.93
# Epoch 50:	########################################	elapsed: 0.35s, accuracy: 96.93
# Training finished!
# <h3>First layer filters in the DBN</h3>
# <h3>Input layer filters in the pretrained & finetuned MLP</h3>

# %% [markdown]
# ### Deep neural network

# %%
deep_mlp = [
    Layer(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, sigmoid_derivative, LEARNING_RATE, MOMENTUM, L2_PENALTY),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, sigmoid_derivative, LEARNING_RATE, MOMENTUM, L2_PENALTY),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, sigmoid_derivative, LEARNING_RATE, MOMENTUM, L2_PENALTY),
    Layer(HIDDEN_LAYER_SIZE, 10, softmax, None, SOFTMAX_LEARNING_RATE, MOMENTUM, L2_PENALTY)
]

deep_dbn = [
    Rbm(mlp_layer.visible_size,
        mlp_layer.hidden_size,
        LEARNING_RATE, MOMENTUM, 0.0, L2_PENALTY) for mlp_layer in deep_mlp[:-1]
]

compare_pretraining_results(deep_mlp, deep_dbn,
                            mnist_train_images, mnist_train_labels,
                            mnist_test_images, mnist_test_labels,
                            monitoring_set,
                            BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>Plain MLP training</h3>
# Epoch 1:	########################################	elapsed: 0.48s, accuracy: 10.10
# Epoch 2:	########################################	elapsed: 0.47s, accuracy: 10.10
# Epoch 3:	########################################	elapsed: 0.39s, accuracy: 8.92
# Epoch 4:	########################################	elapsed: 0.63s, accuracy: 8.92
# Epoch 5:	########################################	elapsed: 0.43s, accuracy: 11.35
# Epoch 6:	########################################	elapsed: 0.43s, accuracy: 9.74
# Epoch 7:	########################################	elapsed: 0.63s, accuracy: 9.74
# Epoch 8:	########################################	elapsed: 0.40s, accuracy: 14.23
# Epoch 9:	########################################	elapsed: 0.38s, accuracy: 13.81
# Epoch 10:	########################################	elapsed: 0.38s, accuracy: 13.76
# Epoch 11:	########################################	elapsed: 0.80s, accuracy: 15.84
# Epoch 12:	########################################	elapsed: 0.46s, accuracy: 28.25
# Epoch 13:	########################################	elapsed: 0.42s, accuracy: 29.61
# Epoch 14:	########################################	elapsed: 0.38s, accuracy: 29.53
# Epoch 15:	########################################	elapsed: 0.44s, accuracy: 30.97
# Epoch 16:	########################################	elapsed: 0.42s, accuracy: 33.94
# Epoch 17:	########################################	elapsed: 0.42s, accuracy: 35.42
# Epoch 18:	########################################	elapsed: 0.38s, accuracy: 37.85
# Epoch 19:	########################################	elapsed: 0.39s, accuracy: 39.41
# Epoch 20:	########################################	elapsed: 0.40s, accuracy: 40.33
# Epoch 21:	########################################	elapsed: 0.47s, accuracy: 41.60
# Epoch 22:	########################################	elapsed: 0.53s, accuracy: 42.84
# Epoch 23:	########################################	elapsed: 0.44s, accuracy: 43.73
# Epoch 24:	########################################	elapsed: 0.46s, accuracy: 45.79
# Epoch 25:	########################################	elapsed: 0.47s, accuracy: 47.79
# Epoch 26:	########################################	elapsed: 0.48s, accuracy: 49.45
# Epoch 27:	########################################	elapsed: 0.44s, accuracy: 51.31
# Epoch 28:	########################################	elapsed: 0.45s, accuracy: 52.49
# Epoch 29:	########################################	elapsed: 0.47s, accuracy: 53.44
# Epoch 30:	########################################	elapsed: 0.41s, accuracy: 54.48
# Epoch 31:	########################################	elapsed: 0.42s, accuracy: 55.59
# Epoch 32:	########################################	elapsed: 0.46s, accuracy: 56.99
# Epoch 33:	########################################	elapsed: 0.46s, accuracy: 58.15
# Epoch 34:	########################################	elapsed: 0.46s, accuracy: 60.53
# Epoch 35:	########################################	elapsed: 0.44s, accuracy: 68.43
# Epoch 36:	########################################	elapsed: 0.45s, accuracy: 76.69
# Epoch 37:	########################################	elapsed: 0.44s, accuracy: 77.99
# Epoch 38:	########################################	elapsed: 0.48s, accuracy: 79.08
# Epoch 39:	########################################	elapsed: 0.63s, accuracy: 79.86
# Epoch 40:	########################################	elapsed: 0.44s, accuracy: 80.72
# Epoch 41:	########################################	elapsed: 0.45s, accuracy: 81.67
# Epoch 42:	########################################	elapsed: 0.48s, accuracy: 82.96
# Epoch 43:	########################################	elapsed: 0.42s, accuracy: 84.45
# Epoch 44:	########################################	elapsed: 0.47s, accuracy: 85.77
# Epoch 45:	########################################	elapsed: 0.46s, accuracy: 86.61
# Epoch 46:	########################################	elapsed: 0.43s, accuracy: 87.28
# Epoch 47:	########################################	elapsed: 0.43s, accuracy: 89.17
# Epoch 48:	########################################	elapsed: 0.43s, accuracy: 90.51
# Epoch 49:	########################################	elapsed: 0.42s, accuracy: 91.01
# Epoch 50:	########################################	elapsed: 0.43s, accuracy: 91.45
# Training finished!
# <h3>Input layer filters in the plain MLP</h3>
# <h3>DBN training</h3>
# Learning layer 0
# Epoch 1:	########################################	elapsed: 0.65s, reconstruction error: 31.45
# Epoch 2:	########################################	elapsed: 0.60s, reconstruction error: 24.59
# Epoch 3:	########################################	elapsed: 0.63s, reconstruction error: 21.27
# Epoch 4:	########################################	elapsed: 0.79s, reconstruction error: 19.01
# Epoch 5:	########################################	elapsed: 0.60s, reconstruction error: 17.61
# Epoch 6:	########################################	elapsed: 0.61s, reconstruction error: 15.56
# Epoch 7:	########################################	elapsed: 0.63s, reconstruction error: 13.37
# Epoch 8:	########################################	elapsed: 0.65s, reconstruction error: 12.53
# Epoch 9:	########################################	elapsed: 0.63s, reconstruction error: 12.16
# Epoch 10:	########################################	elapsed: 0.60s, reconstruction error: 11.43
# Epoch 11:	########################################	elapsed: 0.68s, reconstruction error: 11.11
# Epoch 12:	########################################	elapsed: 0.78s, reconstruction error: 10.85
# Epoch 13:	########################################	elapsed: 0.68s, reconstruction error: 10.60
# Epoch 14:	########################################	elapsed: 0.65s, reconstruction error: 10.37
# Epoch 15:	########################################	elapsed: 0.68s, reconstruction error: 10.05
# Epoch 16:	########################################	elapsed: 0.58s, reconstruction error: 9.96
# Epoch 17:	########################################	elapsed: 0.76s, reconstruction error: 9.97
# Epoch 18:	########################################	elapsed: 0.65s, reconstruction error: 9.93
# Epoch 19:	########################################	elapsed: 0.59s, reconstruction error: 9.90
# Epoch 20:	########################################	elapsed: 0.88s, reconstruction error: 9.77
# Epoch 21:	########################################	elapsed: 0.78s, reconstruction error: 9.90
# Epoch 22:	########################################	elapsed: 0.63s, reconstruction error: 9.75
# Epoch 23:	########################################	elapsed: 0.83s, reconstruction error: 9.55
# Epoch 24:	########################################	elapsed: 0.63s, reconstruction error: 9.61
# Epoch 25:	########################################	elapsed: 0.62s, reconstruction error: 9.34
# Epoch 26:	########################################	elapsed: 0.59s, reconstruction error: 9.28
# Epoch 27:	########################################	elapsed: 0.65s, reconstruction error: 9.18
# Epoch 28:	########################################	elapsed: 0.64s, reconstruction error: 9.32
# Epoch 29:	########################################	elapsed: 0.59s, reconstruction error: 9.15
# Epoch 30:	########################################	elapsed: 0.60s, reconstruction error: 9.14
# Epoch 31:	########################################	elapsed: 0.63s, reconstruction error: 9.16
# Epoch 32:	########################################	elapsed: 0.62s, reconstruction error: 9.16
# Epoch 33:	########################################	elapsed: 0.65s, reconstruction error: 9.00
# Epoch 34:	########################################	elapsed: 0.69s, reconstruction error: 8.99
# Epoch 35:	########################################	elapsed: 0.72s, reconstruction error: 9.02
# Epoch 36:	########################################	elapsed: 0.80s, reconstruction error: 8.86
# Epoch 37:	########################################	elapsed: 0.94s, reconstruction error: 9.04
# Epoch 38:	########################################	elapsed: 0.84s, reconstruction error: 9.03
# Epoch 39:	########################################	elapsed: 0.70s, reconstruction error: 8.92
# Epoch 40:	########################################	elapsed: 0.65s, reconstruction error: 8.81
# Epoch 41:	########################################	elapsed: 0.68s, reconstruction error: 8.68
# Epoch 42:	########################################	elapsed: 0.69s, reconstruction error: 8.91
# Epoch 43:	########################################	elapsed: 0.65s, reconstruction error: 8.77
# Epoch 44:	########################################	elapsed: 0.61s, reconstruction error: 8.72
# Epoch 45:	########################################	elapsed: 0.65s, reconstruction error: 8.70
# Epoch 46:	########################################	elapsed: 0.72s, reconstruction error: 8.81
# Epoch 47:	########################################	elapsed: 0.61s, reconstruction error: 8.65
# Epoch 48:	########################################	elapsed: 0.64s, reconstruction error: 8.66
# Epoch 49:	########################################	elapsed: 0.63s, reconstruction error: 8.64
# Epoch 50:	########################################	elapsed: 0.67s, reconstruction error: 8.53
#
# Learning layer 1
# Epoch 1:	########################################	elapsed: 0.30s, reconstruction error: 19.40
# Epoch 2:	########################################	elapsed: 0.30s, reconstruction error: 14.95
# Epoch 3:	########################################	elapsed: 0.29s, reconstruction error: 12.88
# Epoch 4:	########################################	elapsed: 0.31s, reconstruction error: 11.35
# Epoch 5:	########################################	elapsed: 0.30s, reconstruction error: 10.39
# Epoch 6:	########################################	elapsed: 0.45s, reconstruction error: 8.56
# Epoch 7:	########################################	elapsed: 0.77s, reconstruction error: 7.19
# Epoch 8:	########################################	elapsed: 0.74s, reconstruction error: 6.59
# Epoch 9:	########################################	elapsed: 0.49s, reconstruction error: 6.17
# Epoch 10:	########################################	elapsed: 1.17s, reconstruction error: 5.74
# Epoch 11:	########################################	elapsed: 0.71s, reconstruction error: 5.64
# Epoch 12:	########################################	elapsed: 0.98s, reconstruction error: 5.32
# Epoch 13:	########################################	elapsed: 0.89s, reconstruction error: 5.29
# Epoch 14:	########################################	elapsed: 0.95s, reconstruction error: 5.15
# Epoch 15:	########################################	elapsed: 1.05s, reconstruction error: 5.00
# Epoch 16:	########################################	elapsed: 0.74s, reconstruction error: 4.93
# Epoch 17:	########################################	elapsed: 0.58s, reconstruction error: 4.83
# Epoch 18:	########################################	elapsed: 0.29s, reconstruction error: 4.73
# Epoch 19:	########################################	elapsed: 0.36s, reconstruction error: 4.71
# Epoch 20:	########################################	elapsed: 0.55s, reconstruction error: 4.63
# Epoch 21:	########################################	elapsed: 0.30s, reconstruction error: 4.50
# Epoch 22:	########################################	elapsed: 0.33s, reconstruction error: 4.59
# Epoch 23:	########################################	elapsed: 0.35s, reconstruction error: 4.47
# Epoch 24:	########################################	elapsed: 0.29s, reconstruction error: 4.42
# Epoch 25:	########################################	elapsed: 0.25s, reconstruction error: 4.42
# Epoch 26:	########################################	elapsed: 0.29s, reconstruction error: 4.34
# Epoch 27:	########################################	elapsed: 0.30s, reconstruction error: 4.28
# Epoch 28:	########################################	elapsed: 0.45s, reconstruction error: 4.28
# Epoch 29:	########################################	elapsed: 0.45s, reconstruction error: 4.30
# Epoch 30:	########################################	elapsed: 0.32s, reconstruction error: 4.29
# Epoch 31:	########################################	elapsed: 0.29s, reconstruction error: 4.30
# Epoch 32:	########################################	elapsed: 0.29s, reconstruction error: 4.25
# Epoch 33:	########################################	elapsed: 0.29s, reconstruction error: 4.26
# Epoch 34:	########################################	elapsed: 0.28s, reconstruction error: 4.23
# Epoch 35:	########################################	elapsed: 0.45s, reconstruction error: 4.16
# Epoch 36:	########################################	elapsed: 0.38s, reconstruction error: 4.21
# Epoch 37:	########################################	elapsed: 0.29s, reconstruction error: 4.12
# Epoch 38:	########################################	elapsed: 0.29s, reconstruction error: 4.07
# Epoch 39:	########################################	elapsed: 0.27s, reconstruction error: 4.08
# Epoch 40:	########################################	elapsed: 0.28s, reconstruction error: 4.17
# Epoch 41:	########################################	elapsed: 0.55s, reconstruction error: 4.09
# Epoch 42:	########################################	elapsed: 0.72s, reconstruction error: 4.07
# Epoch 43:	########################################	elapsed: 0.90s, reconstruction error: 4.02
# Epoch 44:	########################################	elapsed: 1.05s, reconstruction error: 4.20
# Epoch 45:	########################################	elapsed: 1.05s, reconstruction error: 4.04
# Epoch 46:	########################################	elapsed: 0.89s, reconstruction error: 4.04
# Epoch 47:	########################################	elapsed: 0.84s, reconstruction error: 4.06
# Epoch 48:	########################################	elapsed: 0.79s, reconstruction error: 4.07
# Epoch 49:	########################################	elapsed: 0.59s, reconstruction error: 4.03
# Epoch 50:	########################################	elapsed: 0.41s, reconstruction error: 3.97
#
# Learning layer 2
# Epoch 1:	########################################	elapsed: 0.59s, reconstruction error: 15.60
# Epoch 2:	########################################	elapsed: 0.51s, reconstruction error: 11.22
# Epoch 3:	########################################	elapsed: 0.80s, reconstruction error: 9.34
# Epoch 4:	########################################	elapsed: 0.67s, reconstruction error: 8.10
# Epoch 5:	########################################	elapsed: 0.68s, reconstruction error: 7.36
# Epoch 6:	########################################	elapsed: 0.50s, reconstruction error: 5.83
# Epoch 7:	########################################	elapsed: 0.44s, reconstruction error: 5.04
# Epoch 8:	########################################	elapsed: 0.43s, reconstruction error: 4.56
# Epoch 9:	########################################	elapsed: 0.47s, reconstruction error: 4.31
# Epoch 10:	########################################	elapsed: 0.45s, reconstruction error: 4.10
# Epoch 11:	########################################	elapsed: 0.43s, reconstruction error: 3.90
# Epoch 12:	########################################	elapsed: 0.41s, reconstruction error: 3.69
# Epoch 13:	########################################	elapsed: 0.90s, reconstruction error: 3.66
# Epoch 14:	########################################	elapsed: 0.46s, reconstruction error: 3.61
# Epoch 15:	########################################	elapsed: 0.78s, reconstruction error: 3.51
# Epoch 16:	########################################	elapsed: 0.47s, reconstruction error: 3.48
# Epoch 17:	########################################	elapsed: 0.77s, reconstruction error: 3.42
# Epoch 18:	########################################	elapsed: 0.48s, reconstruction error: 3.41
# Epoch 19:	########################################	elapsed: 0.35s, reconstruction error: 3.33
# Epoch 20:	########################################	elapsed: 0.54s, reconstruction error: 3.26
# Epoch 21:	########################################	elapsed: 0.61s, reconstruction error: 3.30
# Epoch 22:	########################################	elapsed: 0.68s, reconstruction error: 3.28
# Epoch 23:	########################################	elapsed: 0.66s, reconstruction error: 3.24
# Epoch 24:	########################################	elapsed: 0.75s, reconstruction error: 3.23
# Epoch 25:	########################################	elapsed: 0.53s, reconstruction error: 3.16
# Epoch 26:	########################################	elapsed: 0.61s, reconstruction error: 3.19
# Epoch 27:	########################################	elapsed: 0.31s, reconstruction error: 3.15
# Epoch 28:	########################################	elapsed: 0.51s, reconstruction error: 3.16
# Epoch 29:	########################################	elapsed: 0.55s, reconstruction error: 3.08
# Epoch 30:	########################################	elapsed: 0.41s, reconstruction error: 3.11
# Epoch 31:	########################################	elapsed: 0.94s, reconstruction error: 3.04
# Epoch 32:	########################################	elapsed: 0.51s, reconstruction error: 3.05
# Epoch 33:	########################################	elapsed: 0.61s, reconstruction error: 3.07
# Epoch 34:	########################################	elapsed: 0.69s, reconstruction error: 3.09
# Epoch 35:	########################################	elapsed: 0.30s, reconstruction error: 3.04
# Epoch 36:	########################################	elapsed: 0.29s, reconstruction error: 3.03
# Epoch 37:	########################################	elapsed: 0.56s, reconstruction error: 2.99
# Epoch 38:	########################################	elapsed: 0.69s, reconstruction error: 3.01
# Epoch 39:	########################################	elapsed: 0.91s, reconstruction error: 2.99
# Epoch 40:	########################################	elapsed: 0.40s, reconstruction error: 3.00
# Epoch 41:	########################################	elapsed: 0.41s, reconstruction error: 3.00
# Epoch 42:	########################################	elapsed: 0.40s, reconstruction error: 2.96
# Epoch 43:	########################################	elapsed: 0.59s, reconstruction error: 2.94
# Epoch 44:	########################################	elapsed: 0.83s, reconstruction error: 2.99
# Epoch 45:	########################################	elapsed: 0.51s, reconstruction error: 2.93
# Epoch 46:	########################################	elapsed: 0.48s, reconstruction error: 2.95
# Epoch 47:	########################################	elapsed: 0.73s, reconstruction error: 3.00
# Epoch 48:	########################################	elapsed: 0.49s, reconstruction error: 3.01
# Epoch 49:	########################################	elapsed: 0.75s, reconstruction error: 2.88
# Epoch 50:	########################################	elapsed: 0.39s, reconstruction error: 2.89
# <h3>Finetuning pretrained MLP</h3>
# Epoch 1:	########################################	elapsed: 0.65s, accuracy: 93.99
# Epoch 2:	########################################	elapsed: 0.42s, accuracy: 95.20
# Epoch 3:	########################################	elapsed: 0.40s, accuracy: 95.62
# Epoch 4:	########################################	elapsed: 0.42s, accuracy: 95.92
# Epoch 5:	########################################	elapsed: 0.47s, accuracy: 96.09
# Epoch 6:	########################################	elapsed: 0.58s, accuracy: 96.19
# Epoch 7:	########################################	elapsed: 0.47s, accuracy: 96.44
# Epoch 8:	########################################	elapsed: 0.98s, accuracy: 96.50
# Epoch 9:	########################################	elapsed: 0.89s, accuracy: 96.56
# Epoch 10:	########################################	elapsed: 0.63s, accuracy: 96.65
# Epoch 11:	########################################	elapsed: 0.57s, accuracy: 96.60
# Epoch 12:	########################################	elapsed: 0.49s, accuracy: 96.66
# Epoch 13:	########################################	elapsed: 0.74s, accuracy: 96.70
# Epoch 14:	########################################	elapsed: 0.59s, accuracy: 96.72
# Epoch 15:	########################################	elapsed: 0.60s, accuracy: 96.78
# Epoch 16:	########################################	elapsed: 0.41s, accuracy: 96.82
# Epoch 17:	########################################	elapsed: 0.42s, accuracy: 96.81
# Epoch 18:	########################################	elapsed: 0.63s, accuracy: 96.84
# Epoch 19:	########################################	elapsed: 0.59s, accuracy: 96.91
# Epoch 20:	########################################	elapsed: 0.47s, accuracy: 96.94
# Epoch 21:	########################################	elapsed: 0.86s, accuracy: 96.95
# Epoch 22:	########################################	elapsed: 0.43s, accuracy: 96.95
# Epoch 23:	########################################	elapsed: 0.67s, accuracy: 96.98
# Epoch 24:	########################################	elapsed: 0.60s, accuracy: 97.00
# Epoch 25:	########################################	elapsed: 0.59s, accuracy: 97.01
# Epoch 26:	########################################	elapsed: 0.59s, accuracy: 97.00
# Epoch 27:	########################################	elapsed: 0.69s, accuracy: 97.00
# Epoch 28:	########################################	elapsed: 0.86s, accuracy: 97.00
# Epoch 29:	########################################	elapsed: 0.72s, accuracy: 97.00
# Epoch 30:	########################################	elapsed: 1.06s, accuracy: 97.01
# Epoch 31:	########################################	elapsed: 0.52s, accuracy: 97.00
# Epoch 32:	########################################	elapsed: 0.49s, accuracy: 97.02
# Epoch 33:	########################################	elapsed: 0.69s, accuracy: 97.01
# Epoch 34:	########################################	elapsed: 0.56s, accuracy: 97.01
# Epoch 35:	########################################	elapsed: 0.53s, accuracy: 97.03
# Epoch 36:	########################################	elapsed: 0.49s, accuracy: 97.02
# Epoch 37:	########################################	elapsed: 0.50s, accuracy: 97.02
# Epoch 38:	########################################	elapsed: 0.48s, accuracy: 97.02
# Epoch 39:	########################################	elapsed: 0.51s, accuracy: 97.02
# Epoch 40:	########################################	elapsed: 0.48s, accuracy: 97.02
# Epoch 41:	########################################	elapsed: 0.43s, accuracy: 97.01
# Epoch 42:	########################################	elapsed: 0.49s, accuracy: 97.02
# Epoch 43:	########################################	elapsed: 0.53s, accuracy: 97.03
# Epoch 44:	########################################	elapsed: 0.59s, accuracy: 97.05
# Epoch 45:	########################################	elapsed: 0.49s, accuracy: 97.04
# Epoch 46:	########################################	elapsed: 0.48s, accuracy: 97.04
# Epoch 47:	########################################	elapsed: 0.54s, accuracy: 97.03
# Epoch 48:	########################################	elapsed: 0.74s, accuracy: 97.05
# Epoch 49:	########################################	elapsed: 0.48s, accuracy: 97.06
# Epoch 50:	########################################	elapsed: 0.47s, accuracy: 97.06
# Training finished!
# <h3>First layer filters in the DBN</h3>
# <h3>Input layer filters in the pretrained & finetuned MLP</h3>

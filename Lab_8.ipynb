# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import mkl

mkl.set_num_threads(4)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def randn(*dims):
    return np.random.randn(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def as_matrix(vector):
    return np.reshape(vector, (-1, 1))

def one_hot_encode(labels):
    one_hot = zeros(labels.shape[0], np.max(labels) + 1) 
    one_hot[np.arange(labels.shape[0]), labels] = 1
    return one_hot.astype(np.float32)

def classify(mlp, batch):
    probabilities = forward_pass(mlp, batch, False)
    return np.argmax(probabilities, axis=1)

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

def draw_rbm_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)

def draw_layer_filters(layer):
    filters = np.reshape(layer.W[:-1].T, newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# ### Activation functions

# %%
def sigmoid(batch, stochastic=False):
    activations = 1.0 / (1.0 + np.exp(-batch))
    if stochastic:
        return activations > rand(*activations.shape).astype(np.float32)
    else:
        return activations

def sigmoid_derivative(batch):
    s = sigmoid(batch)
    return s * (1.0 - s)

def softmax(z):
    z = z - np.expand_dims(np.max(z, axis = 1), 1)
    return np.exp(z) / np.expand_dims(np.exp(z).sum(axis=1), 1)

# %% [markdown]
# # MNIST dataset

# %%
import mnist
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # ReLU and Max-Norm regularization

# %%
def relu(batch, stochastic=False):
    activations = np.maximum(batch, 0)
    if stochastic:
        return np.maximum(0, batch + np.random.normal(scale=np.sqrt(sigmoid(batch)), size=batch.shape))
    
    return np.maximum(0, batch)

def relu_derivative(batch):
    return np.where(batch > 0, 1, 0)

# %%
def limit_weights(weights, limit):
    norms = np.linalg.norm(weights, axis=0)
    scale = np.where(norms > limit, limit/norms, 1)
    return weights * scale

# %% [markdown]
# # RBM & DBN training

# %%
class Rbm:
    def __init__(self, visible_size, hidden_size, visible_act_func, hidden_act_func, 
                 learning_rate, momentum, weight_limit):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.visible_act_func = visible_act_func
        self.hidden_act_func = hidden_act_func
        
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.weight_limit = weight_limit
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.M = zeros(self.visible_size+1, self.hidden_size+1)

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]

    positive_visible = minibatch
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    z = minibatch @ rbm.W[:, :-1]
    positive_hidden[:, :-1] = rbm.hidden_act_func(z)
    negative_hidden[:, :-1] = rbm.hidden_act_func(z, stochastic=True)

    for cd_i in range(k):
        negative_visible[:, :-1] = rbm.visible_act_func(negative_hidden @ rbm.W[:-1, :].T,
                                                        stochastic=True)
        z = negative_visible @ rbm.W[:, :-1]
        if cd_i < (k - 1):
            negative_hidden[:, :-1] = rbm.hidden_act_func(z, stochastic=True)
        else:
            negative_hidden[:, :-1] = rbm.hidden_act_func(z)

    rbm.M *= rbm.momentum
    rbm.M += (rbm.learning_rate / observations_count) * positive_visible.T @ positive_hidden
    rbm.M -= (rbm.learning_rate / observations_count) * negative_visible.T @ negative_hidden

    rbm.W += rbm.M;
    
    if rbm.weight_limit > 0.0:
        rbm.W[:-1, :-1] = limit_weights(rbm.W[:-1, :-1], rbm.weight_limit)

def reconstuction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    hidden[:, :-1] =  rbm.hidden_act_func(minibatch @ rbm.W[:, :-1], stochastic=True)
    visible = rbm.visible_act_func(hidden @ np.transpose(rbm.W[:-1, :]))
    
    error = minibatch[:, :-1] - visible
    error = np.sum(np.square(error)) / observations_count
    
    return error

# %%
def propagate_up(dbn, layers_count, visible):
    for i in range(layers_count):
        visible = append_ones(sigmoid(visible @ dbn[i].W[:, :-1]))
    return visible

def propagate_down(dbn, layers_count, hidden):
    for i in reversed(range(layers_count)):
        hidden = append_ones(sigmoid(hidden @ np.transpose(dbn[i].W[:-1, :])))
    return hidden

def dbn_reconstuction_error(dbn, layer_idx, minibatch):
    propagated = propagate_up(dbn, layer_idx, minibatch)
    return reconstuction_error(dbn[layer_idx], propagated)

def train_dbn_layer(dbn, layer_idx, dataset, batch_size):
    dataset = propagate_up(dbn, layer_idx, dataset)
    
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(dbn[layer_idx], batch)
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")
            
def run_dbn_training(dbn, dataset, monitoring_set, batch_size, epochs_count, target_momentum=0.9):
    for layer_idx in range(len(dbn)):
        print("\nLearning layer {}".format(layer_idx+1))

        for epoch in range(epochs_count):
            print("Epoch {}:".format(epoch+1),  end="\t")

            if epoch == 5:
                dbn[layer_idx].momentum = target_momentum

            start_time = time.time()
            train_dbn_layer(dbn, layer_idx, dataset, batch_size)
            elapsed = time.time() - start_time

            error = dbn_reconstuction_error(dbn, layer_idx, monitoring_set)
            print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

# %% [markdown]
# # MLP training

# %%
class Layer:
    def __init__(self, visible_size, hidden_size, activation_fun, d_activation_fun, 
                 learning_rate, momentum, weight_limit):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.activation_fun = activation_fun
        self.d_activation_fun = d_activation_fun
                
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.weight_limit = weight_limit
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size)).astype(np.float32)
        self.W[-1, :] = 0.0
        
        self.activations = None
        self.d_activations = None
        self.deltas = None

        self.M = zeros(self.visible_size+1, self.hidden_size)

# %% [markdown]
# ### Forward pass

# %%
def forward_pass(mlp, batch, compute_derivatives):
    visible = batch
    
    for layer_idx, layer in enumerate(mlp):
        z = visible @ layer.W
        layer.activations = append_ones(layer.activation_fun(z))
        
        if compute_derivatives and (layer_idx < len(mlp) - 1):
            layer.d_activations = layer.d_activation_fun(z)
        
        visible = layer.activations
        
    return visible[:, :-1]

# %% [markdown]
# ### Error backpropagation

# %%
def error_backpropagate(mlp, batch):
    observations_count = batch.shape[0]
    
    for layer_idx, layer in reversed(list(enumerate(mlp))):
        if layer_idx > 0:
            prev_layer = mlp[layer_idx - 1]
            visible = prev_layer.activations
            prev_layer.deltas = (layer.deltas @ layer.W[:-1, :].T) * prev_layer.d_activations
        else:
            visible = batch
        
        layer.M = layer.momentum * layer.M - layer.learning_rate * ((visible.T @ layer.deltas) / observations_count)
        
        layer.W += layer.M
        
        if layer.weight_limit > 0.0:
            layer.W[:-1, :] = limit_weights(layer.W[:-1, :], layer.weight_limit)

# %% [markdown]
# ### Training procedure

# %%
def train_mlp(mlp, dataset, labels, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    
    batched_data = chunks(dataset, batch_size)
    batched_labels = chunks(labels, batch_size)
    
    for batch_idx, (batch, batch_labels) in enumerate(zip(batched_data, batched_labels)):
        # Forward pass: compute activatations and derivatives of activations
        y = forward_pass(mlp, batch, True)
        
        mlp[-1].deltas = y - batch_labels
        
        # Once softmax deltas are set, we may backpropagate errors
        error_backpropagate(mlp, batch)
        
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

# %%
def run_mlp_training(mlp, train_set, train_labels, validation_set, validation_labels,
                     batch_size, epochs_count, target_momentum=0.95):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch+1),  end="\t")
        
        if epoch == 5:
            for layer in mlp: layer.momentum = target_momentum
        
        start_time = time.time()
        train_mlp(mlp, train_set, train_labels, batch_size)
        elapsed = time.time() - start_time

        predictions = classify(mlp, validation_set)
        accuracy = 100.0 * np.sum(predictions == validation_labels) / predictions.shape[0]
        print("\telapsed: {0:>2.2f}s, accuracy: {1:>2.2f}".format(elapsed, accuracy))

    print("Training finished!")

# %% [markdown]
# #  Initializing MLP with DBN weights
#
# Implement initialization of MLP weights (and biases) using weights (and biases) from the DBN layers.
#
# Make sure that the MLP weights (and biases) are **copies** of the DBN weights (and biases). You can use ```np.copy(...)``` function to copy the weights (simple assignment will make a view instead of a copy).

# %%
def initialize_mlp(mlp, dbn):
    for i, r in enumerate(dbn):
        mlp[i].W = np.copy(r.W[:, :-1])

# %% [markdown]
# # MNIST digits classification

# %%
DATASET_SIZE = 10000 # 60000 for whole dataset
DIGIT_SIZE = 28

##### Train set #####

mnist_train_images = mnist.train_images().astype(np.float32) / 255.0
mnist_train_labels = mnist.train_labels()

order = np.random.permutation(len(mnist_train_images))
mnist_train_images = mnist_train_images[order]
mnist_train_labels = mnist_train_labels[order]

mnist_train_images = np.reshape(mnist_train_images[:DATASET_SIZE],
                                newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
mnist_train_images = append_ones(mnist_train_images)

mnist_train_labels = mnist_train_labels[:DATASET_SIZE]
mnist_train_labels = one_hot_encode(mnist_train_labels)

monitoring_set_indeces = np.random.choice(mnist_train_images.shape[0], 512, replace=False)
monitoring_set = mnist_train_images[monitoring_set_indeces]

##### Test set #####

mnist_test_images = mnist.test_images().astype(np.float32) / 255.0
mnist_test_images = np.reshape(mnist_test_images, newshape=(-1, DIGIT_SIZE*DIGIT_SIZE))
mnist_test_images = append_ones(mnist_test_images)

mnist_test_labels = mnist.test_labels()

# %%
VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 256

BATCH_SIZE = 128
EPOCHS_COUNT = 50

MLP_LEARNING_RATE = 0.03
SOFTMAX_LEARNING_RATE = 0.15
RBM_LEARNING_RATE = 0.003
MOMENTUM = 0.5

# %% [markdown]
# ### Plain vs pretrained comparison

# %%
from IPython.core.display import HTML

def compare_pretraining_results(mlp, dbn,
                                train_set, train_labels,
                                validation_set, validation_labels,
                                monitoring_set,
                                batch_size, epochs_count):
    for layer in mlp:
        layer.reset()

    display(HTML('<h3>Plain MLP training</h3>'))
    run_mlp_training(mlp,
                     train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count)
    
    display(HTML('<h3>Input layer filters in the plain MLP</h3>'))
    draw_layer_filters(mlp[0])
    
    display(HTML('<h3>Largest norms of weight-vectors in the plain MLP layers</h3>'))
    for i, layer in enumerate(mlp):
        max_norm = np.max(np.linalg.norm(layer.W[:-1, :], axis=0))
        print('\tlayer {0}: {1:.2f}'.format(i+1, max_norm))
    
    display(HTML('<h3>DBN training</h3>'))
    run_dbn_training(dbn, train_set, monitoring_set, batch_size, epochs_count)
    
    for layer in mlp:
        layer.reset()
    
    initialize_mlp(mlp, dbn)
    
    display(HTML('<h3>Finetuning pretrained MLP</h3>'))
    run_mlp_training(mlp,
                     train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count)
    
    display(HTML('<h3>First layer filters in the DBN</h3>'))
    draw_rbm_filters(dbn[0])
    
    display(HTML('<h3>Input layer filters in the pretrained & finetuned MLP</h3>'))
    draw_layer_filters(mlp[0])

    display(HTML('<h3>Largest norms of weight-vectors in the finetuned MLP layers</h3>'))
    for i, layer in enumerate(mlp):
        max_norm = np.max(np.linalg.norm(layer.W[:-1, :], axis=0))
        print('\tlayer {0}: {1:.2f}'.format(i+1, max_norm))

# %% [markdown]
# ### Shallow ReLU network

# %%
shallow_mlp = [
    Layer(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, MLP_LEARNING_RATE, MOMENTUM,
          weight_limit=2.0),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, MLP_LEARNING_RATE, MOMENTUM,
          weight_limit=1.0),
    Layer(HIDDEN_LAYER_SIZE, 10, softmax, None, SOFTMAX_LEARNING_RATE, MOMENTUM,
          weight_limit=4.0)
]

shallow_dbn = [
    Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=2.0),
    Rbm(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=1.0)
]

compare_pretraining_results(shallow_mlp, shallow_dbn,
                            mnist_train_images, mnist_train_labels,
                            mnist_test_images, mnist_test_labels,
                            monitoring_set,
                            BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>Plain MLP training</h3>
# Epoch 1:	########################################	elapsed: 0.98s, accuracy: 11.35
# Epoch 2:	########################################	elapsed: 1.13s, accuracy: 31.54
# Epoch 3:	########################################	elapsed: 1.00s, accuracy: 65.26
# Epoch 4:	########################################	elapsed: 0.98s, accuracy: 74.15
# Epoch 5:	########################################	elapsed: 0.97s, accuracy: 80.37
# Epoch 6:	########################################	elapsed: 1.01s, accuracy: 89.83
# Epoch 7:	########################################	elapsed: 1.02s, accuracy: 92.23
# Epoch 8:	########################################	elapsed: 1.01s, accuracy: 93.19
# Epoch 9:	########################################	elapsed: 1.04s, accuracy: 94.34
# Epoch 10:	########################################	elapsed: 1.01s, accuracy: 94.50
# Epoch 11:	########################################	elapsed: 1.01s, accuracy: 93.47
# Epoch 12:	########################################	elapsed: 1.00s, accuracy: 95.46
# Epoch 13:	########################################	elapsed: 1.00s, accuracy: 95.22
# Epoch 14:	########################################	elapsed: 1.03s, accuracy: 94.96
# Epoch 15:	########################################	elapsed: 1.02s, accuracy: 95.14
# Epoch 16:	########################################	elapsed: 1.00s, accuracy: 94.21
# Epoch 17:	########################################	elapsed: 1.00s, accuracy: 95.17
# Epoch 18:	########################################	elapsed: 0.99s, accuracy: 95.68
# Epoch 19:	########################################	elapsed: 0.98s, accuracy: 95.69
# Epoch 20:	########################################	elapsed: 1.01s, accuracy: 95.99
# Epoch 21:	########################################	elapsed: 0.99s, accuracy: 95.87
# Epoch 22:	########################################	elapsed: 1.00s, accuracy: 96.06
# Epoch 23:	########################################	elapsed: 0.97s, accuracy: 96.36
# Epoch 24:	########################################	elapsed: 0.97s, accuracy: 96.57
# Epoch 25:	########################################	elapsed: 0.94s, accuracy: 96.54
# Epoch 26:	########################################	elapsed: 0.94s, accuracy: 96.60
# Epoch 27:	########################################	elapsed: 0.93s, accuracy: 96.56
# Epoch 28:	########################################	elapsed: 1.01s, accuracy: 96.58
# Epoch 29:	########################################	elapsed: 1.00s, accuracy: 96.58
# Epoch 30:	########################################	elapsed: 1.00s, accuracy: 96.55
# Epoch 31:	########################################	elapsed: 1.00s, accuracy: 96.56
# Epoch 32:	########################################	elapsed: 1.00s, accuracy: 96.57
# Epoch 33:	########################################	elapsed: 0.97s, accuracy: 96.57
# Epoch 34:	########################################	elapsed: 0.98s, accuracy: 96.57
# Epoch 35:	########################################	elapsed: 0.98s, accuracy: 96.57
# Epoch 36:	########################################	elapsed: 0.99s, accuracy: 96.57
# Epoch 37:	########################################	elapsed: 0.98s, accuracy: 96.57
# Epoch 38:	########################################	elapsed: 0.97s, accuracy: 96.56
# Epoch 39:	########################################	elapsed: 0.98s, accuracy: 96.56
# Epoch 40:	########################################	elapsed: 0.98s, accuracy: 96.55
# Epoch 41:	########################################	elapsed: 0.99s, accuracy: 96.55
# Epoch 42:	########################################	elapsed: 0.97s, accuracy: 96.55
# Epoch 43:	########################################	elapsed: 0.98s, accuracy: 96.54
# Epoch 44:	########################################	elapsed: 0.97s, accuracy: 96.55
# Epoch 45:	########################################	elapsed: 1.00s, accuracy: 96.55
# Epoch 46:	########################################	elapsed: 1.03s, accuracy: 96.55
# Epoch 47:	########################################	elapsed: 0.93s, accuracy: 96.55
# Epoch 48:	########################################	elapsed: 1.16s, accuracy: 96.55
# Epoch 49:	########################################	elapsed: 0.92s, accuracy: 96.54
# Epoch 50:	########################################	elapsed: 0.88s, accuracy: 96.54
# Training finished!
# <h3>Input layer filters in the plain MLP</h3>
# <h3>Largest norms of weight-vectors in the plain MLP layers</h3>
# 	layer 1: 1.78
# 	layer 2: 1.00
# 	layer 3: 4.00
# <h3>DBN training</h3>
# Learning layer 1
# Epoch 1:	########################################	elapsed: 1.09s, reconstruction error: 75.37
# Epoch 2:	########################################	elapsed: 1.06s, reconstruction error: 54.90
# Epoch 3:	########################################	elapsed: 1.10s, reconstruction error: 42.84
# Epoch 4:	########################################	elapsed: 1.03s, reconstruction error: 36.50
# Epoch 5:	########################################	elapsed: 0.99s, reconstruction error: 32.70
# Epoch 6:	########################################	elapsed: 1.02s, reconstruction error: 24.96
# Epoch 7:	########################################	elapsed: 1.00s, reconstruction error: 20.96
# Epoch 8:	########################################	elapsed: 1.11s, reconstruction error: 18.62
# Epoch 9:	########################################	elapsed: 1.15s, reconstruction error: 16.90
# Epoch 10:	########################################	elapsed: 1.79s, reconstruction error: 15.66
# Epoch 11:	########################################	elapsed: 1.24s, reconstruction error: 14.76
# Epoch 12:	########################################	elapsed: 1.20s, reconstruction error: 13.85
# Epoch 13:	########################################	elapsed: 1.15s, reconstruction error: 13.17
# Epoch 14:	########################################	elapsed: 1.10s, reconstruction error: 12.51
# Epoch 15:	########################################	elapsed: 1.11s, reconstruction error: 11.90
# Epoch 16:	########################################	elapsed: 1.13s, reconstruction error: 11.47
# Epoch 17:	########################################	elapsed: 1.13s, reconstruction error: 11.21
# Epoch 18:	########################################	elapsed: 1.15s, reconstruction error: 10.65
# Epoch 19:	########################################	elapsed: 1.16s, reconstruction error: 10.42
# Epoch 20:	########################################	elapsed: 1.16s, reconstruction error: 10.23
# Epoch 21:	########################################	elapsed: 1.16s, reconstruction error: 9.86
# Epoch 22:	########################################	elapsed: 1.19s, reconstruction error: 9.59
# Epoch 23:	########################################	elapsed: 1.19s, reconstruction error: 9.49
# Epoch 24:	########################################	elapsed: 1.19s, reconstruction error: 9.35
# Epoch 25:	########################################	elapsed: 1.18s, reconstruction error: 9.30
# Epoch 26:	########################################	elapsed: 1.14s, reconstruction error: 9.10
# Epoch 27:	########################################	elapsed: 1.15s, reconstruction error: 8.92
# Epoch 28:	########################################	elapsed: 1.15s, reconstruction error: 8.83
# Epoch 29:	########################################	elapsed: 1.17s, reconstruction error: 8.81
# Epoch 30:	########################################	elapsed: 1.20s, reconstruction error: 8.67
# Epoch 31:	########################################	elapsed: 1.19s, reconstruction error: 8.54
# Epoch 32:	########################################	elapsed: 1.20s, reconstruction error: 8.57
# Epoch 33:	########################################	elapsed: 1.21s, reconstruction error: 8.51
# Epoch 34:	########################################	elapsed: 1.20s, reconstruction error: 8.50
# Epoch 35:	########################################	elapsed: 1.19s, reconstruction error: 8.46
# Epoch 36:	########################################	elapsed: 1.20s, reconstruction error: 8.55
# Epoch 37:	########################################	elapsed: 1.21s, reconstruction error: 8.37
# Epoch 38:	########################################	elapsed: 1.20s, reconstruction error: 8.30
# Epoch 39:	########################################	elapsed: 1.19s, reconstruction error: 8.25
# Epoch 40:	########################################	elapsed: 1.20s, reconstruction error: 8.17
# Epoch 41:	########################################	elapsed: 1.21s, reconstruction error: 8.18
# Epoch 42:	########################################	elapsed: 1.21s, reconstruction error: 8.20
# Epoch 43:	########################################	elapsed: 1.20s, reconstruction error: 8.20
# Epoch 44:	########################################	elapsed: 1.20s, reconstruction error: 8.13
# Epoch 45:	########################################	elapsed: 1.21s, reconstruction error: 8.13
# Epoch 46:	########################################	elapsed: 1.19s, reconstruction error: 8.11
# Epoch 47:	########################################	elapsed: 1.21s, reconstruction error: 8.02
# Epoch 48:	########################################	elapsed: 1.19s, reconstruction error: 8.00
# Epoch 49:	########################################	elapsed: 1.22s, reconstruction error: 7.99
# Epoch 50:	########################################	elapsed: 1.17s, reconstruction error: 7.87
#
# Learning layer 2
# Epoch 1:	########################################	elapsed: 1.11s, reconstruction error: 25.53
# Epoch 2:	########################################	elapsed: 1.02s, reconstruction error: 22.86
# Epoch 3:	########################################	elapsed: 0.98s, reconstruction error: 20.73
# Epoch 4:	########################################	elapsed: 1.03s, reconstruction error: 18.77
# Epoch 5:	########################################	elapsed: 1.00s, reconstruction error: 18.65
# Epoch 6:	########################################	elapsed: 1.00s, reconstruction error: 18.36
# Epoch 7:	########################################	elapsed: 1.00s, reconstruction error: 16.43
# Epoch 8:	########################################	elapsed: 0.99s, reconstruction error: 16.69
# Epoch 9:	########################################	elapsed: 0.97s, reconstruction error: 16.60
# Epoch 10:	########################################	elapsed: 0.96s, reconstruction error: 15.78
# Epoch 11:	########################################	elapsed: 0.98s, reconstruction error: 14.58
# Epoch 12:	########################################	elapsed: 0.97s, reconstruction error: 15.03
# Epoch 13:	########################################	elapsed: 0.99s, reconstruction error: 15.01
# Epoch 14:	########################################	elapsed: 0.97s, reconstruction error: 15.37
# Epoch 15:	########################################	elapsed: 0.97s, reconstruction error: 13.27
# Epoch 16:	########################################	elapsed: 1.06s, reconstruction error: 13.60
# Epoch 17:	########################################	elapsed: 1.03s, reconstruction error: 13.88
# Epoch 18:	########################################	elapsed: 0.99s, reconstruction error: 13.79
# Epoch 19:	########################################	elapsed: 0.99s, reconstruction error: 14.91
# Epoch 20:	########################################	elapsed: 1.04s, reconstruction error: 14.07
# Epoch 21:	########################################	elapsed: 0.96s, reconstruction error: 13.11
# Epoch 22:	########################################	elapsed: 0.96s, reconstruction error: 14.17
# Epoch 23:	########################################	elapsed: 0.97s, reconstruction error: 13.41
# Epoch 24:	########################################	elapsed: 0.96s, reconstruction error: 12.92
# Epoch 25:	########################################	elapsed: 0.98s, reconstruction error: 13.45
# Epoch 26:	########################################	elapsed: 0.99s, reconstruction error: 13.90
# Epoch 27:	########################################	elapsed: 0.98s, reconstruction error: 12.74
# Epoch 28:	########################################	elapsed: 0.99s, reconstruction error: 13.68
# Epoch 29:	########################################	elapsed: 1.00s, reconstruction error: 12.79
# Epoch 30:	########################################	elapsed: 0.97s, reconstruction error: 12.57
# Epoch 31:	########################################	elapsed: 0.98s, reconstruction error: 13.27
# Epoch 32:	########################################	elapsed: 0.97s, reconstruction error: 12.83
# Epoch 33:	########################################	elapsed: 0.99s, reconstruction error: 14.03
# Epoch 34:	########################################	elapsed: 0.98s, reconstruction error: 12.92
# Epoch 35:	########################################	elapsed: 0.96s, reconstruction error: 13.18
# Epoch 36:	########################################	elapsed: 1.00s, reconstruction error: 12.81
# Epoch 37:	########################################	elapsed: 0.98s, reconstruction error: 13.10
# Epoch 38:	########################################	elapsed: 0.99s, reconstruction error: 12.36
# Epoch 39:	########################################	elapsed: 0.97s, reconstruction error: 12.95
# Epoch 40:	########################################	elapsed: 0.98s, reconstruction error: 13.04
# Epoch 41:	########################################	elapsed: 1.02s, reconstruction error: 12.96
# Epoch 42:	########################################	elapsed: 0.98s, reconstruction error: 13.13
# Epoch 43:	########################################	elapsed: 1.01s, reconstruction error: 12.69
# Epoch 44:	########################################	elapsed: 0.98s, reconstruction error: 13.09
# Epoch 45:	########################################	elapsed: 1.17s, reconstruction error: 12.50
# Epoch 46:	########################################	elapsed: 1.06s, reconstruction error: 13.23
# Epoch 47:	########################################	elapsed: 1.12s, reconstruction error: 12.42
# Epoch 48:	########################################	elapsed: 1.05s, reconstruction error: 12.36
# Epoch 49:	########################################	elapsed: 0.98s, reconstruction error: 12.87
# Epoch 50:	########################################	elapsed: 0.98s, reconstruction error: 13.04
# <h3>Finetuning pretrained MLP</h3>
# Epoch 1:	########################################	elapsed: 0.95s, accuracy: 92.44
# Epoch 2:	########################################	elapsed: 0.94s, accuracy: 94.09
# Epoch 3:	########################################	elapsed: 0.95s, accuracy: 95.57
# Epoch 4:	########################################	elapsed: 0.97s, accuracy: 95.72
# Epoch 5:	########################################	elapsed: 0.95s, accuracy: 96.12
# Epoch 6:	########################################	elapsed: 0.95s, accuracy: 95.83
# Epoch 7:	########################################	elapsed: 0.97s, accuracy: 96.52
# Epoch 8:	########################################	elapsed: 0.97s, accuracy: 96.77
# Epoch 9:	########################################	elapsed: 0.96s, accuracy: 96.45
# Epoch 10:	########################################	elapsed: 0.96s, accuracy: 96.62
# Epoch 11:	########################################	elapsed: 0.99s, accuracy: 97.01
# Epoch 12:	########################################	elapsed: 1.03s, accuracy: 96.89
# Epoch 13:	########################################	elapsed: 0.92s, accuracy: 97.00
# Epoch 14:	########################################	elapsed: 0.97s, accuracy: 96.68
# Epoch 15:	########################################	elapsed: 0.95s, accuracy: 97.17
# Epoch 16:	########################################	elapsed: 0.94s, accuracy: 96.96
# Epoch 17:	########################################	elapsed: 0.92s, accuracy: 96.96
# Epoch 18:	########################################	elapsed: 0.91s, accuracy: 97.10
# Epoch 19:	########################################	elapsed: 0.90s, accuracy: 97.12
# Epoch 20:	########################################	elapsed: 0.89s, accuracy: 97.20
# Epoch 21:	########################################	elapsed: 0.91s, accuracy: 97.16
# Epoch 22:	########################################	elapsed: 0.93s, accuracy: 97.11
# Epoch 23:	########################################	elapsed: 0.90s, accuracy: 97.18
# Epoch 24:	########################################	elapsed: 0.89s, accuracy: 97.18
# Epoch 25:	########################################	elapsed: 0.91s, accuracy: 97.16
# Epoch 26:	########################################	elapsed: 0.90s, accuracy: 97.16
# Epoch 27:	########################################	elapsed: 0.90s, accuracy: 97.16
# Epoch 28:	########################################	elapsed: 0.90s, accuracy: 97.15
# Epoch 29:	########################################	elapsed: 0.90s, accuracy: 97.16
# Epoch 30:	########################################	elapsed: 0.98s, accuracy: 97.16
# Epoch 31:	########################################	elapsed: 0.92s, accuracy: 97.18
# Epoch 32:	########################################	elapsed: 0.92s, accuracy: 97.19
# Epoch 33:	########################################	elapsed: 0.91s, accuracy: 97.18
# Epoch 34:	########################################	elapsed: 0.91s, accuracy: 97.21
# Epoch 35:	########################################	elapsed: 0.92s, accuracy: 97.20
# Epoch 36:	########################################	elapsed: 0.89s, accuracy: 97.19
# Epoch 37:	########################################	elapsed: 0.90s, accuracy: 97.19
# Epoch 38:	########################################	elapsed: 0.91s, accuracy: 97.19
# Epoch 39:	########################################	elapsed: 0.93s, accuracy: 97.19
# Epoch 40:	########################################	elapsed: 0.91s, accuracy: 97.17
# Epoch 41:	########################################	elapsed: 0.89s, accuracy: 97.17
# Epoch 42:	########################################	elapsed: 0.89s, accuracy: 97.16
# Epoch 43:	########################################	elapsed: 0.90s, accuracy: 97.16
# Epoch 44:	########################################	elapsed: 0.92s, accuracy: 97.17
# Epoch 45:	########################################	elapsed: 0.89s, accuracy: 97.17
# Epoch 46:	########################################	elapsed: 0.89s, accuracy: 97.17
# Epoch 47:	########################################	elapsed: 0.92s, accuracy: 97.16
# Epoch 48:	########################################	elapsed: 0.90s, accuracy: 97.17
# Epoch 49:	########################################	elapsed: 0.91s, accuracy: 97.15
# Epoch 50:	########################################	elapsed: 0.91s, accuracy: 97.17
# Training finished!
# <h3>First layer filters in the DBN</h3>
# <h3>Input layer filters in the pretrained & finetuned MLP</h3>
# <h3>Largest norms of weight-vectors in the finetuned MLP layers</h3>
# 	layer 1: 2.00
# 	layer 2: 1.00
# 	layer 3: 4.00

# %% [markdown]
# ### Deep ReLU network

# %%
deep_mlp = [
    Layer(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, MLP_LEARNING_RATE, MOMENTUM,
          weight_limit=2.0),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, MLP_LEARNING_RATE, MOMENTUM,
          weight_limit=1.0),
    Layer(HIDDEN_LAYER_SIZE, 2 * HIDDEN_LAYER_SIZE, relu, relu_derivative, MLP_LEARNING_RATE, MOMENTUM,
          weight_limit=1.0),
    Layer(2 * HIDDEN_LAYER_SIZE, 10, softmax, None, SOFTMAX_LEARNING_RATE, MOMENTUM,
          weight_limit=4.0)
]

deep_dbn = [
    Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=2.0),
    Rbm(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=1.0),
    Rbm(HIDDEN_LAYER_SIZE, 2 * HIDDEN_LAYER_SIZE, relu, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=1.0)
]

compare_pretraining_results(deep_mlp, deep_dbn,
                            mnist_train_images, mnist_train_labels,
                            mnist_test_images, mnist_test_labels,
                            monitoring_set,
                            BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>Plain MLP training</h3>
# Epoch 1:	########################################	elapsed: 1.65s, accuracy: 11.35
# Epoch 2:	########################################	elapsed: 1.64s, accuracy: 11.35
# Epoch 3:	########################################	elapsed: 1.64s, accuracy: 11.35
# Epoch 4:	########################################	elapsed: 1.64s, accuracy: 11.35
# Epoch 5:	########################################	elapsed: 1.62s, accuracy: 11.35
# Epoch 6:	########################################	elapsed: 1.61s, accuracy: 38.85
# Epoch 7:	########################################	elapsed: 1.57s, accuracy: 79.21
# Epoch 8:	########################################	elapsed: 1.65s, accuracy: 88.21
# Epoch 9:	########################################	elapsed: 1.62s, accuracy: 92.27
# Epoch 10:	########################################	elapsed: 1.59s, accuracy: 93.45
# Epoch 11:	########################################	elapsed: 1.56s, accuracy: 94.00
# Epoch 12:	########################################	elapsed: 1.56s, accuracy: 93.67
# Epoch 13:	########################################	elapsed: 1.74s, accuracy: 93.65
# Epoch 14:	########################################	elapsed: 1.71s, accuracy: 93.97
# Epoch 15:	########################################	elapsed: 1.63s, accuracy: 94.33
# Epoch 16:	########################################	elapsed: 1.62s, accuracy: 93.50
# Epoch 17:	########################################	elapsed: 1.63s, accuracy: 94.88
# Epoch 18:	########################################	elapsed: 1.63s, accuracy: 94.84
# Epoch 19:	########################################	elapsed: 1.63s, accuracy: 95.14
# Epoch 20:	########################################	elapsed: 1.65s, accuracy: 95.65
# Epoch 21:	########################################	elapsed: 1.62s, accuracy: 95.56
# Epoch 22:	########################################	elapsed: 1.62s, accuracy: 96.04
# Epoch 23:	########################################	elapsed: 1.61s, accuracy: 95.99
# Epoch 24:	########################################	elapsed: 1.57s, accuracy: 96.41
# Epoch 25:	########################################	elapsed: 1.53s, accuracy: 95.93
# Epoch 26:	########################################	elapsed: 1.53s, accuracy: 95.34
# Epoch 27:	########################################	elapsed: 1.53s, accuracy: 96.05
# Epoch 28:	########################################	elapsed: 1.54s, accuracy: 95.76
# Epoch 29:	########################################	elapsed: 1.52s, accuracy: 95.65
# Epoch 30:	########################################	elapsed: 1.53s, accuracy: 96.25
# Epoch 31:	########################################	elapsed: 1.55s, accuracy: 96.59
# Epoch 32:	########################################	elapsed: 1.53s, accuracy: 96.41
# Epoch 33:	########################################	elapsed: 1.57s, accuracy: 96.56
# Epoch 34:	########################################	elapsed: 1.55s, accuracy: 96.56
# Epoch 35:	########################################	elapsed: 1.62s, accuracy: 96.57
# Epoch 36:	########################################	elapsed: 1.61s, accuracy: 96.58
# Epoch 37:	########################################	elapsed: 1.56s, accuracy: 96.56
# Epoch 38:	########################################	elapsed: 1.56s, accuracy: 96.55
# Epoch 39:	########################################	elapsed: 1.56s, accuracy: 96.57
# Epoch 40:	########################################	elapsed: 1.55s, accuracy: 96.59
# Epoch 41:	########################################	elapsed: 1.63s, accuracy: 96.59
# Epoch 42:	########################################	elapsed: 1.57s, accuracy: 96.60
# Epoch 43:	########################################	elapsed: 1.55s, accuracy: 96.59
# Epoch 44:	########################################	elapsed: 1.68s, accuracy: 96.60
# Epoch 45:	########################################	elapsed: 1.56s, accuracy: 96.60
# Epoch 46:	########################################	elapsed: 1.53s, accuracy: 96.61
# Epoch 47:	########################################	elapsed: 1.55s, accuracy: 96.61
# Epoch 48:	########################################	elapsed: 1.58s, accuracy: 96.60
# Epoch 49:	########################################	elapsed: 1.58s, accuracy: 96.60
# Epoch 50:	########################################	elapsed: 1.62s, accuracy: 96.60
# Training finished!
# <h3>Input layer filters in the plain MLP</h3>
# <h3>Largest norms of weight-vectors in the plain MLP layers</h3>
# 	layer 1: 2.00
# 	layer 2: 1.00
# 	layer 3: 0.79
# 	layer 4: 4.00
# <h3>DBN training</h3>
# Learning layer 1
# Epoch 1:	########################################	elapsed: 1.09s, reconstruction error: 74.95
# Epoch 2:	########################################	elapsed: 1.09s, reconstruction error: 54.83
# Epoch 3:	########################################	elapsed: 1.10s, reconstruction error: 42.51
# Epoch 4:	########################################	elapsed: 1.09s, reconstruction error: 36.23
# Epoch 5:	########################################	elapsed: 1.08s, reconstruction error: 32.50
# Epoch 6:	########################################	elapsed: 1.07s, reconstruction error: 24.70
# Epoch 7:	########################################	elapsed: 1.09s, reconstruction error: 20.91
# Epoch 8:	########################################	elapsed: 1.08s, reconstruction error: 18.62
# Epoch 9:	########################################	elapsed: 1.07s, reconstruction error: 16.92
# Epoch 10:	########################################	elapsed: 1.08s, reconstruction error: 15.68
# Epoch 11:	########################################	elapsed: 1.09s, reconstruction error: 14.93
# Epoch 12:	########################################	elapsed: 1.09s, reconstruction error: 13.87
# Epoch 13:	########################################	elapsed: 1.07s, reconstruction error: 13.30
# Epoch 14:	########################################	elapsed: 1.07s, reconstruction error: 12.55
# Epoch 15:	########################################	elapsed: 1.08s, reconstruction error: 11.96
# Epoch 16:	########################################	elapsed: 1.11s, reconstruction error: 11.52
# Epoch 17:	########################################	elapsed: 1.11s, reconstruction error: 11.14
# Epoch 18:	########################################	elapsed: 1.13s, reconstruction error: 10.75
# Epoch 19:	########################################	elapsed: 1.12s, reconstruction error: 10.40
# Epoch 20:	########################################	elapsed: 1.17s, reconstruction error: 10.16
# Epoch 21:	########################################	elapsed: 1.15s, reconstruction error: 9.94
# Epoch 22:	########################################	elapsed: 1.14s, reconstruction error: 9.86
# Epoch 23:	########################################	elapsed: 1.15s, reconstruction error: 9.66
# Epoch 24:	########################################	elapsed: 1.17s, reconstruction error: 9.47
# Epoch 25:	########################################	elapsed: 1.17s, reconstruction error: 9.39
# Epoch 26:	########################################	elapsed: 1.17s, reconstruction error: 9.20
# Epoch 27:	########################################	elapsed: 1.19s, reconstruction error: 9.17
# Epoch 28:	########################################	elapsed: 1.20s, reconstruction error: 8.99
# Epoch 29:	########################################	elapsed: 1.18s, reconstruction error: 8.99
# Epoch 30:	########################################	elapsed: 1.16s, reconstruction error: 8.86
# Epoch 31:	########################################	elapsed: 1.16s, reconstruction error: 8.76
# Epoch 32:	########################################	elapsed: 1.16s, reconstruction error: 8.70
# Epoch 33:	########################################	elapsed: 1.17s, reconstruction error: 8.59
# Epoch 34:	########################################	elapsed: 1.16s, reconstruction error: 8.52
# Epoch 35:	########################################	elapsed: 1.16s, reconstruction error: 8.52
# Epoch 36:	########################################	elapsed: 1.17s, reconstruction error: 8.46
# Epoch 37:	########################################	elapsed: 1.17s, reconstruction error: 8.40
# Epoch 38:	########################################	elapsed: 1.16s, reconstruction error: 8.37
# Epoch 39:	########################################	elapsed: 1.17s, reconstruction error: 8.24
# Epoch 40:	########################################	elapsed: 1.22s, reconstruction error: 8.17
# Epoch 41:	########################################	elapsed: 1.17s, reconstruction error: 8.24
# Epoch 42:	########################################	elapsed: 1.17s, reconstruction error: 8.22
# Epoch 43:	########################################	elapsed: 1.17s, reconstruction error: 8.20
# Epoch 44:	########################################	elapsed: 1.19s, reconstruction error: 8.23
# Epoch 45:	########################################	elapsed: 1.20s, reconstruction error: 8.17
# Epoch 46:	########################################	elapsed: 1.22s, reconstruction error: 8.12
# Epoch 47:	########################################	elapsed: 1.20s, reconstruction error: 7.98
# Epoch 48:	########################################	elapsed: 1.20s, reconstruction error: 8.02
# Epoch 49:	########################################	elapsed: 1.17s, reconstruction error: 8.01
# Epoch 50:	########################################	elapsed: 1.22s, reconstruction error: 8.06
#
# Learning layer 2
# Epoch 1:	########################################	elapsed: 1.04s, reconstruction error: 24.38
# Epoch 2:	########################################	elapsed: 0.99s, reconstruction error: 23.22
# Epoch 3:	########################################	elapsed: 0.99s, reconstruction error: 20.86
# Epoch 4:	########################################	elapsed: 1.13s, reconstruction error: 19.45
# Epoch 5:	########################################	elapsed: 0.98s, reconstruction error: 18.69
# Epoch 6:	########################################	elapsed: 0.98s, reconstruction error: 18.47
# Epoch 7:	########################################	elapsed: 0.99s, reconstruction error: 17.40
# Epoch 8:	########################################	elapsed: 0.97s, reconstruction error: 15.00
# Epoch 9:	########################################	elapsed: 0.98s, reconstruction error: 15.89
# Epoch 10:	########################################	elapsed: 0.96s, reconstruction error: 15.24
# Epoch 11:	########################################	elapsed: 0.96s, reconstruction error: 14.79
# Epoch 12:	########################################	elapsed: 0.95s, reconstruction error: 15.03
# Epoch 13:	########################################	elapsed: 0.96s, reconstruction error: 14.73
# Epoch 14:	########################################	elapsed: 0.97s, reconstruction error: 13.98
# Epoch 15:	########################################	elapsed: 0.94s, reconstruction error: 14.19
# Epoch 16:	########################################	elapsed: 0.93s, reconstruction error: 15.06
# Epoch 17:	########################################	elapsed: 0.91s, reconstruction error: 14.62
# Epoch 18:	########################################	elapsed: 0.89s, reconstruction error: 13.58
# Epoch 19:	########################################	elapsed: 0.94s, reconstruction error: 13.00
# Epoch 20:	########################################	elapsed: 0.99s, reconstruction error: 13.03
# Epoch 21:	########################################	elapsed: 0.97s, reconstruction error: 13.54
# Epoch 22:	########################################	elapsed: 0.99s, reconstruction error: 13.83
# Epoch 23:	########################################	elapsed: 0.98s, reconstruction error: 13.24
# Epoch 24:	########################################	elapsed: 1.00s, reconstruction error: 13.69
# Epoch 25:	########################################	elapsed: 0.97s, reconstruction error: 13.88
# Epoch 26:	########################################	elapsed: 0.97s, reconstruction error: 14.56
# Epoch 27:	########################################	elapsed: 0.98s, reconstruction error: 13.30
# Epoch 28:	########################################	elapsed: 0.97s, reconstruction error: 13.02
# Epoch 29:	########################################	elapsed: 1.04s, reconstruction error: 13.50
# Epoch 30:	########################################	elapsed: 0.99s, reconstruction error: 12.65
# Epoch 31:	########################################	elapsed: 0.99s, reconstruction error: 12.66
# Epoch 32:	########################################	elapsed: 0.98s, reconstruction error: 14.03
# Epoch 33:	########################################	elapsed: 0.96s, reconstruction error: 13.08
# Epoch 34:	########################################	elapsed: 1.00s, reconstruction error: 13.56
# Epoch 35:	########################################	elapsed: 0.96s, reconstruction error: 13.33
# Epoch 36:	########################################	elapsed: 0.98s, reconstruction error: 12.79
# Epoch 37:	########################################	elapsed: 0.98s, reconstruction error: 12.43
# Epoch 38:	########################################	elapsed: 0.99s, reconstruction error: 13.72
# Epoch 39:	########################################	elapsed: 0.98s, reconstruction error: 12.84
# Epoch 40:	########################################	elapsed: 0.98s, reconstruction error: 13.15
# Epoch 41:	########################################	elapsed: 0.97s, reconstruction error: 12.57
# Epoch 42:	########################################	elapsed: 0.97s, reconstruction error: 13.44
# Epoch 43:	########################################	elapsed: 0.98s, reconstruction error: 12.51
# Epoch 44:	########################################	elapsed: 0.98s, reconstruction error: 12.66
# Epoch 45:	########################################	elapsed: 0.98s, reconstruction error: 12.88
# Epoch 46:	########################################	elapsed: 0.97s, reconstruction error: 12.95
# Epoch 47:	########################################	elapsed: 0.97s, reconstruction error: 12.44
# Epoch 48:	########################################	elapsed: 0.99s, reconstruction error: 12.93
# Epoch 49:	########################################	elapsed: 0.97s, reconstruction error: 12.51
# Epoch 50:	########################################	elapsed: 0.96s, reconstruction error: 13.15
#
# Learning layer 3
# Epoch 1:	########################################	elapsed: 1.47s, reconstruction error: 13.80
# Epoch 2:	########################################	elapsed: 1.44s, reconstruction error: 14.41
# Epoch 3:	########################################	elapsed: 1.51s, reconstruction error: 14.34
# Epoch 4:	########################################	elapsed: 1.45s, reconstruction error: 14.17
# Epoch 5:	########################################	elapsed: 1.42s, reconstruction error: 14.34
# Epoch 6:	########################################	elapsed: 1.44s, reconstruction error: 14.64
# Epoch 7:	########################################	elapsed: 1.43s, reconstruction error: 15.70
# Epoch 8:	########################################	elapsed: 1.49s, reconstruction error: 14.94
# Epoch 9:	########################################	elapsed: 1.46s, reconstruction error: 13.95
# Epoch 10:	########################################	elapsed: 1.45s, reconstruction error: 13.44
# Epoch 11:	########################################	elapsed: 1.46s, reconstruction error: 14.28
# Epoch 12:	########################################	elapsed: 1.48s, reconstruction error: 14.55
# Epoch 13:	########################################	elapsed: 1.50s, reconstruction error: 13.58
# Epoch 14:	########################################	elapsed: 1.53s, reconstruction error: 13.41
# Epoch 15:	########################################	elapsed: 1.43s, reconstruction error: 13.65
# Epoch 16:	########################################	elapsed: 1.45s, reconstruction error: 14.54
# Epoch 17:	########################################	elapsed: 1.44s, reconstruction error: 13.49
# Epoch 18:	########################################	elapsed: 1.42s, reconstruction error: 13.33
# Epoch 19:	########################################	elapsed: 1.42s, reconstruction error: 13.39
# Epoch 20:	########################################	elapsed: 1.45s, reconstruction error: 13.48
# Epoch 21:	########################################	elapsed: 1.49s, reconstruction error: 13.25
# Epoch 22:	########################################	elapsed: 1.42s, reconstruction error: 13.86
# Epoch 23:	########################################	elapsed: 1.51s, reconstruction error: 13.13
# Epoch 24:	########################################	elapsed: 1.59s, reconstruction error: 13.04
# Epoch 25:	########################################	elapsed: 1.67s, reconstruction error: 13.61
# Epoch 26:	########################################	elapsed: 1.59s, reconstruction error: 12.76
# Epoch 27:	########################################	elapsed: 1.41s, reconstruction error: 13.61
# Epoch 28:	########################################	elapsed: 1.35s, reconstruction error: 13.10
# Epoch 29:	########################################	elapsed: 1.46s, reconstruction error: 13.18
# Epoch 30:	########################################	elapsed: 1.43s, reconstruction error: 12.96
# Epoch 31:	########################################	elapsed: 1.35s, reconstruction error: 13.20
# Epoch 32:	########################################	elapsed: 1.36s, reconstruction error: 13.01
# Epoch 33:	########################################	elapsed: 1.39s, reconstruction error: 13.09
# Epoch 34:	########################################	elapsed: 1.35s, reconstruction error: 12.56
# Epoch 35:	########################################	elapsed: 1.35s, reconstruction error: 12.41
# Epoch 36:	########################################	elapsed: 1.34s, reconstruction error: 12.49
# Epoch 37:	########################################	elapsed: 1.55s, reconstruction error: 12.39
# Epoch 38:	########################################	elapsed: 1.45s, reconstruction error: 12.31
# Epoch 39:	########################################	elapsed: 1.44s, reconstruction error: 12.70
# Epoch 40:	########################################	elapsed: 1.45s, reconstruction error: 12.83
# Epoch 41:	########################################	elapsed: 1.36s, reconstruction error: 12.28
# Epoch 42:	########################################	elapsed: 1.37s, reconstruction error: 12.80
# Epoch 43:	########################################	elapsed: 1.39s, reconstruction error: 12.85
# Epoch 44:	########################################	elapsed: 1.45s, reconstruction error: 12.77
# Epoch 45:	########################################	elapsed: 1.44s, reconstruction error: 12.04
# Epoch 46:	########################################	elapsed: 1.42s, reconstruction error: 12.52
# Epoch 47:	########################################	elapsed: 1.43s, reconstruction error: 12.65
# Epoch 48:	########################################	elapsed: 1.41s, reconstruction error: 12.44
# Epoch 49:	########################################	elapsed: 1.42s, reconstruction error: 12.36
# Epoch 50:	########################################	elapsed: 1.44s, reconstruction error: 12.44
# <h3>Finetuning pretrained MLP</h3>
# Epoch 1:	########################################	elapsed: 1.53s, accuracy: 90.56
# Epoch 2:	########################################	elapsed: 1.50s, accuracy: 94.40
# Epoch 3:	########################################	elapsed: 1.53s, accuracy: 94.37
# Epoch 4:	########################################	elapsed: 1.50s, accuracy: 94.06
# Epoch 5:	########################################	elapsed: 1.51s, accuracy: 94.81
# Epoch 6:	########################################	elapsed: 1.56s, accuracy: 94.36
# Epoch 7:	########################################	elapsed: 1.55s, accuracy: 95.11
# Epoch 8:	########################################	elapsed: 1.53s, accuracy: 96.11
# Epoch 9:	########################################	elapsed: 1.47s, accuracy: 95.88
# Epoch 10:	########################################	elapsed: 1.50s, accuracy: 95.93
# Epoch 11:	########################################	elapsed: 1.50s, accuracy: 95.45
# Epoch 12:	########################################	elapsed: 1.50s, accuracy: 96.29
# Epoch 13:	########################################	elapsed: 1.51s, accuracy: 95.79
# Epoch 14:	########################################	elapsed: 1.57s, accuracy: 96.94
# Epoch 15:	########################################	elapsed: 1.56s, accuracy: 96.37
# Epoch 16:	########################################	elapsed: 1.59s, accuracy: 96.64
# Epoch 17:	########################################	elapsed: 1.59s, accuracy: 96.04
# Epoch 18:	########################################	elapsed: 1.58s, accuracy: 96.78
# Epoch 19:	########################################	elapsed: 1.64s, accuracy: 97.14
# Epoch 20:	########################################	elapsed: 1.51s, accuracy: 97.15
# Epoch 21:	########################################	elapsed: 1.50s, accuracy: 97.27
# Epoch 22:	########################################	elapsed: 1.51s, accuracy: 97.34
# Epoch 23:	########################################	elapsed: 1.53s, accuracy: 97.35
# Epoch 24:	########################################	elapsed: 1.52s, accuracy: 97.33
# Epoch 25:	########################################	elapsed: 1.59s, accuracy: 97.34
# Epoch 26:	########################################	elapsed: 1.49s, accuracy: 97.32
# Epoch 27:	########################################	elapsed: 1.50s, accuracy: 97.33
# Epoch 28:	########################################	elapsed: 1.53s, accuracy: 97.33
# Epoch 29:	########################################	elapsed: 1.52s, accuracy: 97.33
# Epoch 30:	########################################	elapsed: 1.51s, accuracy: 97.33
# Epoch 31:	########################################	elapsed: 1.52s, accuracy: 97.32
# Epoch 32:	########################################	elapsed: 1.61s, accuracy: 97.32
# Epoch 33:	########################################	elapsed: 1.50s, accuracy: 97.31
# Epoch 34:	########################################	elapsed: 1.52s, accuracy: 97.31
# Epoch 35:	########################################	elapsed: 1.51s, accuracy: 97.32
# Epoch 36:	########################################	elapsed: 1.52s, accuracy: 97.32
# Epoch 37:	########################################	elapsed: 1.53s, accuracy: 97.32
# Epoch 38:	########################################	elapsed: 1.62s, accuracy: 97.31
# Epoch 39:	########################################	elapsed: 1.58s, accuracy: 97.31
# Epoch 40:	########################################	elapsed: 1.56s, accuracy: 97.34
# Epoch 41:	########################################	elapsed: 1.56s, accuracy: 97.34
# Epoch 42:	########################################	elapsed: 1.59s, accuracy: 97.36
# Epoch 43:	########################################	elapsed: 1.57s, accuracy: 97.34
# Epoch 44:	########################################	elapsed: 1.60s, accuracy: 97.34
# Epoch 45:	########################################	elapsed: 1.62s, accuracy: 97.35
# Epoch 46:	########################################	elapsed: 1.59s, accuracy: 97.35
# Epoch 47:	########################################	elapsed: 1.61s, accuracy: 97.34
# Epoch 48:	########################################	elapsed: 1.60s, accuracy: 97.35
# Epoch 49:	########################################	elapsed: 1.60s, accuracy: 97.35
# Epoch 50:	########################################	elapsed: 1.61s, accuracy: 97.37
# Training finished!
# <h3>First layer filters in the DBN</h3>
# <h3>Input layer filters in the pretrained & finetuned MLP</h3>
# <h3>Largest norms of weight-vectors in the finetuned MLP layers</h3>
# 	layer 1: 2.00
# 	layer 2: 1.00
# 	layer 3: 1.00
# 	layer 4: 4.00
